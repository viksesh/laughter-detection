# %% [markdown]
# # Creating an Audioset subset
#
# First, we need to download the full [Audioset](https://research.google.com/audioset/download.html) dataset. This is about 2.5GB so it may take some time to download.
#
# ### NOTE: The Audioset data is stored with filenames that are case sensitive. If you are using a filesystem with case-insensitive filenames (such as macOS) 75% of the dataset will be overwritten when you decompress the archive. You should only run this on a Linux machine.

# %%
# !wget http://storage.googleapis.com/us_audioset/youtube_corpus/v1/features/features.tar.gz
# Out:
# --2019-07-03 02:06:51--  http://storage.googleapis.com/us_audioset/youtube_corpus/v1/features/features.tar.gz
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.20.128, 2607:f8b0:400e:c08::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.20.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2588881044 (2.4G) [application/octet-stream]
# Saving to: ‘features.tar.gz’
#
# features.tar.gz     100%[===================>]   2.41G  23.5MB/s    in 47s
#
# 2019-07-03 02:07:44 (52.5 MB/s) - ‘features.tar.gz’ saved [2588881044/2588881044]

# %%
# !wget http://storage.googleapis.com/us_audioset/youtube_corpus/v1/csv/unbalanced_train_segments.csv
# Out:
# --2019-07-03 02:09:31--  http://storage.googleapis.com/us_audioset/youtube_corpus/v1/csv/unbalanced_train_segments.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.135.128, 2607:f8b0:400e:c07::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.135.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 101468408 (97M) [application/octet-stream]
# Saving to: ‘unbalanced_train_segments.csv’
#
# unbalanced_train_se 100%[===================>]  96.77M  23.9MB/s    in 4.0s
#
# 2019-07-03 02:09:37 (23.9 MB/s) - ‘unbalanced_train_segments.csv’ saved [101468408/101468408]

# %%
# !tar xvzf features.tar.gz
# Out:
# audioset_v1_embeddings/unbal_train/HV.tfrecord
# audioset_v1_embeddings/unbal_train/S0.tfrecord
# audioset_v1_embeddings/unbal_train/bo.tfrecord
# audioset_v1_embeddings/unbal_train/VL.tfrecord
# audioset_v1_embeddings/unbal_train/kN.tfrecord
# audioset_v1_embeddings/unbal_train/Wg.tfrecord
# audioset_v1_embeddings/unbal_train/5j.tfrecord
# audioset_v1_embeddings/unbal_train/nW.tfrecord
# audioset_v1_embeddings/unbal_train/uo.tfrecord
# audioset_v1_embeddings/unbal_train/fT.tfrecord
# audioset_v1_embeddings/unbal_train/jZ.tfrecord
# audioset_v1_embeddings/unbal_train/nU.tfrecord
# audioset_v1_embeddings/unbal_train/kI.tfrecord
# audioset_v1_embeddings/unbal_train/yG.tfrecord
# audioset_v1_embeddings/unbal_train/BA.tfrecord
# audioset_v1_embeddings/unbal_train/Lq.tfrecord
# audioset_v1_embeddings/unbal_train/Mu.tfrecord
# audioset_v1_embeddings/unbal_train/cU.tfrecord
# audioset_v1_embeddings/unbal_train/f3.tfrecord
# audioset_v1_embeddings/unbal_train/p-.tfrecord
# audioset_v1_embeddings/unbal_train/dp.tfrecord
# audioset_v1_embeddings/unbal_train/AL.tfrecord
# audioset_v1_embeddings/unbal_train/YM.tfrecord
# audioset_v1_embeddings/unbal_train/nX.tfrecord
# audioset_v1_embeddings/unbal_train/qe.tfrecord
# audioset_v1_embeddings/unbal_train/UH.tfrecord
# audioset_v1_embeddings/unbal_train/iX.tfrecord
# audioset_v1_embeddings/unbal_train/hm.tfrecord
# audioset_v1_embeddings/unbal_train/W3.tfrecord
# audioset_v1_embeddings/unbal_train/rp.tfrecord
# audioset_v1_embeddings/unbal_train/Rp.tfrecord
# audioset_v1_embeddings/unbal_train/8x.tfrecord
# audioset_v1_embeddings/unbal_train/B0.tfrecord
# audioset_v1_embeddings/unbal_train/7l.tfrecord
# audioset_v1_embeddings/unbal_train/XR.tfrecord
# audioset_v1_embeddings/unbal_train/9G.tfrecord
# audioset_v1_embeddings/unbal_train/9k.tfrecord
# audioset_v1_embeddings/unbal_train/E4.tfrecord
# audioset_v1_embeddings/unbal_train/8e.tfrecord
# audioset_v1_embeddings/unbal_train/uZ.tfrecord
# audioset_v1_embeddings/unbal_train/2H.tfrecord
# audioset_v1_embeddings/unbal_train/r8.tfrecord
# audioset_v1_embeddings/unbal_train/nj.tfrecord
# audioset_v1_embeddings/unbal_train/IL.tfrecord
# audioset_v1_embeddings/unbal_train/CP.tfrecord
# audioset_v1_embeddings/unbal_train/Lr.tfrecord
# audioset_v1_embeddings/unbal_train/ro.tfrecord
# audioset_v1_embeddings/unbal_train/Tq.tfrecord
# audioset_v1_embeddings/unbal_train/fB.tfrecord
# audioset_v1_embeddings/unbal_train/hK.tfrecord
# audioset_v1_embeddings/unbal_train/Gd.tfrecord
# audioset_v1_embeddings/unbal_train/C_.tfrecord
# audioset_v1_embeddings/unbal_train/vd.tfrecord
# audioset_v1_embeddings/unbal_train/3L.tfrecord
# audioset_v1_embeddings/unbal_train/vs.tfrecord
# audioset_v1_embeddings/unbal_train/tn.tfrecord
# audioset_v1_embeddings/unbal_train/g-.tfrecord
# audioset_v1_embeddings/unbal_train/Fr.tfrecord
# audioset_v1_embeddings/unbal_train/wU.tfrecord
# audioset_v1_embeddings/unbal_train/IW.tfrecord
# audioset_v1_embeddings/unbal_train/Dz.tfrecord
# audioset_v1_embeddings/unbal_train/Jc.tfrecord
# audioset_v1_embeddings/unbal_train/cZ.tfrecord
# audioset_v1_embeddings/unbal_train/ba.tfrecord
# audioset_v1_embeddings/unbal_train/Px.tfrecord
# audioset_v1_embeddings/unbal_train/vQ.tfrecord
# audioset_v1_embeddings/unbal_train/Uf.tfrecord
# audioset_v1_embeddings/unbal_train/ke.tfrecord
# audioset_v1_embeddings/unbal_train/gc.tfrecord
# audioset_v1_embeddings/unbal_train/g9.tfrecord
# audioset_v1_embeddings/unbal_train/LN.tfrecord
# audioset_v1_embeddings/unbal_train/il.tfrecord
# audioset_v1_embeddings/unbal_train/BR.tfrecord
# audioset_v1_embeddings/unbal_train/rO.tfrecord
# audioset_v1_embeddings/unbal_train/DF.tfrecord
# audioset_v1_embeddings/unbal_train/ad.tfrecord
# audioset_v1_embeddings/unbal_train/bq.tfrecord
# audioset_v1_embeddings/unbal_train/38.tfrecord
# audioset_v1_embeddings/unbal_train/nu.tfrecord
# audioset_v1_embeddings/unbal_train/Uh.tfrecord
# audioset_v1_embeddings/unbal_train/aE.tfrecord
# audioset_v1_embeddings/unbal_train/Dt.tfrecord
# audioset_v1_embeddings/unbal_train/x7.tfrecord
# audioset_v1_embeddings/unbal_train/K1.tfrecord
# audioset_v1_embeddings/unbal_train/c1.tfrecord
# audioset_v1_embeddings/unbal_train/5D.tfrecord
# audioset_v1_embeddings/unbal_train/bu.tfrecord
# audioset_v1_embeddings/unbal_train/y1.tfrecord
# audioset_v1_embeddings/unbal_train/qP.tfrecord
# audioset_v1_embeddings/unbal_train/vp.tfrecord
# audioset_v1_embeddings/unbal_train/ml.tfrecord
# audioset_v1_embeddings/unbal_train/vv.tfrecord
# audioset_v1_embeddings/unbal_train/fe.tfrecord
# audioset_v1_embeddings/unbal_train/N3.tfrecord
# audioset_v1_embeddings/unbal_train/4j.tfrecord
# audioset_v1_embeddings/unbal_train/dD.tfrecord
# audioset_v1_embeddings/unbal_train/ni.tfrecord
# audioset_v1_embeddings/unbal_train/1P.tfrecord
# audioset_v1_embeddings/unbal_train/RP.tfrecord
# audioset_v1_embeddings/unbal_train/9l.tfrecord
# audioset_v1_embeddings/unbal_train/Qz.tfrecord
# audioset_v1_embeddings/unbal_train/Pv.tfrecord
# audioset_v1_embeddings/unbal_train/zD.tfrecord
# audioset_v1_embeddings/unbal_train/Fv.tfrecord
# audioset_v1_embeddings/unbal_train/lm.tfrecord
# audioset_v1_embeddings/unbal_train/Ly.tfrecord
# audioset_v1_embeddings/unbal_train/9H.tfrecord
# audioset_v1_embeddings/unbal_train/0F.tfrecord
# audioset_v1_embeddings/unbal_train/u5.tfrecord
# audioset_v1_embeddings/unbal_train/uM.tfrecord
# audioset_v1_embeddings/unbal_train/r2.tfrecord
# audioset_v1_embeddings/unbal_train/Iy.tfrecord
# audioset_v1_embeddings/unbal_train/7R.tfrecord
# audioset_v1_embeddings/unbal_train/wK.tfrecord
# audioset_v1_embeddings/unbal_train/2B.tfrecord
# audioset_v1_embeddings/unbal_train/-2.tfrecord
# audioset_v1_embeddings/unbal_train/BV.tfrecord
# audioset_v1_embeddings/unbal_train/gN.tfrecord
# audioset_v1_embeddings/unbal_train/p9.tfrecord
# audioset_v1_embeddings/unbal_train/YZ.tfrecord
# audioset_v1_embeddings/unbal_train/pS.tfrecord
# audioset_v1_embeddings/unbal_train/Pw.tfrecord
# audioset_v1_embeddings/unbal_train/km.tfrecord
# audioset_v1_embeddings/unbal_train/rn.tfrecord
# audioset_v1_embeddings/unbal_train/ec.tfrecord
# audioset_v1_embeddings/unbal_train/LH.tfrecord
# audioset_v1_embeddings/unbal_train/P8.tfrecord
# audioset_v1_embeddings/unbal_train/wC.tfrecord
# audioset_v1_embeddings/unbal_train/Pa.tfrecord
# audioset_v1_embeddings/unbal_train/Vj.tfrecord
# audioset_v1_embeddings/unbal_train/Co.tfrecord
# audioset_v1_embeddings/unbal_train/MY.tfrecord
# audioset_v1_embeddings/unbal_train/xq.tfrecord
# audioset_v1_embeddings/unbal_train/Zr.tfrecord
# audioset_v1_embeddings/unbal_train/tS.tfrecord
# audioset_v1_embeddings/unbal_train/OB.tfrecord
# audioset_v1_embeddings/unbal_train/J5.tfrecord
# audioset_v1_embeddings/unbal_train/Nh.tfrecord
# audioset_v1_embeddings/unbal_train/KL.tfrecord
# audioset_v1_embeddings/unbal_train/PC.tfrecord
# audioset_v1_embeddings/unbal_train/xl.tfrecord
# audioset_v1_embeddings/unbal_train/kf.tfrecord
# audioset_v1_embeddings/unbal_train/CC.tfrecord
# audioset_v1_embeddings/unbal_train/Ck.tfrecord
# audioset_v1_embeddings/unbal_train/p3.tfrecord
# audioset_v1_embeddings/unbal_train/cp.tfrecord
# audioset_v1_embeddings/unbal_train/Bz.tfrecord
# audioset_v1_embeddings/unbal_train/2b.tfrecord
# audioset_v1_embeddings/unbal_train/X0.tfrecord
# audioset_v1_embeddings/unbal_train/9f.tfrecord
# audioset_v1_embeddings/unbal_train/au.tfrecord
# audioset_v1_embeddings/unbal_train/_f.tfrecord
# audioset_v1_embeddings/unbal_train/Ty.tfrecord
# audioset_v1_embeddings/unbal_train/-b.tfrecord
# audioset_v1_embeddings/unbal_train/3t.tfrecord
# audioset_v1_embeddings/unbal_train/Rx.tfrecord
# audioset_v1_embeddings/unbal_train/7k.tfrecord
# audioset_v1_embeddings/unbal_train/tu.tfrecord
# audioset_v1_embeddings/unbal_train/gB.tfrecord
# audioset_v1_embeddings/unbal_train/U6.tfrecord
# audioset_v1_embeddings/unbal_train/8-.tfrecord
# audioset_v1_embeddings/unbal_train/aP.tfrecord
# audioset_v1_embeddings/unbal_train/Rk.tfrecord
# audioset_v1_embeddings/unbal_train/WR.tfrecord
# audioset_v1_embeddings/unbal_train/ej.tfrecord
# audioset_v1_embeddings/unbal_train/P0.tfrecord
# audioset_v1_embeddings/unbal_train/hk.tfrecord
# audioset_v1_embeddings/unbal_train/3F.tfrecord
# audioset_v1_embeddings/unbal_train/Wi.tfrecord
# audioset_v1_embeddings/unbal_train/we.tfrecord
# audioset_v1_embeddings/unbal_train/uj.tfrecord
# audioset_v1_embeddings/unbal_train/0m.tfrecord
# audioset_v1_embeddings/unbal_train/XA.tfrecord
# audioset_v1_embeddings/unbal_train/id.tfrecord
# audioset_v1_embeddings/unbal_train/Kw.tfrecord
# audioset_v1_embeddings/unbal_train/Yj.tfrecord
# audioset_v1_embeddings/unbal_train/fi.tfrecord
# audioset_v1_embeddings/unbal_train/xM.tfrecord
# audioset_v1_embeddings/unbal_train/rN.tfrecord
# audioset_v1_embeddings/unbal_train/0g.tfrecord
# audioset_v1_embeddings/unbal_train/cK.tfrecord
# audioset_v1_embeddings/unbal_train/Vl.tfrecord
# audioset_v1_embeddings/unbal_train/7t.tfrecord
# audioset_v1_embeddings/unbal_train/zN.tfrecord
# audioset_v1_embeddings/unbal_train/NY.tfrecord
# audioset_v1_embeddings/unbal_train/6j.tfrecord
# audioset_v1_embeddings/unbal_train/pX.tfrecord
# audioset_v1_embeddings/unbal_train/3f.tfrecord
# audioset_v1_embeddings/unbal_train/Ou.tfrecord
# audioset_v1_embeddings/unbal_train/3N.tfrecord
# audioset_v1_embeddings/unbal_train/Bt.tfrecord
# audioset_v1_embeddings/unbal_train/Je.tfrecord
# audioset_v1_embeddings/unbal_train/zt.tfrecord
# audioset_v1_embeddings/unbal_train/qa.tfrecord
# audioset_v1_embeddings/unbal_train/Ow.tfrecord
# audioset_v1_embeddings/unbal_train/gp.tfrecord
# audioset_v1_embeddings/unbal_train/E8.tfrecord
# audioset_v1_embeddings/unbal_train/KW.tfrecord
# audioset_v1_embeddings/unbal_train/9p.tfrecord
# audioset_v1_embeddings/unbal_train/76.tfrecord
# audioset_v1_embeddings/unbal_train/y8.tfrecord
# audioset_v1_embeddings/unbal_train/Fy.tfrecord
# audioset_v1_embeddings/unbal_train/AE.tfrecord
# audioset_v1_embeddings/unbal_train/VQ.tfrecord
# audioset_v1_embeddings/unbal_train/rF.tfrecord
# audioset_v1_embeddings/unbal_train/QS.tfrecord
# audioset_v1_embeddings/unbal_train/z6.tfrecord
# audioset_v1_embeddings/unbal_train/y3.tfrecord
# audioset_v1_embeddings/unbal_train/L6.tfrecord
# audioset_v1_embeddings/unbal_train/0h.tfrecord
# audioset_v1_embeddings/unbal_train/jC.tfrecord
# audioset_v1_embeddings/unbal_train/T9.tfrecord
# audioset_v1_embeddings/unbal_train/zU.tfrecord
# audioset_v1_embeddings/unbal_train/eU.tfrecord
# audioset_v1_embeddings/unbal_train/dL.tfrecord
# audioset_v1_embeddings/unbal_train/Bm.tfrecord
# audioset_v1_embeddings/unbal_train/F-.tfrecord
# audioset_v1_embeddings/unbal_train/O7.tfrecord
# audioset_v1_embeddings/unbal_train/om.tfrecord
# audioset_v1_embeddings/unbal_train/2M.tfrecord
# audioset_v1_embeddings/unbal_train/7D.tfrecord
# audioset_v1_embeddings/unbal_train/LW.tfrecord
# audioset_v1_embeddings/unbal_train/kU.tfrecord
# audioset_v1_embeddings/unbal_train/j6.tfrecord
# audioset_v1_embeddings/unbal_train/W0.tfrecord
# audioset_v1_embeddings/unbal_train/aJ.tfrecord
# audioset_v1_embeddings/unbal_train/Yk.tfrecord
# audioset_v1_embeddings/unbal_train/T6.tfrecord
# audioset_v1_embeddings/unbal_train/uU.tfrecord
# audioset_v1_embeddings/unbal_train/b4.tfrecord
# audioset_v1_embeddings/unbal_train/6H.tfrecord
# audioset_v1_embeddings/unbal_train/x1.tfrecord
# audioset_v1_embeddings/unbal_train/1N.tfrecord
# audioset_v1_embeddings/unbal_train/T7.tfrecord
# audioset_v1_embeddings/unbal_train/b9.tfrecord
# audioset_v1_embeddings/unbal_train/-R.tfrecord
# audioset_v1_embeddings/unbal_train/pY.tfrecord
# audioset_v1_embeddings/unbal_train/qs.tfrecord
# audioset_v1_embeddings/unbal_train/Zk.tfrecord
# audioset_v1_embeddings/unbal_train/bf.tfrecord
# audioset_v1_embeddings/unbal_train/vu.tfrecord
# audioset_v1_embeddings/unbal_train/O9.tfrecord
# audioset_v1_embeddings/unbal_train/qE.tfrecord
# audioset_v1_embeddings/unbal_train/5G.tfrecord
# audioset_v1_embeddings/unbal_train/I3.tfrecord
# audioset_v1_embeddings/unbal_train/xD.tfrecord
# audioset_v1_embeddings/unbal_train/F_.tfrecord
# audioset_v1_embeddings/unbal_train/fX.tfrecord
# audioset_v1_embeddings/unbal_train/FG.tfrecord
# audioset_v1_embeddings/unbal_train/bl.tfrecord
# audioset_v1_embeddings/unbal_train/f7.tfrecord
# audioset_v1_embeddings/unbal_train/cc.tfrecord
# audioset_v1_embeddings/unbal_train/Fh.tfrecord
# audioset_v1_embeddings/unbal_train/QX.tfrecord
# audioset_v1_embeddings/unbal_train/Hl.tfrecord
# audioset_v1_embeddings/unbal_train/Fk.tfrecord
# audioset_v1_embeddings/unbal_train/_9.tfrecord
# audioset_v1_embeddings/unbal_train/pb.tfrecord
# audioset_v1_embeddings/unbal_train/dB.tfrecord
# audioset_v1_embeddings/unbal_train/SM.tfrecord
# audioset_v1_embeddings/unbal_train/oE.tfrecord
# audioset_v1_embeddings/unbal_train/Hb.tfrecord
# audioset_v1_embeddings/unbal_train/wt.tfrecord
# audioset_v1_embeddings/unbal_train/lP.tfrecord
# audioset_v1_embeddings/unbal_train/Lm.tfrecord
# audioset_v1_embeddings/unbal_train/lf.tfrecord
# audioset_v1_embeddings/unbal_train/EL.tfrecord
# audioset_v1_embeddings/unbal_train/Mo.tfrecord
# audioset_v1_embeddings/unbal_train/nl.tfrecord
# audioset_v1_embeddings/unbal_train/X5.tfrecord
# audioset_v1_embeddings/unbal_train/ZN.tfrecord
# audioset_v1_embeddings/unbal_train/4O.tfrecord
# audioset_v1_embeddings/unbal_train/YB.tfrecord
# audioset_v1_embeddings/unbal_train/ZY.tfrecord
# audioset_v1_embeddings/unbal_train/rR.tfrecord
# audioset_v1_embeddings/unbal_train/rj.tfrecord
# audioset_v1_embeddings/unbal_train/-9.tfrecord
# audioset_v1_embeddings/unbal_train/nN.tfrecord
# audioset_v1_embeddings/unbal_train/2S.tfrecord
# audioset_v1_embeddings/unbal_train/Ml.tfrecord
# audioset_v1_embeddings/unbal_train/b1.tfrecord
# audioset_v1_embeddings/unbal_train/2n.tfrecord
# audioset_v1_embeddings/unbal_train/fN.tfrecord
# audioset_v1_embeddings/unbal_train/fW.tfrecord
# audioset_v1_embeddings/unbal_train/y5.tfrecord
# audioset_v1_embeddings/unbal_train/_Y.tfrecord
# audioset_v1_embeddings/unbal_train/AN.tfrecord
# audioset_v1_embeddings/unbal_train/Mm.tfrecord
# audioset_v1_embeddings/unbal_train/3n.tfrecord
# audioset_v1_embeddings/unbal_train/Fo.tfrecord
# audioset_v1_embeddings/unbal_train/ru.tfrecord
# audioset_v1_embeddings/unbal_train/GE.tfrecord
# audioset_v1_embeddings/unbal_train/7Q.tfrecord
# audioset_v1_embeddings/unbal_train/h0.tfrecord
# audioset_v1_embeddings/unbal_train/Ba.tfrecord
# audioset_v1_embeddings/unbal_train/3O.tfrecord
# audioset_v1_embeddings/unbal_train/sI.tfrecord
# audioset_v1_embeddings/unbal_train/fV.tfrecord
# audioset_v1_embeddings/unbal_train/gt.tfrecord
# audioset_v1_embeddings/unbal_train/mK.tfrecord
# audioset_v1_embeddings/unbal_train/ZZ.tfrecord
# audioset_v1_embeddings/unbal_train/Ym.tfrecord
# audioset_v1_embeddings/unbal_train/2J.tfrecord
# audioset_v1_embeddings/unbal_train/Pb.tfrecord
# audioset_v1_embeddings/unbal_train/ZB.tfrecord
# audioset_v1_embeddings/unbal_train/d4.tfrecord
# audioset_v1_embeddings/unbal_train/RJ.tfrecord
# audioset_v1_embeddings/unbal_train/AI.tfrecord
# audioset_v1_embeddings/unbal_train/Ll.tfrecord
# audioset_v1_embeddings/unbal_train/JJ.tfrecord
# audioset_v1_embeddings/unbal_train/v7.tfrecord
# audioset_v1_embeddings/unbal_train/Eb.tfrecord
# audioset_v1_embeddings/unbal_train/ap.tfrecord
# audioset_v1_embeddings/unbal_train/V-.tfrecord
# audioset_v1_embeddings/unbal_train/7L.tfrecord
# audioset_v1_embeddings/unbal_train/hB.tfrecord
# audioset_v1_embeddings/unbal_train/5-.tfrecord
# audioset_v1_embeddings/unbal_train/vr.tfrecord
# audioset_v1_embeddings/unbal_train/FC.tfrecord
# audioset_v1_embeddings/unbal_train/vE.tfrecord
# audioset_v1_embeddings/unbal_train/u4.tfrecord
# audioset_v1_embeddings/unbal_train/-h.tfrecord
# audioset_v1_embeddings/unbal_train/33.tfrecord
# audioset_v1_embeddings/unbal_train/PU.tfrecord
# audioset_v1_embeddings/unbal_train/c5.tfrecord
# audioset_v1_embeddings/unbal_train/r3.tfrecord
# audioset_v1_embeddings/unbal_train/6o.tfrecord
# audioset_v1_embeddings/unbal_train/7A.tfrecord
# audioset_v1_embeddings/unbal_train/jE.tfrecord
# audioset_v1_embeddings/unbal_train/dk.tfrecord
# audioset_v1_embeddings/unbal_train/yQ.tfrecord
# audioset_v1_embeddings/unbal_train/2o.tfrecord
# audioset_v1_embeddings/unbal_train/6B.tfrecord
# audioset_v1_embeddings/unbal_train/Jq.tfrecord
# audioset_v1_embeddings/unbal_train/2X.tfrecord
# audioset_v1_embeddings/unbal_train/xy.tfrecord
# audioset_v1_embeddings/unbal_train/kA.tfrecord
# audioset_v1_embeddings/unbal_train/aQ.tfrecord
# audioset_v1_embeddings/unbal_train/PO.tfrecord
# audioset_v1_embeddings/unbal_train/Aq.tfrecord
# audioset_v1_embeddings/unbal_train/Sp.tfrecord
# audioset_v1_embeddings/unbal_train/ev.tfrecord
# audioset_v1_embeddings/unbal_train/iQ.tfrecord
# audioset_v1_embeddings/unbal_train/t2.tfrecord
# audioset_v1_embeddings/unbal_train/-Q.tfrecord
# audioset_v1_embeddings/unbal_train/sV.tfrecord
# audioset_v1_embeddings/unbal_train/ga.tfrecord
# audioset_v1_embeddings/unbal_train/aC.tfrecord
# audioset_v1_embeddings/unbal_train/Vz.tfrecord
# audioset_v1_embeddings/unbal_train/i4.tfrecord
# audioset_v1_embeddings/unbal_train/bM.tfrecord
# audioset_v1_embeddings/unbal_train/6M.tfrecord
# audioset_v1_embeddings/unbal_train/WS.tfrecord
# audioset_v1_embeddings/unbal_train/AA.tfrecord
# audioset_v1_embeddings/unbal_train/6X.tfrecord
# audioset_v1_embeddings/unbal_train/09.tfrecord
# audioset_v1_embeddings/unbal_train/nV.tfrecord
# audioset_v1_embeddings/unbal_train/u6.tfrecord
# audioset_v1_embeddings/unbal_train/R1.tfrecord
# audioset_v1_embeddings/unbal_train/DI.tfrecord
# audioset_v1_embeddings/unbal_train/fS.tfrecord
# audioset_v1_embeddings/unbal_train/a8.tfrecord
# audioset_v1_embeddings/unbal_train/xe.tfrecord
# audioset_v1_embeddings/unbal_train/Bf.tfrecord
# audioset_v1_embeddings/unbal_train/mj.tfrecord
# audioset_v1_embeddings/unbal_train/xT.tfrecord
# audioset_v1_embeddings/unbal_train/kd.tfrecord
# audioset_v1_embeddings/unbal_train/PS.tfrecord
# audioset_v1_embeddings/unbal_train/ms.tfrecord
# audioset_v1_embeddings/unbal_train/66.tfrecord
# audioset_v1_embeddings/unbal_train/dG.tfrecord
# audioset_v1_embeddings/unbal_train/0y.tfrecord
# audioset_v1_embeddings/unbal_train/1X.tfrecord
# audioset_v1_embeddings/unbal_train/Zj.tfrecord
# audioset_v1_embeddings/unbal_train/y0.tfrecord
# audioset_v1_embeddings/unbal_train/YL.tfrecord
# audioset_v1_embeddings/unbal_train/RD.tfrecord
# audioset_v1_embeddings/unbal_train/R5.tfrecord
# audioset_v1_embeddings/unbal_train/e5.tfrecord
# audioset_v1_embeddings/unbal_train/y2.tfrecord
# audioset_v1_embeddings/unbal_train/sW.tfrecord
# audioset_v1_embeddings/unbal_train/Wz.tfrecord
# audioset_v1_embeddings/unbal_train/KX.tfrecord
# audioset_v1_embeddings/unbal_train/8k.tfrecord
# audioset_v1_embeddings/unbal_train/rV.tfrecord
# audioset_v1_embeddings/unbal_train/g1.tfrecord
# audioset_v1_embeddings/unbal_train/DP.tfrecord
# audioset_v1_embeddings/unbal_train/qp.tfrecord
# audioset_v1_embeddings/unbal_train/iG.tfrecord
# audioset_v1_embeddings/unbal_train/SR.tfrecord
# audioset_v1_embeddings/unbal_train/Ua.tfrecord
# audioset_v1_embeddings/unbal_train/cW.tfrecord
# audioset_v1_embeddings/unbal_train/uL.tfrecord
# audioset_v1_embeddings/unbal_train/hH.tfrecord
# audioset_v1_embeddings/unbal_train/h3.tfrecord
# audioset_v1_embeddings/unbal_train/bv.tfrecord
# audioset_v1_embeddings/unbal_train/8K.tfrecord
# audioset_v1_embeddings/unbal_train/MR.tfrecord
# audioset_v1_embeddings/unbal_train/1D.tfrecord
# audioset_v1_embeddings/unbal_train/tv.tfrecord
# audioset_v1_embeddings/unbal_train/Xi.tfrecord
# audioset_v1_embeddings/unbal_train/tG.tfrecord
# audioset_v1_embeddings/unbal_train/HM.tfrecord
# audioset_v1_embeddings/unbal_train/aa.tfrecord
# audioset_v1_embeddings/unbal_train/BZ.tfrecord
# audioset_v1_embeddings/unbal_train/sy.tfrecord
# audioset_v1_embeddings/unbal_train/uh.tfrecord
# audioset_v1_embeddings/unbal_train/GW.tfrecord
# audioset_v1_embeddings/unbal_train/4L.tfrecord
# audioset_v1_embeddings/unbal_train/j_.tfrecord
# audioset_v1_embeddings/unbal_train/GP.tfrecord
# audioset_v1_embeddings/unbal_train/vD.tfrecord
# audioset_v1_embeddings/unbal_train/xX.tfrecord
# audioset_v1_embeddings/unbal_train/mX.tfrecord
# audioset_v1_embeddings/unbal_train/W6.tfrecord
# audioset_v1_embeddings/unbal_train/5x.tfrecord
# audioset_v1_embeddings/unbal_train/UQ.tfrecord
# audioset_v1_embeddings/unbal_train/Cz.tfrecord
# audioset_v1_embeddings/unbal_train/ei.tfrecord
# audioset_v1_embeddings/unbal_train/3Q.tfrecord
# audioset_v1_embeddings/unbal_train/Vh.tfrecord
# audioset_v1_embeddings/unbal_train/j3.tfrecord
# audioset_v1_embeddings/unbal_train/L2.tfrecord
# audioset_v1_embeddings/unbal_train/yM.tfrecord
# audioset_v1_embeddings/unbal_train/-n.tfrecord
# audioset_v1_embeddings/unbal_train/nk.tfrecord
# audioset_v1_embeddings/unbal_train/3H.tfrecord
# audioset_v1_embeddings/unbal_train/Ns.tfrecord
# audioset_v1_embeddings/unbal_train/56.tfrecord
# audioset_v1_embeddings/unbal_train/hI.tfrecord
# audioset_v1_embeddings/unbal_train/ab.tfrecord
# audioset_v1_embeddings/unbal_train/US.tfrecord
# audioset_v1_embeddings/unbal_train/w_.tfrecord
# audioset_v1_embeddings/unbal_train/AM.tfrecord
# audioset_v1_embeddings/unbal_train/TN.tfrecord
# audioset_v1_embeddings/unbal_train/By.tfrecord
# audioset_v1_embeddings/unbal_train/4P.tfrecord
# audioset_v1_embeddings/unbal_train/yz.tfrecord
# audioset_v1_embeddings/unbal_train/qC.tfrecord
# audioset_v1_embeddings/unbal_train/O2.tfrecord
# audioset_v1_embeddings/unbal_train/Zp.tfrecord
# audioset_v1_embeddings/unbal_train/oz.tfrecord
# audioset_v1_embeddings/unbal_train/Km.tfrecord
# audioset_v1_embeddings/unbal_train/BU.tfrecord
# audioset_v1_embeddings/unbal_train/an.tfrecord
# audioset_v1_embeddings/unbal_train/I2.tfrecord
# audioset_v1_embeddings/unbal_train/jq.tfrecord
# audioset_v1_embeddings/unbal_train/sU.tfrecord
# audioset_v1_embeddings/unbal_train/CB.tfrecord
# audioset_v1_embeddings/unbal_train/eR.tfrecord
# audioset_v1_embeddings/unbal_train/-O.tfrecord
# audioset_v1_embeddings/unbal_train/-d.tfrecord
# audioset_v1_embeddings/unbal_train/E_.tfrecord
# audioset_v1_embeddings/unbal_train/EP.tfrecord
# audioset_v1_embeddings/unbal_train/17.tfrecord
# audioset_v1_embeddings/unbal_train/xC.tfrecord
# audioset_v1_embeddings/unbal_train/pd.tfrecord
# audioset_v1_embeddings/unbal_train/J8.tfrecord
# audioset_v1_embeddings/unbal_train/ff.tfrecord
# audioset_v1_embeddings/unbal_train/8M.tfrecord
# audioset_v1_embeddings/unbal_train/Zm.tfrecord
# audioset_v1_embeddings/unbal_train/Fj.tfrecord
# audioset_v1_embeddings/unbal_train/nG.tfrecord
# audioset_v1_embeddings/unbal_train/d9.tfrecord
# audioset_v1_embeddings/unbal_train/1m.tfrecord
# audioset_v1_embeddings/unbal_train/yP.tfrecord
# audioset_v1_embeddings/unbal_train/75.tfrecord
# audioset_v1_embeddings/unbal_train/od.tfrecord
# audioset_v1_embeddings/unbal_train/v9.tfrecord
# audioset_v1_embeddings/unbal_train/ca.tfrecord
# audioset_v1_embeddings/unbal_train/fO.tfrecord
# audioset_v1_embeddings/unbal_train/xp.tfrecord
# audioset_v1_embeddings/unbal_train/2E.tfrecord
# audioset_v1_embeddings/unbal_train/Z-.tfrecord
# audioset_v1_embeddings/unbal_train/PD.tfrecord
# audioset_v1_embeddings/unbal_train/lX.tfrecord
# audioset_v1_embeddings/unbal_train/XP.tfrecord
# audioset_v1_embeddings/unbal_train/op.tfrecord
# audioset_v1_embeddings/unbal_train/jA.tfrecord
# audioset_v1_embeddings/unbal_train/z9.tfrecord
# audioset_v1_embeddings/unbal_train/6A.tfrecord
# audioset_v1_embeddings/unbal_train/5q.tfrecord
# audioset_v1_embeddings/unbal_train/8V.tfrecord
# audioset_v1_embeddings/unbal_train/Tf.tfrecord
# audioset_v1_embeddings/unbal_train/Fg.tfrecord
# audioset_v1_embeddings/unbal_train/HJ.tfrecord
# audioset_v1_embeddings/unbal_train/hT.tfrecord
# audioset_v1_embeddings/unbal_train/3w.tfrecord
# audioset_v1_embeddings/unbal_train/Ut.tfrecord
# audioset_v1_embeddings/unbal_train/C0.tfrecord
# audioset_v1_embeddings/unbal_train/W1.tfrecord
# audioset_v1_embeddings/unbal_train/bK.tfrecord
# audioset_v1_embeddings/unbal_train/l4.tfrecord
# audioset_v1_embeddings/unbal_train/8z.tfrecord
# audioset_v1_embeddings/unbal_train/dv.tfrecord
# audioset_v1_embeddings/unbal_train/h1.tfrecord
# audioset_v1_embeddings/unbal_train/7J.tfrecord
# audioset_v1_embeddings/unbal_train/W7.tfrecord
# audioset_v1_embeddings/unbal_train/jG.tfrecord
# audioset_v1_embeddings/unbal_train/aB.tfrecord
# audioset_v1_embeddings/unbal_train/GC.tfrecord
# audioset_v1_embeddings/unbal_train/bc.tfrecord
# audioset_v1_embeddings/unbal_train/t9.tfrecord
# audioset_v1_embeddings/unbal_train/qV.tfrecord
# audioset_v1_embeddings/unbal_train/8B.tfrecord
# audioset_v1_embeddings/unbal_train/wA.tfrecord
# audioset_v1_embeddings/unbal_train/2i.tfrecord
# audioset_v1_embeddings/unbal_train/Sa.tfrecord
# audioset_v1_embeddings/unbal_train/DX.tfrecord
# audioset_v1_embeddings/unbal_train/o-.tfrecord
# audioset_v1_embeddings/unbal_train/qo.tfrecord
# audioset_v1_embeddings/unbal_train/6k.tfrecord
# audioset_v1_embeddings/unbal_train/EM.tfrecord
# audioset_v1_embeddings/unbal_train/gX.tfrecord
# audioset_v1_embeddings/unbal_train/to.tfrecord
# audioset_v1_embeddings/unbal_train/GF.tfrecord
# audioset_v1_embeddings/unbal_train/WY.tfrecord
# audioset_v1_embeddings/unbal_train/Y8.tfrecord
# audioset_v1_embeddings/unbal_train/gk.tfrecord
# audioset_v1_embeddings/unbal_train/a9.tfrecord
# audioset_v1_embeddings/unbal_train/lG.tfrecord
# audioset_v1_embeddings/unbal_train/5B.tfrecord
# audioset_v1_embeddings/unbal_train/1J.tfrecord
# audioset_v1_embeddings/unbal_train/HK.tfrecord
# audioset_v1_embeddings/unbal_train/c2.tfrecord
# audioset_v1_embeddings/unbal_train/wR.tfrecord
# audioset_v1_embeddings/unbal_train/UY.tfrecord
# audioset_v1_embeddings/unbal_train/p5.tfrecord
# audioset_v1_embeddings/unbal_train/Vv.tfrecord
# audioset_v1_embeddings/unbal_train/Et.tfrecord
# audioset_v1_embeddings/unbal_train/4z.tfrecord
# audioset_v1_embeddings/unbal_train/tz.tfrecord
# audioset_v1_embeddings/unbal_train/qU.tfrecord
# audioset_v1_embeddings/unbal_train/-l.tfrecord
# audioset_v1_embeddings/unbal_train/Oc.tfrecord
# audioset_v1_embeddings/unbal_train/yt.tfrecord
# audioset_v1_embeddings/unbal_train/oA.tfrecord
# audioset_v1_embeddings/unbal_train/Hc.tfrecord
# audioset_v1_embeddings/unbal_train/l-.tfrecord
# audioset_v1_embeddings/unbal_train/Ib.tfrecord
# audioset_v1_embeddings/unbal_train/GG.tfrecord
# audioset_v1_embeddings/unbal_train/Bq.tfrecord
# audioset_v1_embeddings/unbal_train/QL.tfrecord
# audioset_v1_embeddings/unbal_train/HR.tfrecord
# audioset_v1_embeddings/unbal_train/Ms.tfrecord
# audioset_v1_embeddings/unbal_train/gT.tfrecord
# audioset_v1_embeddings/unbal_train/bQ.tfrecord
# audioset_v1_embeddings/unbal_train/sf.tfrecord
# audioset_v1_embeddings/unbal_train/ds.tfrecord
# audioset_v1_embeddings/unbal_train/vM.tfrecord
# audioset_v1_embeddings/unbal_train/jK.tfrecord
# audioset_v1_embeddings/unbal_train/Xy.tfrecord
# audioset_v1_embeddings/unbal_train/nY.tfrecord
# audioset_v1_embeddings/unbal_train/yw.tfrecord
# audioset_v1_embeddings/unbal_train/CE.tfrecord
# audioset_v1_embeddings/unbal_train/AP.tfrecord
# audioset_v1_embeddings/unbal_train/O3.tfrecord
# audioset_v1_embeddings/unbal_train/8Q.tfrecord
# audioset_v1_embeddings/unbal_train/nI.tfrecord
# audioset_v1_embeddings/unbal_train/xf.tfrecord
# audioset_v1_embeddings/unbal_train/wa.tfrecord
# audioset_v1_embeddings/unbal_train/Ww.tfrecord
# audioset_v1_embeddings/unbal_train/zv.tfrecord
# audioset_v1_embeddings/unbal_train/Vy.tfrecord
# audioset_v1_embeddings/unbal_train/-g.tfrecord
# audioset_v1_embeddings/unbal_train/55.tfrecord
# audioset_v1_embeddings/unbal_train/wg.tfrecord
# audioset_v1_embeddings/unbal_train/ma.tfrecord
# audioset_v1_embeddings/unbal_train/7E.tfrecord
# audioset_v1_embeddings/unbal_train/_W.tfrecord
# audioset_v1_embeddings/unbal_train/-I.tfrecord
# audioset_v1_embeddings/unbal_train/4I.tfrecord
# audioset_v1_embeddings/unbal_train/99.tfrecord
# audioset_v1_embeddings/unbal_train/IB.tfrecord
# audioset_v1_embeddings/unbal_train/6w.tfrecord
# audioset_v1_embeddings/unbal_train/og.tfrecord
# audioset_v1_embeddings/unbal_train/-x.tfrecord
# audioset_v1_embeddings/unbal_train/2u.tfrecord
# audioset_v1_embeddings/unbal_train/EH.tfrecord
# audioset_v1_embeddings/unbal_train/_w.tfrecord
# audioset_v1_embeddings/unbal_train/4A.tfrecord
# audioset_v1_embeddings/unbal_train/Xk.tfrecord
# audioset_v1_embeddings/unbal_train/st.tfrecord
# audioset_v1_embeddings/unbal_train/-4.tfrecord
# audioset_v1_embeddings/unbal_train/Vg.tfrecord
# audioset_v1_embeddings/unbal_train/Zy.tfrecord
# audioset_v1_embeddings/unbal_train/xF.tfrecord
# audioset_v1_embeddings/unbal_train/ik.tfrecord
# audioset_v1_embeddings/unbal_train/Ro.tfrecord
# audioset_v1_embeddings/unbal_train/o4.tfrecord
# audioset_v1_embeddings/unbal_train/uQ.tfrecord
# audioset_v1_embeddings/unbal_train/Dh.tfrecord
# audioset_v1_embeddings/unbal_train/-W.tfrecord
# audioset_v1_embeddings/unbal_train/-C.tfrecord
# audioset_v1_embeddings/unbal_train/m9.tfrecord
# audioset_v1_embeddings/unbal_train/IO.tfrecord
# audioset_v1_embeddings/unbal_train/fM.tfrecord
# audioset_v1_embeddings/unbal_train/lN.tfrecord
# audioset_v1_embeddings/unbal_train/7X.tfrecord
# audioset_v1_embeddings/unbal_train/xo.tfrecord
# audioset_v1_embeddings/unbal_train/tm.tfrecord
# audioset_v1_embeddings/unbal_train/4M.tfrecord
# audioset_v1_embeddings/unbal_train/Xu.tfrecord
# audioset_v1_embeddings/unbal_train/nr.tfrecord
# audioset_v1_embeddings/unbal_train/Bo.tfrecord
# audioset_v1_embeddings/unbal_train/1w.tfrecord
# audioset_v1_embeddings/unbal_train/gJ.tfrecord
# audioset_v1_embeddings/unbal_train/No.tfrecord
# audioset_v1_embeddings/unbal_train/i8.tfrecord
# audioset_v1_embeddings/unbal_train/r0.tfrecord
# audioset_v1_embeddings/unbal_train/2m.tfrecord
# audioset_v1_embeddings/unbal_train/x2.tfrecord
# audioset_v1_embeddings/unbal_train/s6.tfrecord
# audioset_v1_embeddings/unbal_train/hU.tfrecord
# audioset_v1_embeddings/unbal_train/S8.tfrecord
# audioset_v1_embeddings/unbal_train/sr.tfrecord
# audioset_v1_embeddings/unbal_train/yE.tfrecord
# audioset_v1_embeddings/unbal_train/bX.tfrecord
# audioset_v1_embeddings/unbal_train/LL.tfrecord
# audioset_v1_embeddings/unbal_train/Ed.tfrecord
# audioset_v1_embeddings/unbal_train/fn.tfrecord
# audioset_v1_embeddings/unbal_train/xE.tfrecord
# audioset_v1_embeddings/unbal_train/KG.tfrecord
# audioset_v1_embeddings/unbal_train/Dm.tfrecord
# audioset_v1_embeddings/unbal_train/fp.tfrecord
# audioset_v1_embeddings/unbal_train/Mc.tfrecord
# audioset_v1_embeddings/unbal_train/nM.tfrecord
# audioset_v1_embeddings/unbal_train/M1.tfrecord
# audioset_v1_embeddings/unbal_train/S2.tfrecord
# audioset_v1_embeddings/unbal_train/dg.tfrecord
# audioset_v1_embeddings/unbal_train/b_.tfrecord
# audioset_v1_embeddings/unbal_train/Ko.tfrecord
# audioset_v1_embeddings/unbal_train/vS.tfrecord
# audioset_v1_embeddings/unbal_train/qw.tfrecord
# audioset_v1_embeddings/unbal_train/cF.tfrecord
# audioset_v1_embeddings/unbal_train/tr.tfrecord
# audioset_v1_embeddings/unbal_train/eV.tfrecord
# audioset_v1_embeddings/unbal_train/C1.tfrecord
# audioset_v1_embeddings/unbal_train/za.tfrecord
# audioset_v1_embeddings/unbal_train/h-.tfrecord
# audioset_v1_embeddings/unbal_train/EO.tfrecord
# audioset_v1_embeddings/unbal_train/wh.tfrecord
# audioset_v1_embeddings/unbal_train/S_.tfrecord
# audioset_v1_embeddings/unbal_train/Pq.tfrecord
# audioset_v1_embeddings/unbal_train/JW.tfrecord
# audioset_v1_embeddings/unbal_train/iM.tfrecord
# audioset_v1_embeddings/unbal_train/Om.tfrecord
# audioset_v1_embeddings/unbal_train/iU.tfrecord
# audioset_v1_embeddings/unbal_train/jt.tfrecord
# audioset_v1_embeddings/unbal_train/Uz.tfrecord
# audioset_v1_embeddings/unbal_train/Un.tfrecord
# audioset_v1_embeddings/unbal_train/Yh.tfrecord
# audioset_v1_embeddings/unbal_train/OR.tfrecord
# audioset_v1_embeddings/unbal_train/xg.tfrecord
# audioset_v1_embeddings/unbal_train/Z5.tfrecord
# audioset_v1_embeddings/unbal_train/9b.tfrecord
# audioset_v1_embeddings/unbal_train/re.tfrecord
# audioset_v1_embeddings/unbal_train/cG.tfrecord
# audioset_v1_embeddings/unbal_train/hn.tfrecord
# audioset_v1_embeddings/unbal_train/Ez.tfrecord
# audioset_v1_embeddings/unbal_train/3v.tfrecord
# audioset_v1_embeddings/unbal_train/TX.tfrecord
# audioset_v1_embeddings/unbal_train/K4.tfrecord
# audioset_v1_embeddings/unbal_train/CH.tfrecord
# audioset_v1_embeddings/unbal_train/H8.tfrecord
# audioset_v1_embeddings/unbal_train/yd.tfrecord
# audioset_v1_embeddings/unbal_train/Bp.tfrecord
# audioset_v1_embeddings/unbal_train/Q5.tfrecord
# audioset_v1_embeddings/unbal_train/MD.tfrecord
# audioset_v1_embeddings/unbal_train/yl.tfrecord
# audioset_v1_embeddings/unbal_train/Lu.tfrecord
# audioset_v1_embeddings/unbal_train/bP.tfrecord
# audioset_v1_embeddings/unbal_train/3j.tfrecord
# audioset_v1_embeddings/unbal_train/VU.tfrecord
# audioset_v1_embeddings/unbal_train/eQ.tfrecord
# audioset_v1_embeddings/unbal_train/8X.tfrecord
# audioset_v1_embeddings/unbal_train/hP.tfrecord
# audioset_v1_embeddings/unbal_train/Ji.tfrecord
# audioset_v1_embeddings/unbal_train/dT.tfrecord
# audioset_v1_embeddings/unbal_train/NZ.tfrecord
# audioset_v1_embeddings/unbal_train/h9.tfrecord
# audioset_v1_embeddings/unbal_train/AJ.tfrecord
# audioset_v1_embeddings/unbal_train/X9.tfrecord
# audioset_v1_embeddings/unbal_train/P6.tfrecord
# audioset_v1_embeddings/unbal_train/1E.tfrecord
# audioset_v1_embeddings/unbal_train/-a.tfrecord
# audioset_v1_embeddings/unbal_train/P2.tfrecord
# audioset_v1_embeddings/unbal_train/Yf.tfrecord
# audioset_v1_embeddings/unbal_train/Rv.tfrecord
# audioset_v1_embeddings/unbal_train/JE.tfrecord
# audioset_v1_embeddings/unbal_train/jX.tfrecord
# audioset_v1_embeddings/unbal_train/dh.tfrecord
# audioset_v1_embeddings/unbal_train/yc.tfrecord
# audioset_v1_embeddings/unbal_train/Og.tfrecord
# audioset_v1_embeddings/unbal_train/5z.tfrecord
# audioset_v1_embeddings/unbal_train/Kn.tfrecord
# audioset_v1_embeddings/unbal_train/a0.tfrecord
# audioset_v1_embeddings/unbal_train/jf.tfrecord
# audioset_v1_embeddings/unbal_train/hF.tfrecord
# audioset_v1_embeddings/unbal_train/Vt.tfrecord
# audioset_v1_embeddings/unbal_train/vz.tfrecord
# audioset_v1_embeddings/unbal_train/LD.tfrecord
# audioset_v1_embeddings/unbal_train/zs.tfrecord
# audioset_v1_embeddings/unbal_train/Nz.tfrecord
# audioset_v1_embeddings/unbal_train/B2.tfrecord
# audioset_v1_embeddings/unbal_train/iL.tfrecord
# audioset_v1_embeddings/unbal_train/2L.tfrecord
# audioset_v1_embeddings/unbal_train/c7.tfrecord
# audioset_v1_embeddings/unbal_train/iF.tfrecord
# audioset_v1_embeddings/unbal_train/U3.tfrecord
# audioset_v1_embeddings/unbal_train/bH.tfrecord
# audioset_v1_embeddings/unbal_train/8r.tfrecord
# audioset_v1_embeddings/unbal_train/4B.tfrecord
# audioset_v1_embeddings/unbal_train/do.tfrecord
# audioset_v1_embeddings/unbal_train/xA.tfrecord
# audioset_v1_embeddings/unbal_train/0G.tfrecord
# audioset_v1_embeddings/unbal_train/iP.tfrecord
# audioset_v1_embeddings/unbal_train/Tl.tfrecord
# audioset_v1_embeddings/unbal_train/ez.tfrecord
# audioset_v1_embeddings/unbal_train/Cj.tfrecord
# audioset_v1_embeddings/unbal_train/E0.tfrecord
# audioset_v1_embeddings/unbal_train/xa.tfrecord
# audioset_v1_embeddings/unbal_train/dx.tfrecord
# audioset_v1_embeddings/unbal_train/u8.tfrecord
# audioset_v1_embeddings/unbal_train/LM.tfrecord
# audioset_v1_embeddings/unbal_train/Wl.tfrecord
# audioset_v1_embeddings/unbal_train/9a.tfrecord
# audioset_v1_embeddings/unbal_train/II.tfrecord
# audioset_v1_embeddings/unbal_train/36.tfrecord
# audioset_v1_embeddings/unbal_train/WA.tfrecord
# audioset_v1_embeddings/unbal_train/k1.tfrecord
# audioset_v1_embeddings/unbal_train/u9.tfrecord
# audioset_v1_embeddings/unbal_train/sE.tfrecord
# audioset_v1_embeddings/unbal_train/rq.tfrecord
# audioset_v1_embeddings/unbal_train/PY.tfrecord
# audioset_v1_embeddings/unbal_train/DH.tfrecord
# audioset_v1_embeddings/unbal_train/cY.tfrecord
# audioset_v1_embeddings/unbal_train/Hf.tfrecord
# audioset_v1_embeddings/unbal_train/l2.tfrecord
# audioset_v1_embeddings/unbal_train/mk.tfrecord
# audioset_v1_embeddings/unbal_train/l1.tfrecord
# audioset_v1_embeddings/unbal_train/_u.tfrecord
# audioset_v1_embeddings/unbal_train/at.tfrecord
# audioset_v1_embeddings/unbal_train/ZK.tfrecord
# audioset_v1_embeddings/unbal_train/av.tfrecord
# audioset_v1_embeddings/unbal_train/0u.tfrecord
# audioset_v1_embeddings/unbal_train/VG.tfrecord
# audioset_v1_embeddings/unbal_train/_J.tfrecord
# audioset_v1_embeddings/unbal_train/I1.tfrecord
# audioset_v1_embeddings/unbal_train/mT.tfrecord
# audioset_v1_embeddings/unbal_train/ut.tfrecord
# audioset_v1_embeddings/unbal_train/PI.tfrecord
# audioset_v1_embeddings/unbal_train/Fx.tfrecord
# audioset_v1_embeddings/unbal_train/HG.tfrecord
# audioset_v1_embeddings/unbal_train/Lz.tfrecord
# audioset_v1_embeddings/unbal_train/fk.tfrecord
# audioset_v1_embeddings/unbal_train/zZ.tfrecord
# audioset_v1_embeddings/unbal_train/Q2.tfrecord
# audioset_v1_embeddings/unbal_train/x-.tfrecord
# audioset_v1_embeddings/unbal_train/Rh.tfrecord
# audioset_v1_embeddings/unbal_train/tw.tfrecord
# audioset_v1_embeddings/unbal_train/Ie.tfrecord
# audioset_v1_embeddings/unbal_train/ui.tfrecord
# audioset_v1_embeddings/unbal_train/2Y.tfrecord
# audioset_v1_embeddings/unbal_train/RK.tfrecord
# audioset_v1_embeddings/unbal_train/C-.tfrecord
# audioset_v1_embeddings/unbal_train/FZ.tfrecord
# audioset_v1_embeddings/unbal_train/WF.tfrecord
# audioset_v1_embeddings/unbal_train/l6.tfrecord
# audioset_v1_embeddings/unbal_train/DK.tfrecord
# audioset_v1_embeddings/unbal_train/Bd.tfrecord
# audioset_v1_embeddings/unbal_train/J2.tfrecord
# audioset_v1_embeddings/unbal_train/VX.tfrecord
# audioset_v1_embeddings/unbal_train/LT.tfrecord
# audioset_v1_embeddings/unbal_train/53.tfrecord
# audioset_v1_embeddings/unbal_train/nb.tfrecord
# audioset_v1_embeddings/unbal_train/C6.tfrecord
# audioset_v1_embeddings/unbal_train/qT.tfrecord
# audioset_v1_embeddings/unbal_train/fg.tfrecord
# audioset_v1_embeddings/unbal_train/LF.tfrecord
# audioset_v1_embeddings/unbal_train/Af.tfrecord
# audioset_v1_embeddings/unbal_train/oc.tfrecord
# audioset_v1_embeddings/unbal_train/DG.tfrecord
# audioset_v1_embeddings/unbal_train/Kx.tfrecord
# audioset_v1_embeddings/unbal_train/bV.tfrecord
# audioset_v1_embeddings/unbal_train/yU.tfrecord
# audioset_v1_embeddings/unbal_train/k-.tfrecord
# audioset_v1_embeddings/unbal_train/1_.tfrecord
# audioset_v1_embeddings/unbal_train/iO.tfrecord
# audioset_v1_embeddings/unbal_train/Vw.tfrecord
# audioset_v1_embeddings/unbal_train/NB.tfrecord
# audioset_v1_embeddings/unbal_train/al.tfrecord
# audioset_v1_embeddings/unbal_train/cL.tfrecord
# audioset_v1_embeddings/unbal_train/lw.tfrecord
# audioset_v1_embeddings/unbal_train/-k.tfrecord
# audioset_v1_embeddings/unbal_train/zf.tfrecord
# audioset_v1_embeddings/unbal_train/T5.tfrecord
# audioset_v1_embeddings/unbal_train/5O.tfrecord
# audioset_v1_embeddings/unbal_train/Xp.tfrecord
# audioset_v1_embeddings/unbal_train/aW.tfrecord
# audioset_v1_embeddings/unbal_train/2w.tfrecord
# audioset_v1_embeddings/unbal_train/CU.tfrecord
# audioset_v1_embeddings/unbal_train/kv.tfrecord
# audioset_v1_embeddings/unbal_train/Py.tfrecord
# audioset_v1_embeddings/unbal_train/FJ.tfrecord
# audioset_v1_embeddings/unbal_train/G9.tfrecord
# audioset_v1_embeddings/unbal_train/Qm.tfrecord
# audioset_v1_embeddings/unbal_train/WN.tfrecord
# audioset_v1_embeddings/unbal_train/KN.tfrecord
# audioset_v1_embeddings/unbal_train/sJ.tfrecord
# audioset_v1_embeddings/unbal_train/_6.tfrecord
# audioset_v1_embeddings/unbal_train/-F.tfrecord
# audioset_v1_embeddings/unbal_train/yv.tfrecord
# audioset_v1_embeddings/unbal_train/sB.tfrecord
# audioset_v1_embeddings/unbal_train/Ag.tfrecord
# audioset_v1_embeddings/unbal_train/xR.tfrecord
# audioset_v1_embeddings/unbal_train/mu.tfrecord
# audioset_v1_embeddings/unbal_train/OW.tfrecord
# audioset_v1_embeddings/unbal_train/mF.tfrecord
# audioset_v1_embeddings/unbal_train/0Y.tfrecord
# audioset_v1_embeddings/unbal_train/Hp.tfrecord
# audioset_v1_embeddings/unbal_train/H2.tfrecord
# audioset_v1_embeddings/unbal_train/JF.tfrecord
# audioset_v1_embeddings/unbal_train/5_.tfrecord
# audioset_v1_embeddings/unbal_train/Sx.tfrecord
# audioset_v1_embeddings/unbal_train/va.tfrecord
# audioset_v1_embeddings/unbal_train/HX.tfrecord
# audioset_v1_embeddings/unbal_train/Q3.tfrecord
# audioset_v1_embeddings/unbal_train/oS.tfrecord
# audioset_v1_embeddings/unbal_train/_4.tfrecord
# audioset_v1_embeddings/unbal_train/Cy.tfrecord
# audioset_v1_embeddings/unbal_train/45.tfrecord
# audioset_v1_embeddings/unbal_train/Fa.tfrecord
# audioset_v1_embeddings/unbal_train/qF.tfrecord
# audioset_v1_embeddings/unbal_train/3P.tfrecord
# audioset_v1_embeddings/unbal_train/0o.tfrecord
# audioset_v1_embeddings/unbal_train/8o.tfrecord
# audioset_v1_embeddings/unbal_train/vC.tfrecord
# audioset_v1_embeddings/unbal_train/ri.tfrecord
# audioset_v1_embeddings/unbal_train/jy.tfrecord
# audioset_v1_embeddings/unbal_train/lh.tfrecord
# audioset_v1_embeddings/unbal_train/Tr.tfrecord
# audioset_v1_embeddings/unbal_train/Jh.tfrecord
# audioset_v1_embeddings/unbal_train/6J.tfrecord
# audioset_v1_embeddings/unbal_train/HC.tfrecord
# audioset_v1_embeddings/unbal_train/Rd.tfrecord
# audioset_v1_embeddings/unbal_train/F1.tfrecord
# audioset_v1_embeddings/unbal_train/mC.tfrecord
# audioset_v1_embeddings/unbal_train/de.tfrecord
# audioset_v1_embeddings/unbal_train/-S.tfrecord
# audioset_v1_embeddings/unbal_train/SP.tfrecord
# audioset_v1_embeddings/unbal_train/XX.tfrecord
# audioset_v1_embeddings/unbal_train/07.tfrecord
# audioset_v1_embeddings/unbal_train/Lt.tfrecord
# audioset_v1_embeddings/unbal_train/lt.tfrecord
# audioset_v1_embeddings/unbal_train/bG.tfrecord
# audioset_v1_embeddings/unbal_train/fz.tfrecord
# audioset_v1_embeddings/unbal_train/4_.tfrecord
# audioset_v1_embeddings/unbal_train/p_.tfrecord
# audioset_v1_embeddings/unbal_train/Tg.tfrecord
# audioset_v1_embeddings/unbal_train/LJ.tfrecord
# audioset_v1_embeddings/unbal_train/gH.tfrecord
# audioset_v1_embeddings/unbal_train/d7.tfrecord
# audioset_v1_embeddings/unbal_train/Hz.tfrecord
# audioset_v1_embeddings/unbal_train/jP.tfrecord
# audioset_v1_embeddings/unbal_train/Wt.tfrecord
# audioset_v1_embeddings/unbal_train/3e.tfrecord
# audioset_v1_embeddings/unbal_train/Ne.tfrecord
# audioset_v1_embeddings/unbal_train/5N.tfrecord
# audioset_v1_embeddings/unbal_train/oC.tfrecord
# audioset_v1_embeddings/unbal_train/O8.tfrecord
# audioset_v1_embeddings/unbal_train/kD.tfrecord
# audioset_v1_embeddings/unbal_train/Rq.tfrecord
# audioset_v1_embeddings/unbal_train/0S.tfrecord
# audioset_v1_embeddings/unbal_train/9E.tfrecord
# audioset_v1_embeddings/unbal_train/Gr.tfrecord
# audioset_v1_embeddings/unbal_train/ol.tfrecord
# audioset_v1_embeddings/unbal_train/IC.tfrecord
# audioset_v1_embeddings/unbal_train/9v.tfrecord
# audioset_v1_embeddings/unbal_train/96.tfrecord
# audioset_v1_embeddings/unbal_train/Kd.tfrecord
# audioset_v1_embeddings/unbal_train/w0.tfrecord
# audioset_v1_embeddings/unbal_train/Y_.tfrecord
# audioset_v1_embeddings/unbal_train/Mz.tfrecord
# audioset_v1_embeddings/unbal_train/K2.tfrecord
# audioset_v1_embeddings/unbal_train/te.tfrecord
# audioset_v1_embeddings/unbal_train/NA.tfrecord
# audioset_v1_embeddings/unbal_train/FM.tfrecord
# audioset_v1_embeddings/unbal_train/cd.tfrecord
# audioset_v1_embeddings/unbal_train/03.tfrecord
# audioset_v1_embeddings/unbal_train/Ae.tfrecord
# audioset_v1_embeddings/unbal_train/cy.tfrecord
# audioset_v1_embeddings/unbal_train/MC.tfrecord
# audioset_v1_embeddings/unbal_train/bS.tfrecord
# audioset_v1_embeddings/unbal_train/wX.tfrecord
# audioset_v1_embeddings/unbal_train/Q1.tfrecord
# audioset_v1_embeddings/unbal_train/Ra.tfrecord
# audioset_v1_embeddings/unbal_train/G-.tfrecord
# audioset_v1_embeddings/unbal_train/li.tfrecord
# audioset_v1_embeddings/unbal_train/-B.tfrecord
# audioset_v1_embeddings/unbal_train/lr.tfrecord
# audioset_v1_embeddings/unbal_train/mt.tfrecord
# audioset_v1_embeddings/unbal_train/A8.tfrecord
# audioset_v1_embeddings/unbal_train/0-.tfrecord
# audioset_v1_embeddings/unbal_train/q7.tfrecord
# audioset_v1_embeddings/unbal_train/Do.tfrecord
# audioset_v1_embeddings/unbal_train/e4.tfrecord
# audioset_v1_embeddings/unbal_train/x5.tfrecord
# audioset_v1_embeddings/unbal_train/fr.tfrecord
# audioset_v1_embeddings/unbal_train/HP.tfrecord
# audioset_v1_embeddings/unbal_train/4C.tfrecord
# audioset_v1_embeddings/unbal_train/2f.tfrecord
# audioset_v1_embeddings/unbal_train/i5.tfrecord
# audioset_v1_embeddings/unbal_train/UL.tfrecord
# audioset_v1_embeddings/unbal_train/ip.tfrecord
# audioset_v1_embeddings/unbal_train/A9.tfrecord
# audioset_v1_embeddings/unbal_train/q_.tfrecord
# audioset_v1_embeddings/unbal_train/5Q.tfrecord
# audioset_v1_embeddings/unbal_train/LP.tfrecord
# audioset_v1_embeddings/unbal_train/cQ.tfrecord
# audioset_v1_embeddings/unbal_train/Yg.tfrecord
# audioset_v1_embeddings/unbal_train/Mr.tfrecord
# audioset_v1_embeddings/unbal_train/Y9.tfrecord
# audioset_v1_embeddings/unbal_train/As.tfrecord
# audioset_v1_embeddings/unbal_train/RZ.tfrecord
# audioset_v1_embeddings/unbal_train/bY.tfrecord
# audioset_v1_embeddings/unbal_train/vn.tfrecord
# audioset_v1_embeddings/unbal_train/j5.tfrecord
# audioset_v1_embeddings/unbal_train/-m.tfrecord
# audioset_v1_embeddings/unbal_train/m5.tfrecord
# audioset_v1_embeddings/unbal_train/bL.tfrecord
# audioset_v1_embeddings/unbal_train/1L.tfrecord
# audioset_v1_embeddings/unbal_train/sC.tfrecord
# audioset_v1_embeddings/unbal_train/-5.tfrecord
# audioset_v1_embeddings/unbal_train/I9.tfrecord
# audioset_v1_embeddings/unbal_train/XB.tfrecord
# audioset_v1_embeddings/unbal_train/wI.tfrecord
# audioset_v1_embeddings/unbal_train/gL.tfrecord
# audioset_v1_embeddings/unbal_train/cv.tfrecord
# audioset_v1_embeddings/unbal_train/gy.tfrecord
# audioset_v1_embeddings/unbal_train/mh.tfrecord
# audioset_v1_embeddings/unbal_train/t-.tfrecord
# audioset_v1_embeddings/unbal_train/Oq.tfrecord
# audioset_v1_embeddings/unbal_train/2l.tfrecord
# audioset_v1_embeddings/unbal_train/Nj.tfrecord
# audioset_v1_embeddings/unbal_train/kV.tfrecord
# audioset_v1_embeddings/unbal_train/TA.tfrecord
# audioset_v1_embeddings/unbal_train/jY.tfrecord
# audioset_v1_embeddings/unbal_train/PM.tfrecord
# audioset_v1_embeddings/unbal_train/9h.tfrecord
# audioset_v1_embeddings/unbal_train/S7.tfrecord
# audioset_v1_embeddings/unbal_train/a6.tfrecord
# audioset_v1_embeddings/unbal_train/EF.tfrecord
# audioset_v1_embeddings/unbal_train/n0.tfrecord
# audioset_v1_embeddings/unbal_train/jM.tfrecord
# audioset_v1_embeddings/unbal_train/Eg.tfrecord
# audioset_v1_embeddings/unbal_train/UE.tfrecord
# audioset_v1_embeddings/unbal_train/aR.tfrecord
# audioset_v1_embeddings/unbal_train/z5.tfrecord
# audioset_v1_embeddings/unbal_train/UI.tfrecord
# audioset_v1_embeddings/unbal_train/Ng.tfrecord
# audioset_v1_embeddings/unbal_train/dZ.tfrecord
# audioset_v1_embeddings/unbal_train/eS.tfrecord
# audioset_v1_embeddings/unbal_train/l0.tfrecord
# audioset_v1_embeddings/unbal_train/qS.tfrecord
# audioset_v1_embeddings/unbal_train/g5.tfrecord
# audioset_v1_embeddings/unbal_train/NW.tfrecord
# audioset_v1_embeddings/unbal_train/3z.tfrecord
# audioset_v1_embeddings/unbal_train/Yu.tfrecord
# audioset_v1_embeddings/unbal_train/rQ.tfrecord
# audioset_v1_embeddings/unbal_train/0z.tfrecord
# audioset_v1_embeddings/unbal_train/ux.tfrecord
# audioset_v1_embeddings/unbal_train/Ud.tfrecord
# audioset_v1_embeddings/unbal_train/Ax.tfrecord
# audioset_v1_embeddings/unbal_train/Dx.tfrecord
# audioset_v1_embeddings/unbal_train/_-.tfrecord
# audioset_v1_embeddings/unbal_train/tt.tfrecord
# audioset_v1_embeddings/unbal_train/Sv.tfrecord
# audioset_v1_embeddings/unbal_train/H7.tfrecord
# audioset_v1_embeddings/unbal_train/Pz.tfrecord
# audioset_v1_embeddings/unbal_train/rv.tfrecord
# audioset_v1_embeddings/unbal_train/BP.tfrecord
# audioset_v1_embeddings/unbal_train/en.tfrecord
# audioset_v1_embeddings/unbal_train/um.tfrecord
# audioset_v1_embeddings/unbal_train/_l.tfrecord
# audioset_v1_embeddings/unbal_train/dz.tfrecord
# audioset_v1_embeddings/unbal_train/Fn.tfrecord
# audioset_v1_embeddings/unbal_train/kq.tfrecord
# audioset_v1_embeddings/unbal_train/t1.tfrecord
# audioset_v1_embeddings/unbal_train/7e.tfrecord
# audioset_v1_embeddings/unbal_train/DW.tfrecord
# audioset_v1_embeddings/unbal_train/X-.tfrecord
# audioset_v1_embeddings/unbal_train/rx.tfrecord
# audioset_v1_embeddings/unbal_train/D3.tfrecord
# audioset_v1_embeddings/unbal_train/iE.tfrecord
# audioset_v1_embeddings/unbal_train/dy.tfrecord
# audioset_v1_embeddings/unbal_train/nE.tfrecord
# audioset_v1_embeddings/unbal_train/-z.tfrecord
# audioset_v1_embeddings/unbal_train/ML.tfrecord
# audioset_v1_embeddings/unbal_train/3E.tfrecord
# audioset_v1_embeddings/unbal_train/Qn.tfrecord
# audioset_v1_embeddings/unbal_train/PX.tfrecord
# audioset_v1_embeddings/unbal_train/ef.tfrecord
# audioset_v1_embeddings/unbal_train/2t.tfrecord
# audioset_v1_embeddings/unbal_train/v8.tfrecord
# audioset_v1_embeddings/unbal_train/mR.tfrecord
# audioset_v1_embeddings/unbal_train/J3.tfrecord
# audioset_v1_embeddings/unbal_train/uF.tfrecord
# audioset_v1_embeddings/unbal_train/MU.tfrecord
# audioset_v1_embeddings/unbal_train/OX.tfrecord
# audioset_v1_embeddings/unbal_train/G8.tfrecord
# audioset_v1_embeddings/unbal_train/sb.tfrecord
# audioset_v1_embeddings/unbal_train/qQ.tfrecord
# audioset_v1_embeddings/unbal_train/JA.tfrecord
# audioset_v1_embeddings/unbal_train/sD.tfrecord
# audioset_v1_embeddings/unbal_train/mo.tfrecord
# audioset_v1_embeddings/unbal_train/i2.tfrecord
# audioset_v1_embeddings/unbal_train/s5.tfrecord
# audioset_v1_embeddings/unbal_train/T1.tfrecord
# audioset_v1_embeddings/unbal_train/g8.tfrecord
# audioset_v1_embeddings/unbal_train/Wn.tfrecord
# ...
# audioset_v1_embeddings/unbal_train/ZL.tfrecord
# audioset_v1_embeddings/unbal_train/EN.tfrecord
# audioset_v1_embeddings/unbal_train/ll.tfrecord
# audioset_v1_embeddings/unbal_train/Am.tfrecord
# audioset_v1_embeddings/unbal_train/4k.tfrecord
# audioset_v1_embeddings/unbal_train/Fc.tfrecord
# audioset_v1_embeddings/unbal_train/Nq.tfrecord
# audioset_v1_embeddings/unbal_train/nD.tfrecord
# audioset_v1_embeddings/unbal_train/hW.tfrecord
# audioset_v1_embeddings/unbal_train/pe.tfrecord
# audioset_v1_embeddings/unbal_train/K_.tfrecord
# audioset_v1_embeddings/unbal_train/CK.tfrecord
# audioset_v1_embeddings/unbal_train/IV.tfrecord
# audioset_v1_embeddings/unbal_train/oK.tfrecord
# audioset_v1_embeddings/unbal_train/Qv.tfrecord
# audioset_v1_embeddings/unbal_train/hG.tfrecord
# audioset_v1_embeddings/unbal_train/eJ.tfrecord
# audioset_v1_embeddings/unbal_train/se.tfrecord
# audioset_v1_embeddings/unbal_train/Ik.tfrecord
# audioset_v1_embeddings/unbal_train/OC.tfrecord
# audioset_v1_embeddings/unbal_train/_1.tfrecord
# audioset_v1_embeddings/unbal_train/mO.tfrecord
# audioset_v1_embeddings/unbal_train/HA.tfrecord
# audioset_v1_embeddings/unbal_train/WH.tfrecord
# audioset_v1_embeddings/unbal_train/2s.tfrecord
# audioset_v1_embeddings/unbal_train/GU.tfrecord
# audioset_v1_embeddings/unbal_train/fu.tfrecord
# audioset_v1_embeddings/unbal_train/41.tfrecord
# audioset_v1_embeddings/unbal_train/pq.tfrecord
# audioset_v1_embeddings/unbal_train/bD.tfrecord
# audioset_v1_embeddings/unbal_train/er.tfrecord
# audioset_v1_embeddings/unbal_train/lg.tfrecord
# audioset_v1_embeddings/unbal_train/Jv.tfrecord
# audioset_v1_embeddings/unbal_train/85.tfrecord
# audioset_v1_embeddings/unbal_train/zX.tfrecord
# audioset_v1_embeddings/unbal_train/5g.tfrecord
# audioset_v1_embeddings/unbal_train/GZ.tfrecord
# audioset_v1_embeddings/unbal_train/7s.tfrecord
# audioset_v1_embeddings/unbal_train/qf.tfrecord
# audioset_v1_embeddings/unbal_train/yn.tfrecord
# audioset_v1_embeddings/unbal_train/fC.tfrecord
# audioset_v1_embeddings/unbal_train/kG.tfrecord
# audioset_v1_embeddings/unbal_train/vJ.tfrecord
# audioset_v1_embeddings/unbal_train/S5.tfrecord
# audioset_v1_embeddings/unbal_train/Ia.tfrecord
# audioset_v1_embeddings/unbal_train/KR.tfrecord
# audioset_v1_embeddings/unbal_train/DN.tfrecord
# audioset_v1_embeddings/unbal_train/Bu.tfrecord
# audioset_v1_embeddings/unbal_train/ng.tfrecord
# audioset_v1_embeddings/unbal_train/_K.tfrecord
# audioset_v1_embeddings/unbal_train/RI.tfrecord
# audioset_v1_embeddings/unbal_train/jH.tfrecord
# audioset_v1_embeddings/unbal_train/BL.tfrecord
# audioset_v1_embeddings/unbal_train/6u.tfrecord
# audioset_v1_embeddings/unbal_train/KC.tfrecord
# audioset_v1_embeddings/unbal_train/Ru.tfrecord
# audioset_v1_embeddings/unbal_train/jU.tfrecord
# audioset_v1_embeddings/unbal_train/zS.tfrecord
# audioset_v1_embeddings/unbal_train/-v.tfrecord
# audioset_v1_embeddings/unbal_train/To.tfrecord
# audioset_v1_embeddings/unbal_train/wE.tfrecord
# audioset_v1_embeddings/unbal_train/Ai.tfrecord
# audioset_v1_embeddings/unbal_train/Wr.tfrecord
# audioset_v1_embeddings/unbal_train/Ze.tfrecord
# audioset_v1_embeddings/unbal_train/3M.tfrecord
# audioset_v1_embeddings/unbal_train/ig.tfrecord
# audioset_v1_embeddings/unbal_train/LY.tfrecord
# audioset_v1_embeddings/unbal_train/5t.tfrecord
# audioset_v1_embeddings/unbal_train/YX.tfrecord
# audioset_v1_embeddings/unbal_train/tI.tfrecord
# audioset_v1_embeddings/unbal_train/c9.tfrecord
# audioset_v1_embeddings/unbal_train/Xh.tfrecord
# audioset_v1_embeddings/unbal_train/Mq.tfrecord
# audioset_v1_embeddings/unbal_train/zC.tfrecord
# audioset_v1_embeddings/unbal_train/zW.tfrecord
# audioset_v1_embeddings/unbal_train/sv.tfrecord
# audioset_v1_embeddings/unbal_train/M4.tfrecord
# audioset_v1_embeddings/unbal_train/pc.tfrecord
# audioset_v1_embeddings/unbal_train/Ja.tfrecord
# audioset_v1_embeddings/unbal_train/Ip.tfrecord
# audioset_v1_embeddings/unbal_train/2I.tfrecord
# audioset_v1_embeddings/unbal_train/A0.tfrecord
# audioset_v1_embeddings/unbal_train/C9.tfrecord
# audioset_v1_embeddings/unbal_train/Lh.tfrecord
# audioset_v1_embeddings/unbal_train/Pp.tfrecord
# audioset_v1_embeddings/unbal_train/9F.tfrecord
# audioset_v1_embeddings/unbal_train/5s.tfrecord
# audioset_v1_embeddings/unbal_train/Tm.tfrecord
# audioset_v1_embeddings/unbal_train/QD.tfrecord
# audioset_v1_embeddings/unbal_train/YJ.tfrecord
# audioset_v1_embeddings/unbal_train/UD.tfrecord
# audioset_v1_embeddings/unbal_train/e_.tfrecord
# audioset_v1_embeddings/unbal_train/xn.tfrecord
# audioset_v1_embeddings/unbal_train/E7.tfrecord
# audioset_v1_embeddings/unbal_train/ia.tfrecord
# audioset_v1_embeddings/unbal_train/QU.tfrecord
# audioset_v1_embeddings/unbal_train/Dp.tfrecord
# audioset_v1_embeddings/unbal_train/np.tfrecord
# audioset_v1_embeddings/unbal_train/fI.tfrecord
# audioset_v1_embeddings/unbal_train/mH.tfrecord
# audioset_v1_embeddings/unbal_train/hQ.tfrecord
# audioset_v1_embeddings/unbal_train/XK.tfrecord
# audioset_v1_embeddings/unbal_train/FW.tfrecord
# audioset_v1_embeddings/unbal_train/L0.tfrecord
# audioset_v1_embeddings/unbal_train/pL.tfrecord
# audioset_v1_embeddings/unbal_train/PF.tfrecord
# audioset_v1_embeddings/unbal_train/uD.tfrecord
# audioset_v1_embeddings/unbal_train/cI.tfrecord
# audioset_v1_embeddings/unbal_train/8O.tfrecord
# audioset_v1_embeddings/unbal_train/fc.tfrecord
# audioset_v1_embeddings/unbal_train/wb.tfrecord
# audioset_v1_embeddings/unbal_train/s8.tfrecord
# audioset_v1_embeddings/unbal_train/Rn.tfrecord
# audioset_v1_embeddings/unbal_train/zL.tfrecord
# audioset_v1_embeddings/unbal_train/Ah.tfrecord
# audioset_v1_embeddings/unbal_train/2_.tfrecord
# audioset_v1_embeddings/unbal_train/iA.tfrecord
# audioset_v1_embeddings/unbal_train/mW.tfrecord
# audioset_v1_embeddings/unbal_train/F3.tfrecord
# audioset_v1_embeddings/unbal_train/2R.tfrecord
# audioset_v1_embeddings/unbal_train/Rj.tfrecord
# audioset_v1_embeddings/unbal_train/xP.tfrecord
# audioset_v1_embeddings/unbal_train/eB.tfrecord
# audioset_v1_embeddings/unbal_train/Ox.tfrecord
# audioset_v1_embeddings/unbal_train/L4.tfrecord
# audioset_v1_embeddings/unbal_train/PL.tfrecord
# audioset_v1_embeddings/unbal_train/rk.tfrecord
# audioset_v1_embeddings/unbal_train/jR.tfrecord
# audioset_v1_embeddings/unbal_train/hc.tfrecord
# audioset_v1_embeddings/unbal_train/nx.tfrecord
# audioset_v1_embeddings/unbal_train/Ka.tfrecord
# audioset_v1_embeddings/unbal_train/di.tfrecord
# audioset_v1_embeddings/unbal_train/2K.tfrecord
# audioset_v1_embeddings/unbal_train/6v.tfrecord
# audioset_v1_embeddings/unbal_train/Z2.tfrecord
# audioset_v1_embeddings/unbal_train/o7.tfrecord
# audioset_v1_embeddings/unbal_train/pT.tfrecord
# audioset_v1_embeddings/unbal_train/5S.tfrecord
# audioset_v1_embeddings/unbal_train/yr.tfrecord
# audioset_v1_embeddings/unbal_train/Pd.tfrecord
# audioset_v1_embeddings/unbal_train/d_.tfrecord
# audioset_v1_embeddings/unbal_train/P1.tfrecord
# audioset_v1_embeddings/unbal_train/HT.tfrecord
# audioset_v1_embeddings/unbal_train/fb.tfrecord
# audioset_v1_embeddings/unbal_train/k9.tfrecord
# audioset_v1_embeddings/unbal_train/Kk.tfrecord
# audioset_v1_embeddings/unbal_train/Q_.tfrecord
# audioset_v1_embeddings/unbal_train/6F.tfrecord
# audioset_v1_embeddings/unbal_train/iR.tfrecord
# audioset_v1_embeddings/unbal_train/gw.tfrecord
# audioset_v1_embeddings/unbal_train/8A.tfrecord
# audioset_v1_embeddings/unbal_train/ot.tfrecord
# audioset_v1_embeddings/unbal_train/ZH.tfrecord
# audioset_v1_embeddings/unbal_train/7o.tfrecord
# audioset_v1_embeddings/unbal_train/0f.tfrecord
# audioset_v1_embeddings/unbal_train/aI.tfrecord
# audioset_v1_embeddings/unbal_train/kp.tfrecord
# audioset_v1_embeddings/unbal_train/1l.tfrecord
# audioset_v1_embeddings/unbal_train/AD.tfrecord
# audioset_v1_embeddings/unbal_train/fL.tfrecord
# audioset_v1_embeddings/unbal_train/IM.tfrecord
# audioset_v1_embeddings/unbal_train/_B.tfrecord
# audioset_v1_embeddings/unbal_train/Nn.tfrecord
# audioset_v1_embeddings/unbal_train/oe.tfrecord
# audioset_v1_embeddings/unbal_train/Zh.tfrecord
# audioset_v1_embeddings/unbal_train/Zc.tfrecord
# audioset_v1_embeddings/unbal_train/Go.tfrecord
# audioset_v1_embeddings/unbal_train/Fw.tfrecord
# audioset_v1_embeddings/unbal_train/_i.tfrecord
# audioset_v1_embeddings/unbal_train/6n.tfrecord
# audioset_v1_embeddings/unbal_train/DM.tfrecord
# audioset_v1_embeddings/unbal_train/P5.tfrecord
# audioset_v1_embeddings/unbal_train/7Z.tfrecord
# audioset_v1_embeddings/unbal_train/hE.tfrecord
# audioset_v1_embeddings/unbal_train/M8.tfrecord
# audioset_v1_embeddings/unbal_train/WD.tfrecord
# audioset_v1_embeddings/unbal_train/lS.tfrecord
# audioset_v1_embeddings/unbal_train/Kg.tfrecord
# audioset_v1_embeddings/unbal_train/1M.tfrecord
# audioset_v1_embeddings/unbal_train/Sl.tfrecord
# audioset_v1_embeddings/unbal_train/x8.tfrecord
# audioset_v1_embeddings/unbal_train/K9.tfrecord
# audioset_v1_embeddings/unbal_train/L5.tfrecord
# audioset_v1_embeddings/unbal_train/TP.tfrecord
# audioset_v1_embeddings/unbal_train/Js.tfrecord
# audioset_v1_embeddings/unbal_train/wx.tfrecord
# audioset_v1_embeddings/unbal_train/bs.tfrecord
# audioset_v1_embeddings/unbal_train/kw.tfrecord
# audioset_v1_embeddings/unbal_train/2q.tfrecord
# audioset_v1_embeddings/unbal_train/Cf.tfrecord
# audioset_v1_embeddings/unbal_train/lJ.tfrecord
# audioset_v1_embeddings/unbal_train/Uw.tfrecord
# audioset_v1_embeddings/unbal_train/tF.tfrecord
# audioset_v1_embeddings/unbal_train/_h.tfrecord
# audioset_v1_embeddings/unbal_train/UB.tfrecord
# audioset_v1_embeddings/unbal_train/40.tfrecord
# audioset_v1_embeddings/unbal_train/zQ.tfrecord
# audioset_v1_embeddings/unbal_train/-w.tfrecord
# audioset_v1_embeddings/unbal_train/83.tfrecord
# audioset_v1_embeddings/unbal_train/gE.tfrecord
# audioset_v1_embeddings/unbal_train/7M.tfrecord
# audioset_v1_embeddings/unbal_train/O0.tfrecord
# audioset_v1_embeddings/unbal_train/oH.tfrecord
# audioset_v1_embeddings/unbal_train/Os.tfrecord
# audioset_v1_embeddings/unbal_train/pi.tfrecord
# audioset_v1_embeddings/unbal_train/tC.tfrecord
# audioset_v1_embeddings/unbal_train/WT.tfrecord
# audioset_v1_embeddings/unbal_train/-j.tfrecord
# audioset_v1_embeddings/unbal_train/98.tfrecord
# audioset_v1_embeddings/unbal_train/FB.tfrecord
# audioset_v1_embeddings/unbal_train/Zf.tfrecord
# audioset_v1_embeddings/unbal_train/si.tfrecord
# audioset_v1_embeddings/unbal_train/rt.tfrecord
# audioset_v1_embeddings/unbal_train/GT.tfrecord
# audioset_v1_embeddings/unbal_train/u-.tfrecord
# audioset_v1_embeddings/unbal_train/31.tfrecord
# audioset_v1_embeddings/unbal_train/pz.tfrecord
# audioset_v1_embeddings/unbal_train/oF.tfrecord
# audioset_v1_embeddings/unbal_train/s9.tfrecord
# audioset_v1_embeddings/unbal_train/BM.tfrecord
# audioset_v1_embeddings/unbal_train/2P.tfrecord
# audioset_v1_embeddings/unbal_train/hf.tfrecord
# audioset_v1_embeddings/unbal_train/EK.tfrecord
# audioset_v1_embeddings/unbal_train/zn.tfrecord
# audioset_v1_embeddings/unbal_train/FA.tfrecord
# audioset_v1_embeddings/unbal_train/8D.tfrecord
# audioset_v1_embeddings/unbal_train/eE.tfrecord
# audioset_v1_embeddings/unbal_train/Hd.tfrecord
# audioset_v1_embeddings/unbal_train/t3.tfrecord
# audioset_v1_embeddings/unbal_train/Kh.tfrecord
# audioset_v1_embeddings/unbal_train/8d.tfrecord
# audioset_v1_embeddings/unbal_train/zl.tfrecord
# audioset_v1_embeddings/unbal_train/Nl.tfrecord
# audioset_v1_embeddings/unbal_train/4e.tfrecord
# audioset_v1_embeddings/unbal_train/vZ.tfrecord
# audioset_v1_embeddings/unbal_train/bh.tfrecord
# audioset_v1_embeddings/unbal_train/Cs.tfrecord
# audioset_v1_embeddings/unbal_train/KZ.tfrecord
# audioset_v1_embeddings/unbal_train/2O.tfrecord
# audioset_v1_embeddings/unbal_train/Uc.tfrecord
# audioset_v1_embeddings/unbal_train/uq.tfrecord
# audioset_v1_embeddings/unbal_train/7B.tfrecord
# audioset_v1_embeddings/unbal_train/LX.tfrecord
# audioset_v1_embeddings/unbal_train/Y-.tfrecord
# audioset_v1_embeddings/unbal_train/rA.tfrecord
# audioset_v1_embeddings/unbal_train/F2.tfrecord
# audioset_v1_embeddings/unbal_train/RH.tfrecord
# audioset_v1_embeddings/unbal_train/_M.tfrecord
# audioset_v1_embeddings/unbal_train/pH.tfrecord
# audioset_v1_embeddings/unbal_train/uS.tfrecord
# audioset_v1_embeddings/unbal_train/Es.tfrecord
# audioset_v1_embeddings/unbal_train/F7.tfrecord
# audioset_v1_embeddings/unbal_train/KK.tfrecord
# audioset_v1_embeddings/unbal_train/aY.tfrecord
# audioset_v1_embeddings/unbal_train/_m.tfrecord
# audioset_v1_embeddings/unbal_train/4V.tfrecord
# audioset_v1_embeddings/unbal_train/-G.tfrecord
# audioset_v1_embeddings/unbal_train/w9.tfrecord
# audioset_v1_embeddings/unbal_train/20.tfrecord
# audioset_v1_embeddings/unbal_train/4v.tfrecord
# audioset_v1_embeddings/unbal_train/3W.tfrecord
# audioset_v1_embeddings/unbal_train/ZM.tfrecord
# audioset_v1_embeddings/unbal_train/BH.tfrecord
# audioset_v1_embeddings/unbal_train/jF.tfrecord
# audioset_v1_embeddings/unbal_train/-6.tfrecord
# audioset_v1_embeddings/unbal_train/4E.tfrecord
# audioset_v1_embeddings/unbal_train/W4.tfrecord
# audioset_v1_embeddings/unbal_train/zx.tfrecord
# audioset_v1_embeddings/unbal_train/tZ.tfrecord
# audioset_v1_embeddings/unbal_train/y6.tfrecord
# audioset_v1_embeddings/unbal_train/bz.tfrecord
# audioset_v1_embeddings/unbal_train/zz.tfrecord
# audioset_v1_embeddings/unbal_train/Tw.tfrecord
# audioset_v1_embeddings/unbal_train/0l.tfrecord
# audioset_v1_embeddings/unbal_train/Yw.tfrecord
# audioset_v1_embeddings/unbal_train/kP.tfrecord
# audioset_v1_embeddings/unbal_train/MZ.tfrecord
# audioset_v1_embeddings/unbal_train/zo.tfrecord
# audioset_v1_embeddings/unbal_train/NP.tfrecord
# audioset_v1_embeddings/unbal_train/p2.tfrecord
# audioset_v1_embeddings/unbal_train/Wd.tfrecord
# audioset_v1_embeddings/unbal_train/Hw.tfrecord
# audioset_v1_embeddings/unbal_train/gz.tfrecord
# audioset_v1_embeddings/unbal_train/29.tfrecord
# audioset_v1_embeddings/unbal_train/G_.tfrecord
# audioset_v1_embeddings/unbal_train/T2.tfrecord
# audioset_v1_embeddings/unbal_train/Nb.tfrecord
# audioset_v1_embeddings/unbal_train/i6.tfrecord
# audioset_v1_embeddings/unbal_train/fA.tfrecord
# audioset_v1_embeddings/unbal_train/lv.tfrecord
# audioset_v1_embeddings/unbal_train/3h.tfrecord
# audioset_v1_embeddings/unbal_train/tx.tfrecord
# audioset_v1_embeddings/unbal_train/UF.tfrecord
# audioset_v1_embeddings/unbal_train/QJ.tfrecord
# audioset_v1_embeddings/unbal_train/Q9.tfrecord
# audioset_v1_embeddings/unbal_train/9u.tfrecord
# audioset_v1_embeddings/unbal_train/4Q.tfrecord
# audioset_v1_embeddings/unbal_train/1O.tfrecord
# audioset_v1_embeddings/unbal_train/47.tfrecord
# audioset_v1_embeddings/unbal_train/vq.tfrecord
# audioset_v1_embeddings/unbal_train/V9.tfrecord
# audioset_v1_embeddings/unbal_train/D9.tfrecord
# audioset_v1_embeddings/unbal_train/bt.tfrecord
# audioset_v1_embeddings/unbal_train/W5.tfrecord
# audioset_v1_embeddings/unbal_train/5U.tfrecord
# audioset_v1_embeddings/unbal_train/wr.tfrecord
# audioset_v1_embeddings/unbal_train/O6.tfrecord
# audioset_v1_embeddings/unbal_train/3o.tfrecord
# audioset_v1_embeddings/unbal_train/Um.tfrecord
# audioset_v1_embeddings/unbal_train/-c.tfrecord
# audioset_v1_embeddings/unbal_train/0p.tfrecord
# audioset_v1_embeddings/unbal_train/pQ.tfrecord
# audioset_v1_embeddings/unbal_train/rG.tfrecord
# audioset_v1_embeddings/unbal_train/tM.tfrecord
# audioset_v1_embeddings/unbal_train/Rm.tfrecord
# audioset_v1_embeddings/unbal_train/C7.tfrecord
# audioset_v1_embeddings/unbal_train/c3.tfrecord
# audioset_v1_embeddings/unbal_train/cs.tfrecord
# audioset_v1_embeddings/unbal_train/4K.tfrecord
# audioset_v1_embeddings/unbal_train/pG.tfrecord
# audioset_v1_embeddings/unbal_train/iw.tfrecord
# audioset_v1_embeddings/unbal_train/OS.tfrecord
# audioset_v1_embeddings/unbal_train/Dn.tfrecord
# audioset_v1_embeddings/unbal_train/Qo.tfrecord
# audioset_v1_embeddings/unbal_train/Br.tfrecord
# audioset_v1_embeddings/unbal_train/18.tfrecord
# audioset_v1_embeddings/unbal_train/Mj.tfrecord
# audioset_v1_embeddings/unbal_train/kz.tfrecord
# audioset_v1_embeddings/unbal_train/xz.tfrecord
# audioset_v1_embeddings/unbal_train/aD.tfrecord
# audioset_v1_embeddings/unbal_train/xr.tfrecord
# audioset_v1_embeddings/unbal_train/1b.tfrecord
# audioset_v1_embeddings/unbal_train/Tv.tfrecord
# audioset_v1_embeddings/unbal_train/QT.tfrecord
# audioset_v1_embeddings/unbal_train/ZJ.tfrecord
# audioset_v1_embeddings/unbal_train/zR.tfrecord
# audioset_v1_embeddings/unbal_train/b6.tfrecord
# audioset_v1_embeddings/unbal_train/oL.tfrecord
# audioset_v1_embeddings/unbal_train/9S.tfrecord
# audioset_v1_embeddings/unbal_train/uG.tfrecord

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import pandas as pd
import glob

# %% [markdown]
# In order to run this on a linux machine, I used this notebook in [Google Colaboratory](https://colab.research.google.com/)
# The following cells are for the uploading of necessary files to the colab instance.
# If you are running this locally, you can skip this section

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-bde7d9ed-f33a-4fc9-96c6-4058fcb77a9f" name="files[]" multiple disabled />
#      <output id="result-bde7d9ed-f33a-4fc9-96c6-4058fcb77a9f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
for k,v in uploaded.items():
  with open(k,'wb') as f:
    f.write(v)

# %%
uploaded.keys()
# Out:
# dict_keys([])

# %% [markdown]
# Here is where the laughter and not laughter labels are loaded from local .csv files.
# If you want to create a subset using a different category of labels, create new files containing a list of the labels you want to select as your positive and negative classes. You can find a list of all the Audioset labels [here](class_labels_indices.csv)

# %%
labels = pd.read_csv('unbalanced_train_segments.csv',header=2, quotechar=r'"',skipinitialspace=True)
laugh_labels = pd.read_csv('laugh_labels.csv',names=['num','label','description'])
not_laugh_labels = pd.read_csv('human_non_laugh_labels.csv',names=['num','label','description'])
l_str = '|'.join(laugh_labels['label'].values)

# %%
n_str = '|'.join(not_laugh_labels['label'].values)
labels['not_laughter'] = (labels['positive_labels'].str.contains(n_str) & ~labels['positive_labels'].str.contains(l_str))

# %% [markdown]
# ## Eval set

# %%
# %%time
labels = pd.read_csv('eval_segments.csv',header=2, quotechar=r'"',skipinitialspace=True)
labels['laughter'] = labels['positive_labels'].str.contains(l_str)
labels['not_laughter'] = (labels['positive_labels'].str.contains(n_str) & ~labels['positive_labels'].str.contains(l_str))


positive = labels[labels['laughter']==True]
negative = labels[labels['not_laughter']==True].sample(positive.shape[0])
subset = positive.append(negative)
subset.to_csv('eval_laugh_speech_training_subset.csv')
print(subset.shape[0])


files = glob.glob('audioset_v1_embeddings/eval/*')
subset_ids = subset['# YTID'].values

i=0
writer = tf.python_io.TFRecordWriter('eval_laugh_speech_subset.tfrecord')
for tfrecord in files:
    for example in tf.python_io.tf_record_iterator(tfrecord):
        tf_example = tf.train.Example.FromString(example)
        vid_id = tf_example.features.feature['video_id'].bytes_list.value[0].decode(encoding = 'UTF-8')
        if vid_id in subset_ids:
            writer.write(example)
            i+=1
print(i)

writer.close()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0703 02:56:43.392501 139973038393216 deprecation.py:323] From <timed exec>:19: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# 586
# 586
# CPU times: user 20.1 s, sys: 1.11 s, total: 21.2 s
# Wall time: 21.3 s

# %% [markdown]
# ## train set

# %%
# !pip install tqdm
from tqdm import tqdm
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (4.28.1)

# %% [markdown]
# #### Warning: The audioset dataset is large and this will take a while to run. It took about 2 hours to process.

# %%
# %%time
labels = pd.read_csv('unbalanced_train_segments.csv',header=2, quotechar=r'"',skipinitialspace=True)
n_str = '|'.join(not_laugh_labels['label'].values)
labels['laughter'] = labels['positive_labels'].str.contains(l_str)
labels['not_laughter'] = (labels['positive_labels'].str.contains(n_str) & ~labels['positive_labels'].str.contains(l_str))

positive = labels[labels['laughter']==True]
negative = labels[labels['not_laughter']==True].sample(positive.shape[0])
subset = positive.append(negative)
subset.to_csv('laugh_speech_training_subset.csv')

print(subset.shape[0])

import glob
files = glob.glob('audioset_v1_embeddings/unbal_train/*')
subset_ids = subset['# YTID'].values

i=0
writer = tf.python_io.TFRecordWriter('bal_laugh_speech_subset.tfrecord')
for tfrecord in tqdm(files):
    for example in tf.python_io.tf_record_iterator(tfrecord):
        tf_example = tf.train.Example.FromString(example)
        vid_id = tf_example.features.feature['video_id'].bytes_list.value[0].decode(encoding = 'UTF-8')
        if vid_id in subset_ids:
            writer.write(example)
            i+=1
print(i)

writer.close()
# Out:
#   0%|          | 0/4096 [00:00<?, ?it/s]
# 18768
#  32%|███▏      | 1297/4096 [11:56<24:56,  1.87it/s]

# %% [markdown]
# This is only necessary if you want to download from Colab

# %%
from google.colab import files
files.download('bal_laugh_speech_subset.tfrecord')

# %%
files.download('eval_laugh_speech_subset.tfrecord')
