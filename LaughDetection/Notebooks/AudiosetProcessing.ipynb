# %% [markdown]
# # Creating an Audioset subset
#
# First, we need to download the full [Audioset](https://research.google.com/audioset/download.html) dataset. This is about 2.5GB so it may take some time to download.
#
# ### NOTE: The Audioset data is stored with filenames that are case sensitive. If you are using a filesystem with case-insensitive filenames (such as macOS) 75% of the dataset will be overwritten when you decompress the archive. You should only run this on a Linux machine.

# %%
# !wget http://storage.googleapis.com/us_audioset/youtube_corpus/v1/features/features.tar.gz
# Out:
# --2019-07-20 14:34:47--  http://storage.googleapis.com/us_audioset/youtube_corpus/v1/features/features.tar.gz
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.20.128, 2607:f8b0:400e:c09::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.20.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2588881044 (2.4G) [application/octet-stream]
# Saving to: ‘features.tar.gz’
#
# features.tar.gz     100%[===================>]   2.41G  20.3MB/s    in 45s
#
# 2019-07-20 14:35:33 (55.2 MB/s) - ‘features.tar.gz’ saved [2588881044/2588881044]

# %%
# !wget http://storage.googleapis.com/us_audioset/youtube_corpus/v1/csv/unbalanced_train_segments.csv
# Out:
# --2019-07-20 14:35:42--  http://storage.googleapis.com/us_audioset/youtube_corpus/v1/csv/unbalanced_train_segments.csv
# Resolving storage.googleapis.com (storage.googleapis.com)... 74.125.142.128, 2607:f8b0:400e:c08::80
# Connecting to storage.googleapis.com (storage.googleapis.com)|74.125.142.128|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 101468408 (97M) [application/octet-stream]
# Saving to: ‘unbalanced_train_segments.csv’
#
# unbalanced_train_se 100%[===================>]  96.77M   210MB/s    in 0.5s
#
# 2019-07-20 14:35:42 (210 MB/s) - ‘unbalanced_train_segments.csv’ saved [101468408/101468408]

# %%
# !tar xvzf features.tar.gz
# Out:
# audioset_v1_embeddings/
# audioset_v1_embeddings/eval/
# audioset_v1_embeddings/eval/W8.tfrecord
# audioset_v1_embeddings/eval/L3.tfrecord
# audioset_v1_embeddings/eval/KO.tfrecord
# audioset_v1_embeddings/eval/xt.tfrecord
# audioset_v1_embeddings/eval/Ul.tfrecord
# audioset_v1_embeddings/eval/2T.tfrecord
# audioset_v1_embeddings/eval/bC.tfrecord
# audioset_v1_embeddings/eval/sG.tfrecord
# audioset_v1_embeddings/eval/JB.tfrecord
# audioset_v1_embeddings/eval/oU.tfrecord
# audioset_v1_embeddings/eval/D1.tfrecord
# audioset_v1_embeddings/eval/ph.tfrecord
# audioset_v1_embeddings/eval/qA.tfrecord
# audioset_v1_embeddings/eval/1v.tfrecord
# audioset_v1_embeddings/eval/Vu.tfrecord
# audioset_v1_embeddings/eval/70.tfrecord
# audioset_v1_embeddings/eval/mV.tfrecord
# audioset_v1_embeddings/eval/aK.tfrecord
# audioset_v1_embeddings/eval/Ph.tfrecord
# audioset_v1_embeddings/eval/is.tfrecord
# audioset_v1_embeddings/eval/ka.tfrecord
# audioset_v1_embeddings/eval/Jk.tfrecord
# audioset_v1_embeddings/eval/e0.tfrecord
# audioset_v1_embeddings/eval/22.tfrecord
# audioset_v1_embeddings/eval/0U.tfrecord
# audioset_v1_embeddings/eval/hC.tfrecord
# audioset_v1_embeddings/eval/0O.tfrecord
# audioset_v1_embeddings/eval/4g.tfrecord
# audioset_v1_embeddings/eval/qI.tfrecord
# audioset_v1_embeddings/eval/aT.tfrecord
# audioset_v1_embeddings/eval/Sh.tfrecord
# audioset_v1_embeddings/eval/7h.tfrecord
# audioset_v1_embeddings/eval/dl.tfrecord
# audioset_v1_embeddings/eval/GM.tfrecord
# audioset_v1_embeddings/eval/Oz.tfrecord
# audioset_v1_embeddings/eval/Nk.tfrecord
# audioset_v1_embeddings/eval/Q6.tfrecord
# audioset_v1_embeddings/eval/VE.tfrecord
# audioset_v1_embeddings/eval/J7.tfrecord
# audioset_v1_embeddings/eval/-L.tfrecord
# audioset_v1_embeddings/eval/4b.tfrecord
# audioset_v1_embeddings/eval/zE.tfrecord
# audioset_v1_embeddings/eval/qx.tfrecord
# audioset_v1_embeddings/eval/gA.tfrecord
# audioset_v1_embeddings/eval/6P.tfrecord
# audioset_v1_embeddings/eval/qL.tfrecord
# audioset_v1_embeddings/eval/ov.tfrecord
# audioset_v1_embeddings/eval/Wm.tfrecord
# audioset_v1_embeddings/eval/5K.tfrecord
# audioset_v1_embeddings/eval/rI.tfrecord
# audioset_v1_embeddings/eval/--.tfrecord
# audioset_v1_embeddings/eval/k8.tfrecord
# audioset_v1_embeddings/eval/5p.tfrecord
# audioset_v1_embeddings/eval/cS.tfrecord
# audioset_v1_embeddings/eval/RV.tfrecord
# audioset_v1_embeddings/eval/t7.tfrecord
# audioset_v1_embeddings/eval/IG.tfrecord
# audioset_v1_embeddings/eval/Nm.tfrecord
# audioset_v1_embeddings/eval/qW.tfrecord
# audioset_v1_embeddings/eval/UR.tfrecord
# audioset_v1_embeddings/eval/7w.tfrecord
# audioset_v1_embeddings/eval/Fb.tfrecord
# audioset_v1_embeddings/eval/1j.tfrecord
# audioset_v1_embeddings/eval/Vk.tfrecord
# audioset_v1_embeddings/eval/9C.tfrecord
# audioset_v1_embeddings/eval/Jo.tfrecord
# audioset_v1_embeddings/eval/D6.tfrecord
# audioset_v1_embeddings/eval/59.tfrecord
# audioset_v1_embeddings/eval/h4.tfrecord
# audioset_v1_embeddings/eval/u0.tfrecord
# audioset_v1_embeddings/eval/dY.tfrecord
# audioset_v1_embeddings/eval/z2.tfrecord
# audioset_v1_embeddings/eval/Nv.tfrecord
# audioset_v1_embeddings/eval/yh.tfrecord
# audioset_v1_embeddings/eval/k2.tfrecord
# audioset_v1_embeddings/eval/b2.tfrecord
# audioset_v1_embeddings/eval/_a.tfrecord
# audioset_v1_embeddings/eval/Vd.tfrecord
# audioset_v1_embeddings/eval/XV.tfrecord
# audioset_v1_embeddings/eval/ag.tfrecord
# audioset_v1_embeddings/eval/V7.tfrecord
# audioset_v1_embeddings/eval/zH.tfrecord
# audioset_v1_embeddings/eval/CT.tfrecord
# audioset_v1_embeddings/eval/Eq.tfrecord
# audioset_v1_embeddings/eval/MI.tfrecord
# audioset_v1_embeddings/eval/RX.tfrecord
# audioset_v1_embeddings/eval/Pt.tfrecord
# audioset_v1_embeddings/eval/2V.tfrecord
# audioset_v1_embeddings/eval/g6.tfrecord
# audioset_v1_embeddings/eval/zh.tfrecord
# audioset_v1_embeddings/eval/wc.tfrecord
# audioset_v1_embeddings/eval/yS.tfrecord
# audioset_v1_embeddings/eval/tE.tfrecord
# audioset_v1_embeddings/eval/Xb.tfrecord
# audioset_v1_embeddings/eval/ir.tfrecord
# audioset_v1_embeddings/eval/MT.tfrecord
# audioset_v1_embeddings/eval/_q.tfrecord
# audioset_v1_embeddings/eval/ln.tfrecord
# audioset_v1_embeddings/eval/UU.tfrecord
# audioset_v1_embeddings/eval/uP.tfrecord
# audioset_v1_embeddings/eval/6Q.tfrecord
# audioset_v1_embeddings/eval/oi.tfrecord
# audioset_v1_embeddings/eval/N5.tfrecord
# audioset_v1_embeddings/eval/Qc.tfrecord
# audioset_v1_embeddings/eval/Op.tfrecord
# audioset_v1_embeddings/eval/Gf.tfrecord
# audioset_v1_embeddings/eval/_c.tfrecord
# audioset_v1_embeddings/eval/QQ.tfrecord
# audioset_v1_embeddings/eval/Z7.tfrecord
# audioset_v1_embeddings/eval/yj.tfrecord
# audioset_v1_embeddings/eval/Ij.tfrecord
# audioset_v1_embeddings/eval/g3.tfrecord
# audioset_v1_embeddings/eval/hi.tfrecord
# audioset_v1_embeddings/eval/Ey.tfrecord
# audioset_v1_embeddings/eval/E5.tfrecord
# audioset_v1_embeddings/eval/bg.tfrecord
# audioset_v1_embeddings/eval/2h.tfrecord
# audioset_v1_embeddings/eval/JS.tfrecord
# audioset_v1_embeddings/eval/Q4.tfrecord
# audioset_v1_embeddings/eval/wH.tfrecord
# audioset_v1_embeddings/eval/2x.tfrecord
# audioset_v1_embeddings/eval/G6.tfrecord
# audioset_v1_embeddings/eval/VF.tfrecord
# audioset_v1_embeddings/eval/S4.tfrecord
# audioset_v1_embeddings/eval/7g.tfrecord
# audioset_v1_embeddings/eval/Er.tfrecord
# audioset_v1_embeddings/eval/0A.tfrecord
# audioset_v1_embeddings/eval/Sy.tfrecord
# audioset_v1_embeddings/eval/fm.tfrecord
# audioset_v1_embeddings/eval/f-.tfrecord
# audioset_v1_embeddings/eval/Kr.tfrecord
# audioset_v1_embeddings/eval/v3.tfrecord
# audioset_v1_embeddings/eval/Cn.tfrecord
# audioset_v1_embeddings/eval/Yr.tfrecord
# audioset_v1_embeddings/eval/R4.tfrecord
# audioset_v1_embeddings/eval/N2.tfrecord
# audioset_v1_embeddings/eval/L_.tfrecord
# audioset_v1_embeddings/eval/v4.tfrecord
# audioset_v1_embeddings/eval/0C.tfrecord
# audioset_v1_embeddings/eval/1o.tfrecord
# audioset_v1_embeddings/eval/v5.tfrecord
# audioset_v1_embeddings/eval/x9.tfrecord
# audioset_v1_embeddings/eval/gq.tfrecord
# audioset_v1_embeddings/eval/HD.tfrecord
# audioset_v1_embeddings/eval/R2.tfrecord
# audioset_v1_embeddings/eval/OE.tfrecord
# audioset_v1_embeddings/eval/os.tfrecord
# audioset_v1_embeddings/eval/d3.tfrecord
# audioset_v1_embeddings/eval/P-.tfrecord
# audioset_v1_embeddings/eval/vh.tfrecord
# audioset_v1_embeddings/eval/Du.tfrecord
# audioset_v1_embeddings/eval/FV.tfrecord
# audioset_v1_embeddings/eval/1g.tfrecord
# audioset_v1_embeddings/eval/ij.tfrecord
# audioset_v1_embeddings/eval/Zl.tfrecord
# audioset_v1_embeddings/eval/ZC.tfrecord
# audioset_v1_embeddings/eval/ul.tfrecord
# audioset_v1_embeddings/eval/Vn.tfrecord
# audioset_v1_embeddings/eval/l5.tfrecord
# audioset_v1_embeddings/eval/9z.tfrecord
# audioset_v1_embeddings/eval/WP.tfrecord
# audioset_v1_embeddings/eval/mQ.tfrecord
# audioset_v1_embeddings/eval/6O.tfrecord
# audioset_v1_embeddings/eval/ae.tfrecord
# audioset_v1_embeddings/eval/G4.tfrecord
# audioset_v1_embeddings/eval/VC.tfrecord
# audioset_v1_embeddings/eval/04.tfrecord
# audioset_v1_embeddings/eval/Zw.tfrecord
# audioset_v1_embeddings/eval/yx.tfrecord
# audioset_v1_embeddings/eval/0a.tfrecord
# audioset_v1_embeddings/eval/M7.tfrecord
# audioset_v1_embeddings/eval/AX.tfrecord
# audioset_v1_embeddings/eval/LE.tfrecord
# audioset_v1_embeddings/eval/Ta.tfrecord
# audioset_v1_embeddings/eval/6D.tfrecord
# audioset_v1_embeddings/eval/7S.tfrecord
# audioset_v1_embeddings/eval/MH.tfrecord
# audioset_v1_embeddings/eval/kW.tfrecord
# audioset_v1_embeddings/eval/pR.tfrecord
# audioset_v1_embeddings/eval/as.tfrecord
# audioset_v1_embeddings/eval/aX.tfrecord
# audioset_v1_embeddings/eval/Gq.tfrecord
# audioset_v1_embeddings/eval/pt.tfrecord
# audioset_v1_embeddings/eval/7v.tfrecord
# audioset_v1_embeddings/eval/5w.tfrecord
# audioset_v1_embeddings/eval/HS.tfrecord
# audioset_v1_embeddings/eval/6Z.tfrecord
# audioset_v1_embeddings/eval/Li.tfrecord
# audioset_v1_embeddings/eval/kr.tfrecord
# audioset_v1_embeddings/eval/iZ.tfrecord
# audioset_v1_embeddings/eval/VP.tfrecord
# audioset_v1_embeddings/eval/H0.tfrecord
# audioset_v1_embeddings/eval/wD.tfrecord
# audioset_v1_embeddings/eval/pU.tfrecord
# audioset_v1_embeddings/eval/vP.tfrecord
# audioset_v1_embeddings/eval/EG.tfrecord
# audioset_v1_embeddings/eval/5C.tfrecord
# audioset_v1_embeddings/eval/df.tfrecord
# audioset_v1_embeddings/eval/kS.tfrecord
# audioset_v1_embeddings/eval/dC.tfrecord
# audioset_v1_embeddings/eval/NR.tfrecord
# audioset_v1_embeddings/eval/MO.tfrecord
# audioset_v1_embeddings/eval/Ky.tfrecord
# audioset_v1_embeddings/eval/sd.tfrecord
# audioset_v1_embeddings/eval/10.tfrecord
# audioset_v1_embeddings/eval/ST.tfrecord
# audioset_v1_embeddings/eval/VS.tfrecord
# audioset_v1_embeddings/eval/ET.tfrecord
# audioset_v1_embeddings/eval/IP.tfrecord
# audioset_v1_embeddings/eval/nP.tfrecord
# audioset_v1_embeddings/eval/qH.tfrecord
# audioset_v1_embeddings/eval/Ya.tfrecord
# audioset_v1_embeddings/eval/9i.tfrecord
# audioset_v1_embeddings/eval/x4.tfrecord
# audioset_v1_embeddings/eval/XO.tfrecord
# audioset_v1_embeddings/eval/wu.tfrecord
# audioset_v1_embeddings/eval/7F.tfrecord
# audioset_v1_embeddings/eval/Nd.tfrecord
# audioset_v1_embeddings/eval/T3.tfrecord
# audioset_v1_embeddings/eval/-3.tfrecord
# audioset_v1_embeddings/eval/wp.tfrecord
# audioset_v1_embeddings/eval/oV.tfrecord
# audioset_v1_embeddings/eval/Yy.tfrecord
# audioset_v1_embeddings/eval/_I.tfrecord
# audioset_v1_embeddings/eval/n-.tfrecord
# audioset_v1_embeddings/eval/5Y.tfrecord
# audioset_v1_embeddings/eval/5e.tfrecord
# audioset_v1_embeddings/eval/Us.tfrecord
# audioset_v1_embeddings/eval/IQ.tfrecord
# audioset_v1_embeddings/eval/kZ.tfrecord
# audioset_v1_embeddings/eval/LQ.tfrecord
# audioset_v1_embeddings/eval/-J.tfrecord
# audioset_v1_embeddings/eval/gj.tfrecord
# audioset_v1_embeddings/eval/Ha.tfrecord
# audioset_v1_embeddings/eval/qX.tfrecord
# audioset_v1_embeddings/eval/f2.tfrecord
# audioset_v1_embeddings/eval/fJ.tfrecord
# audioset_v1_embeddings/eval/HZ.tfrecord
# audioset_v1_embeddings/eval/Zv.tfrecord
# audioset_v1_embeddings/eval/1d.tfrecord
# audioset_v1_embeddings/eval/bn.tfrecord
# audioset_v1_embeddings/eval/0R.tfrecord
# audioset_v1_embeddings/eval/l_.tfrecord
# audioset_v1_embeddings/eval/zu.tfrecord
# audioset_v1_embeddings/eval/ZA.tfrecord
# audioset_v1_embeddings/eval/6z.tfrecord
# audioset_v1_embeddings/eval/8Z.tfrecord
# audioset_v1_embeddings/eval/eh.tfrecord
# audioset_v1_embeddings/eval/1R.tfrecord
# audioset_v1_embeddings/eval/TI.tfrecord
# audioset_v1_embeddings/eval/nh.tfrecord
# audioset_v1_embeddings/eval/So.tfrecord
# audioset_v1_embeddings/eval/LG.tfrecord
# audioset_v1_embeddings/eval/l3.tfrecord
# audioset_v1_embeddings/eval/o2.tfrecord
# audioset_v1_embeddings/eval/T8.tfrecord
# audioset_v1_embeddings/eval/TC.tfrecord
# audioset_v1_embeddings/eval/rD.tfrecord
# audioset_v1_embeddings/eval/YV.tfrecord
# audioset_v1_embeddings/eval/bO.tfrecord
# audioset_v1_embeddings/eval/5P.tfrecord
# audioset_v1_embeddings/eval/fa.tfrecord
# audioset_v1_embeddings/eval/cT.tfrecord
# audioset_v1_embeddings/eval/lC.tfrecord
# audioset_v1_embeddings/eval/iW.tfrecord
# audioset_v1_embeddings/eval/1K.tfrecord
# audioset_v1_embeddings/eval/Ap.tfrecord
# audioset_v1_embeddings/eval/Yn.tfrecord
# audioset_v1_embeddings/eval/Vo.tfrecord
# audioset_v1_embeddings/eval/LZ.tfrecord
# audioset_v1_embeddings/eval/ak.tfrecord
# audioset_v1_embeddings/eval/64.tfrecord
# audioset_v1_embeddings/eval/io.tfrecord
# audioset_v1_embeddings/eval/Ld.tfrecord
# audioset_v1_embeddings/eval/23.tfrecord
# audioset_v1_embeddings/eval/_D.tfrecord
# audioset_v1_embeddings/eval/ao.tfrecord
# audioset_v1_embeddings/eval/Vm.tfrecord
# audioset_v1_embeddings/eval/94.tfrecord
# audioset_v1_embeddings/eval/zg.tfrecord
# audioset_v1_embeddings/eval/vW.tfrecord
# audioset_v1_embeddings/eval/lp.tfrecord
# audioset_v1_embeddings/eval/2g.tfrecord
# audioset_v1_embeddings/eval/GI.tfrecord
# audioset_v1_embeddings/eval/zm.tfrecord
# audioset_v1_embeddings/eval/1q.tfrecord
# audioset_v1_embeddings/eval/i0.tfrecord
# audioset_v1_embeddings/eval/jT.tfrecord
# audioset_v1_embeddings/eval/28.tfrecord
# audioset_v1_embeddings/eval/mb.tfrecord
# audioset_v1_embeddings/eval/6f.tfrecord
# audioset_v1_embeddings/eval/K6.tfrecord
# audioset_v1_embeddings/eval/es.tfrecord
# audioset_v1_embeddings/eval/69.tfrecord
# audioset_v1_embeddings/eval/pJ.tfrecord
# audioset_v1_embeddings/eval/FQ.tfrecord
# audioset_v1_embeddings/eval/rz.tfrecord
# audioset_v1_embeddings/eval/0V.tfrecord
# audioset_v1_embeddings/eval/lz.tfrecord
# audioset_v1_embeddings/eval/5v.tfrecord
# audioset_v1_embeddings/eval/A3.tfrecord
# audioset_v1_embeddings/eval/Ih.tfrecord
# audioset_v1_embeddings/eval/oq.tfrecord
# audioset_v1_embeddings/eval/z3.tfrecord
# audioset_v1_embeddings/eval/vx.tfrecord
# audioset_v1_embeddings/eval/Oe.tfrecord
# audioset_v1_embeddings/eval/dm.tfrecord
# audioset_v1_embeddings/eval/PZ.tfrecord
# audioset_v1_embeddings/eval/VK.tfrecord
# audioset_v1_embeddings/eval/EI.tfrecord
# audioset_v1_embeddings/eval/5i.tfrecord
# audioset_v1_embeddings/eval/kQ.tfrecord
# audioset_v1_embeddings/eval/bI.tfrecord
# audioset_v1_embeddings/eval/4U.tfrecord
# audioset_v1_embeddings/eval/w-.tfrecord
# audioset_v1_embeddings/eval/TW.tfrecord
# audioset_v1_embeddings/eval/kn.tfrecord
# audioset_v1_embeddings/eval/7G.tfrecord
# audioset_v1_embeddings/eval/O5.tfrecord
# audioset_v1_embeddings/eval/qZ.tfrecord
# audioset_v1_embeddings/eval/pD.tfrecord
# audioset_v1_embeddings/eval/gC.tfrecord
# audioset_v1_embeddings/eval/kM.tfrecord
# audioset_v1_embeddings/eval/3s.tfrecord
# audioset_v1_embeddings/eval/Ff.tfrecord
# audioset_v1_embeddings/eval/r6.tfrecord
# audioset_v1_embeddings/eval/sa.tfrecord
# audioset_v1_embeddings/eval/bT.tfrecord
# audioset_v1_embeddings/eval/eD.tfrecord
# audioset_v1_embeddings/eval/lL.tfrecord
# audioset_v1_embeddings/eval/a2.tfrecord
# audioset_v1_embeddings/eval/t0.tfrecord
# audioset_v1_embeddings/eval/bk.tfrecord
# audioset_v1_embeddings/eval/LB.tfrecord
# audioset_v1_embeddings/eval/mG.tfrecord
# audioset_v1_embeddings/eval/1W.tfrecord
# audioset_v1_embeddings/eval/Ob.tfrecord
# audioset_v1_embeddings/eval/qj.tfrecord
# audioset_v1_embeddings/eval/Ew.tfrecord
# audioset_v1_embeddings/eval/RG.tfrecord
# audioset_v1_embeddings/eval/mg.tfrecord
# audioset_v1_embeddings/eval/wG.tfrecord
# audioset_v1_embeddings/eval/rX.tfrecord
# audioset_v1_embeddings/eval/2e.tfrecord
# audioset_v1_embeddings/eval/eX.tfrecord
# audioset_v1_embeddings/eval/ah.tfrecord
# audioset_v1_embeddings/eval/8b.tfrecord
# audioset_v1_embeddings/eval/GV.tfrecord
# audioset_v1_embeddings/eval/Mv.tfrecord
# audioset_v1_embeddings/eval/s-.tfrecord
# audioset_v1_embeddings/eval/6b.tfrecord
# audioset_v1_embeddings/eval/bA.tfrecord
# audioset_v1_embeddings/eval/sF.tfrecord
# audioset_v1_embeddings/eval/El.tfrecord
# audioset_v1_embeddings/eval/rf.tfrecord
# audioset_v1_embeddings/eval/Hx.tfrecord
# audioset_v1_embeddings/eval/Sw.tfrecord
# audioset_v1_embeddings/eval/SN.tfrecord
# audioset_v1_embeddings/eval/8U.tfrecord
# audioset_v1_embeddings/eval/SK.tfrecord
# audioset_v1_embeddings/eval/yO.tfrecord
# audioset_v1_embeddings/eval/Ig.tfrecord
# audioset_v1_embeddings/eval/Nw.tfrecord
# audioset_v1_embeddings/eval/RU.tfrecord
# audioset_v1_embeddings/eval/xI.tfrecord
# audioset_v1_embeddings/eval/V5.tfrecord
# audioset_v1_embeddings/eval/mf.tfrecord
# audioset_v1_embeddings/eval/Xs.tfrecord
# audioset_v1_embeddings/eval/NX.tfrecord
# audioset_v1_embeddings/eval/8N.tfrecord
# audioset_v1_embeddings/eval/jc.tfrecord
# audioset_v1_embeddings/eval/YT.tfrecord
# audioset_v1_embeddings/eval/97.tfrecord
# audioset_v1_embeddings/eval/Bk.tfrecord
# audioset_v1_embeddings/eval/8Y.tfrecord
# audioset_v1_embeddings/eval/ub.tfrecord
# audioset_v1_embeddings/eval/gF.tfrecord
# audioset_v1_embeddings/eval/SF.tfrecord
# audioset_v1_embeddings/eval/Oh.tfrecord
# audioset_v1_embeddings/eval/ce.tfrecord
# audioset_v1_embeddings/eval/uw.tfrecord
# audioset_v1_embeddings/eval/Mn.tfrecord
# audioset_v1_embeddings/eval/EU.tfrecord
# audioset_v1_embeddings/eval/TZ.tfrecord
# audioset_v1_embeddings/eval/sq.tfrecord
# audioset_v1_embeddings/eval/ug.tfrecord
# audioset_v1_embeddings/eval/r4.tfrecord
# audioset_v1_embeddings/eval/u7.tfrecord
# audioset_v1_embeddings/eval/Zo.tfrecord
# audioset_v1_embeddings/eval/Z6.tfrecord
# audioset_v1_embeddings/eval/I4.tfrecord
# audioset_v1_embeddings/eval/Au.tfrecord
# audioset_v1_embeddings/eval/bx.tfrecord
# audioset_v1_embeddings/eval/Ks.tfrecord
# audioset_v1_embeddings/eval/3k.tfrecord
# audioset_v1_embeddings/eval/t8.tfrecord
# audioset_v1_embeddings/eval/vk.tfrecord
# audioset_v1_embeddings/eval/iI.tfrecord
# audioset_v1_embeddings/eval/cM.tfrecord
# audioset_v1_embeddings/eval/yZ.tfrecord
# audioset_v1_embeddings/eval/1z.tfrecord
# audioset_v1_embeddings/eval/PB.tfrecord
# audioset_v1_embeddings/eval/oG.tfrecord
# audioset_v1_embeddings/eval/C8.tfrecord
# audioset_v1_embeddings/eval/IY.tfrecord
# audioset_v1_embeddings/eval/E9.tfrecord
# audioset_v1_embeddings/eval/t6.tfrecord
# audioset_v1_embeddings/eval/ji.tfrecord
# audioset_v1_embeddings/eval/X6.tfrecord
# audioset_v1_embeddings/eval/5F.tfrecord
# audioset_v1_embeddings/eval/mP.tfrecord
# audioset_v1_embeddings/eval/th.tfrecord
# audioset_v1_embeddings/eval/SV.tfrecord
# audioset_v1_embeddings/eval/4Y.tfrecord
# audioset_v1_embeddings/eval/im.tfrecord
# audioset_v1_embeddings/eval/GQ.tfrecord
# audioset_v1_embeddings/eval/N9.tfrecord
# audioset_v1_embeddings/eval/8W.tfrecord
# audioset_v1_embeddings/eval/y_.tfrecord
# audioset_v1_embeddings/eval/5R.tfrecord
# audioset_v1_embeddings/eval/nF.tfrecord
# audioset_v1_embeddings/eval/xs.tfrecord
# audioset_v1_embeddings/eval/jJ.tfrecord
# audioset_v1_embeddings/eval/Z1.tfrecord
# audioset_v1_embeddings/eval/A6.tfrecord
# audioset_v1_embeddings/eval/NG.tfrecord
# audioset_v1_embeddings/eval/FO.tfrecord
# audioset_v1_embeddings/eval/EY.tfrecord
# audioset_v1_embeddings/eval/oa.tfrecord
# audioset_v1_embeddings/eval/K5.tfrecord
# audioset_v1_embeddings/eval/0Z.tfrecord
# audioset_v1_embeddings/eval/Qk.tfrecord
# audioset_v1_embeddings/eval/A2.tfrecord
# audioset_v1_embeddings/eval/z-.tfrecord
# audioset_v1_embeddings/eval/yL.tfrecord
# audioset_v1_embeddings/eval/Ue.tfrecord
# audioset_v1_embeddings/eval/uC.tfrecord
# audioset_v1_embeddings/eval/9A.tfrecord
# audioset_v1_embeddings/eval/QB.tfrecord
# audioset_v1_embeddings/eval/-H.tfrecord
# audioset_v1_embeddings/eval/yR.tfrecord
# audioset_v1_embeddings/eval/Lg.tfrecord
# audioset_v1_embeddings/eval/Gm.tfrecord
# audioset_v1_embeddings/eval/Ke.tfrecord
# audioset_v1_embeddings/eval/Sg.tfrecord
# audioset_v1_embeddings/eval/gV.tfrecord
# audioset_v1_embeddings/eval/-T.tfrecord
# audioset_v1_embeddings/eval/X2.tfrecord
# audioset_v1_embeddings/eval/Kl.tfrecord
# audioset_v1_embeddings/eval/4p.tfrecord
# audioset_v1_embeddings/eval/mN.tfrecord
# audioset_v1_embeddings/eval/o3.tfrecord
# audioset_v1_embeddings/eval/bN.tfrecord
# audioset_v1_embeddings/eval/hs.tfrecord
# audioset_v1_embeddings/eval/XW.tfrecord
# audioset_v1_embeddings/eval/dA.tfrecord
# audioset_v1_embeddings/eval/0T.tfrecord
# audioset_v1_embeddings/eval/i9.tfrecord
# audioset_v1_embeddings/eval/vN.tfrecord
# audioset_v1_embeddings/eval/jB.tfrecord
# audioset_v1_embeddings/eval/IN.tfrecord
# audioset_v1_embeddings/eval/ps.tfrecord
# audioset_v1_embeddings/eval/pC.tfrecord
# audioset_v1_embeddings/eval/U8.tfrecord
# audioset_v1_embeddings/eval/Qq.tfrecord
# audioset_v1_embeddings/eval/gU.tfrecord
# audioset_v1_embeddings/eval/vt.tfrecord
# audioset_v1_embeddings/eval/1x.tfrecord
# audioset_v1_embeddings/eval/xL.tfrecord
# audioset_v1_embeddings/eval/0c.tfrecord
# audioset_v1_embeddings/eval/Vi.tfrecord
# audioset_v1_embeddings/eval/-t.tfrecord
# audioset_v1_embeddings/eval/Fd.tfrecord
# audioset_v1_embeddings/eval/Yz.tfrecord
# audioset_v1_embeddings/eval/fy.tfrecord
# audioset_v1_embeddings/eval/Hq.tfrecord
# audioset_v1_embeddings/eval/Bn.tfrecord
# audioset_v1_embeddings/eval/QN.tfrecord
# audioset_v1_embeddings/eval/Vx.tfrecord
# audioset_v1_embeddings/eval/gb.tfrecord
# audioset_v1_embeddings/eval/dn.tfrecord
# audioset_v1_embeddings/eval/3C.tfrecord
# audioset_v1_embeddings/eval/1S.tfrecord
# audioset_v1_embeddings/eval/0Q.tfrecord
# audioset_v1_embeddings/eval/kk.tfrecord
# audioset_v1_embeddings/eval/4T.tfrecord
# audioset_v1_embeddings/eval/9w.tfrecord
# audioset_v1_embeddings/eval/Ni.tfrecord
# audioset_v1_embeddings/eval/5c.tfrecord
# audioset_v1_embeddings/eval/p8.tfrecord
# audioset_v1_embeddings/eval/Xw.tfrecord
# audioset_v1_embeddings/eval/wJ.tfrecord
# audioset_v1_embeddings/eval/da.tfrecord
# audioset_v1_embeddings/eval/Qb.tfrecord
# audioset_v1_embeddings/eval/W2.tfrecord
# audioset_v1_embeddings/eval/U2.tfrecord
# audioset_v1_embeddings/eval/TR.tfrecord
# audioset_v1_embeddings/eval/aS.tfrecord
# audioset_v1_embeddings/eval/zT.tfrecord
# audioset_v1_embeddings/eval/9y.tfrecord
# audioset_v1_embeddings/eval/eL.tfrecord
# audioset_v1_embeddings/eval/RN.tfrecord
# audioset_v1_embeddings/eval/C4.tfrecord
# audioset_v1_embeddings/eval/8t.tfrecord
# audioset_v1_embeddings/eval/Pk.tfrecord
# audioset_v1_embeddings/eval/dI.tfrecord
# audioset_v1_embeddings/eval/a4.tfrecord
# audioset_v1_embeddings/eval/kX.tfrecord
# audioset_v1_embeddings/eval/KU.tfrecord
# audioset_v1_embeddings/eval/uk.tfrecord
# audioset_v1_embeddings/eval/-0.tfrecord
# audioset_v1_embeddings/eval/yk.tfrecord
# audioset_v1_embeddings/eval/2p.tfrecord
# audioset_v1_embeddings/eval/EJ.tfrecord
# audioset_v1_embeddings/eval/21.tfrecord
# audioset_v1_embeddings/eval/vw.tfrecord
# audioset_v1_embeddings/eval/Lk.tfrecord
# audioset_v1_embeddings/eval/hy.tfrecord
# audioset_v1_embeddings/eval/sL.tfrecord
# audioset_v1_embeddings/eval/mi.tfrecord
# audioset_v1_embeddings/eval/OJ.tfrecord
# audioset_v1_embeddings/eval/X_.tfrecord
# audioset_v1_embeddings/eval/Dr.tfrecord
# audioset_v1_embeddings/eval/Iu.tfrecord
# audioset_v1_embeddings/eval/U-.tfrecord
# audioset_v1_embeddings/eval/-f.tfrecord
# audioset_v1_embeddings/eval/LK.tfrecord
# audioset_v1_embeddings/eval/i_.tfrecord
# audioset_v1_embeddings/eval/Cb.tfrecord
# audioset_v1_embeddings/eval/RA.tfrecord
# audioset_v1_embeddings/eval/_j.tfrecord
# audioset_v1_embeddings/eval/9-.tfrecord
# audioset_v1_embeddings/eval/4o.tfrecord
# audioset_v1_embeddings/eval/BK.tfrecord
# audioset_v1_embeddings/eval/J-.tfrecord
# audioset_v1_embeddings/eval/9V.tfrecord
# audioset_v1_embeddings/eval/X8.tfrecord
# audioset_v1_embeddings/eval/6G.tfrecord
# audioset_v1_embeddings/eval/hg.tfrecord
# audioset_v1_embeddings/eval/uv.tfrecord
# audioset_v1_embeddings/eval/pv.tfrecord
# audioset_v1_embeddings/eval/sk.tfrecord
# audioset_v1_embeddings/eval/v2.tfrecord
# audioset_v1_embeddings/eval/2N.tfrecord
# audioset_v1_embeddings/eval/IE.tfrecord
# audioset_v1_embeddings/eval/vI.tfrecord
# audioset_v1_embeddings/eval/1G.tfrecord
# audioset_v1_embeddings/eval/4-.tfrecord
# audioset_v1_embeddings/eval/wn.tfrecord
# audioset_v1_embeddings/eval/hL.tfrecord
# audioset_v1_embeddings/eval/3i.tfrecord
# audioset_v1_embeddings/eval/IS.tfrecord
# audioset_v1_embeddings/eval/87.tfrecord
# audioset_v1_embeddings/eval/jj.tfrecord
# audioset_v1_embeddings/eval/lK.tfrecord
# audioset_v1_embeddings/eval/_C.tfrecord
# audioset_v1_embeddings/eval/R_.tfrecord
# audioset_v1_embeddings/eval/FN.tfrecord
# audioset_v1_embeddings/eval/7d.tfrecord
# audioset_v1_embeddings/eval/nt.tfrecord
# audioset_v1_embeddings/eval/5H.tfrecord
# audioset_v1_embeddings/eval/pu.tfrecord
# audioset_v1_embeddings/eval/NM.tfrecord
# audioset_v1_embeddings/eval/OK.tfrecord
# audioset_v1_embeddings/eval/D0.tfrecord
# audioset_v1_embeddings/eval/qD.tfrecord
# audioset_v1_embeddings/eval/Uk.tfrecord
# audioset_v1_embeddings/eval/jz.tfrecord
# audioset_v1_embeddings/eval/ci.tfrecord
# audioset_v1_embeddings/eval/aF.tfrecord
# audioset_v1_embeddings/eval/MF.tfrecord
# audioset_v1_embeddings/eval/B7.tfrecord
# audioset_v1_embeddings/eval/gi.tfrecord
# audioset_v1_embeddings/eval/MK.tfrecord
# audioset_v1_embeddings/eval/o9.tfrecord
# audioset_v1_embeddings/eval/m3.tfrecord
# audioset_v1_embeddings/eval/BD.tfrecord
# audioset_v1_embeddings/eval/z1.tfrecord
# audioset_v1_embeddings/eval/i-.tfrecord
# audioset_v1_embeddings/eval/Sc.tfrecord
# audioset_v1_embeddings/eval/EX.tfrecord
# audioset_v1_embeddings/eval/Zu.tfrecord
# audioset_v1_embeddings/eval/eK.tfrecord
# audioset_v1_embeddings/eval/pW.tfrecord
# audioset_v1_embeddings/eval/sg.tfrecord
# audioset_v1_embeddings/eval/EA.tfrecord
# audioset_v1_embeddings/eval/x3.tfrecord
# audioset_v1_embeddings/eval/rL.tfrecord
# audioset_v1_embeddings/eval/o0.tfrecord
# audioset_v1_embeddings/eval/kR.tfrecord
# audioset_v1_embeddings/eval/yA.tfrecord
# audioset_v1_embeddings/eval/vT.tfrecord
# audioset_v1_embeddings/eval/26.tfrecord
# audioset_v1_embeddings/eval/01.tfrecord
# audioset_v1_embeddings/eval/6d.tfrecord
# audioset_v1_embeddings/eval/tf.tfrecord
# audioset_v1_embeddings/eval/Md.tfrecord
# audioset_v1_embeddings/eval/gs.tfrecord
# audioset_v1_embeddings/eval/YO.tfrecord
# audioset_v1_embeddings/eval/0d.tfrecord
# audioset_v1_embeddings/eval/Zq.tfrecord
# audioset_v1_embeddings/eval/Re.tfrecord
# audioset_v1_embeddings/eval/1V.tfrecord
# audioset_v1_embeddings/eval/KB.tfrecord
# audioset_v1_embeddings/eval/Ri.tfrecord
# audioset_v1_embeddings/eval/DR.tfrecord
# audioset_v1_embeddings/eval/Hm.tfrecord
# audioset_v1_embeddings/eval/Pl.tfrecord
# audioset_v1_embeddings/eval/Io.tfrecord
# audioset_v1_embeddings/eval/R9.tfrecord
# audioset_v1_embeddings/eval/YI.tfrecord
# audioset_v1_embeddings/eval/3b.tfrecord
# audioset_v1_embeddings/eval/iv.tfrecord
# audioset_v1_embeddings/eval/fE.tfrecord
# audioset_v1_embeddings/eval/XF.tfrecord
# audioset_v1_embeddings/eval/M6.tfrecord
# audioset_v1_embeddings/eval/ki.tfrecord
# audioset_v1_embeddings/eval/nL.tfrecord
# audioset_v1_embeddings/eval/k4.tfrecord
# audioset_v1_embeddings/eval/jQ.tfrecord
# audioset_v1_embeddings/eval/M_.tfrecord
# audioset_v1_embeddings/eval/f5.tfrecord
# audioset_v1_embeddings/eval/DT.tfrecord
# audioset_v1_embeddings/eval/ts.tfrecord
# audioset_v1_embeddings/eval/BQ.tfrecord
# audioset_v1_embeddings/eval/w7.tfrecord
# audioset_v1_embeddings/eval/vF.tfrecord
# audioset_v1_embeddings/eval/n1.tfrecord
# audioset_v1_embeddings/eval/QV.tfrecord
# audioset_v1_embeddings/eval/J4.tfrecord
# audioset_v1_embeddings/eval/qz.tfrecord
# audioset_v1_embeddings/eval/Ts.tfrecord
# audioset_v1_embeddings/eval/1f.tfrecord
# audioset_v1_embeddings/eval/Hs.tfrecord
# audioset_v1_embeddings/eval/Ln.tfrecord
# audioset_v1_embeddings/eval/Ad.tfrecord
# audioset_v1_embeddings/eval/ES.tfrecord
# audioset_v1_embeddings/eval/f4.tfrecord
# audioset_v1_embeddings/eval/Jz.tfrecord
# audioset_v1_embeddings/eval/9e.tfrecord
# audioset_v1_embeddings/eval/mz.tfrecord
# audioset_v1_embeddings/eval/qr.tfrecord
# audioset_v1_embeddings/eval/Is.tfrecord
# audioset_v1_embeddings/eval/Ek.tfrecord
# audioset_v1_embeddings/eval/VJ.tfrecord
# audioset_v1_embeddings/eval/9U.tfrecord
# audioset_v1_embeddings/eval/rg.tfrecord
# audioset_v1_embeddings/eval/Ys.tfrecord
# audioset_v1_embeddings/eval/Wh.tfrecord
# audioset_v1_embeddings/eval/pn.tfrecord
# audioset_v1_embeddings/eval/In.tfrecord
# audioset_v1_embeddings/eval/9c.tfrecord
# audioset_v1_embeddings/eval/qG.tfrecord
# audioset_v1_embeddings/eval/9g.tfrecord
# audioset_v1_embeddings/eval/LS.tfrecord
# audioset_v1_embeddings/eval/RR.tfrecord
# audioset_v1_embeddings/eval/tN.tfrecord
# audioset_v1_embeddings/eval/90.tfrecord
# audioset_v1_embeddings/eval/1Q.tfrecord
# audioset_v1_embeddings/eval/rc.tfrecord
# audioset_v1_embeddings/eval/n9.tfrecord
# audioset_v1_embeddings/eval/Bl.tfrecord
# audioset_v1_embeddings/eval/8F.tfrecord
# audioset_v1_embeddings/eval/tL.tfrecord
# audioset_v1_embeddings/eval/UM.tfrecord
# audioset_v1_embeddings/eval/rC.tfrecord
# audioset_v1_embeddings/eval/0n.tfrecord
# audioset_v1_embeddings/eval/TJ.tfrecord
# audioset_v1_embeddings/eval/3l.tfrecord
# audioset_v1_embeddings/eval/hA.tfrecord
# audioset_v1_embeddings/eval/6R.tfrecord
# audioset_v1_embeddings/eval/_X.tfrecord
# audioset_v1_embeddings/eval/O4.tfrecord
# audioset_v1_embeddings/eval/80.tfrecord
# audioset_v1_embeddings/eval/XZ.tfrecord
# audioset_v1_embeddings/eval/VT.tfrecord
# audioset_v1_embeddings/eval/6r.tfrecord
# audioset_v1_embeddings/eval/Ep.tfrecord
# audioset_v1_embeddings/eval/jL.tfrecord
# audioset_v1_embeddings/eval/Y3.tfrecord
# audioset_v1_embeddings/eval/gh.tfrecord
# audioset_v1_embeddings/eval/pm.tfrecord
# audioset_v1_embeddings/eval/Dc.tfrecord
# audioset_v1_embeddings/eval/OL.tfrecord
# audioset_v1_embeddings/eval/Rr.tfrecord
# audioset_v1_embeddings/eval/TB.tfrecord
# audioset_v1_embeddings/eval/Qs.tfrecord
# audioset_v1_embeddings/eval/DB.tfrecord
# audioset_v1_embeddings/eval/Bj.tfrecord
# audioset_v1_embeddings/eval/FI.tfrecord
# audioset_v1_embeddings/eval/Ot.tfrecord
# audioset_v1_embeddings/eval/gS.tfrecord
# audioset_v1_embeddings/eval/A7.tfrecord
# audioset_v1_embeddings/eval/hj.tfrecord
# audioset_v1_embeddings/eval/MS.tfrecord
# audioset_v1_embeddings/eval/M9.tfrecord
# audioset_v1_embeddings/eval/Y4.tfrecord
# audioset_v1_embeddings/eval/XQ.tfrecord
# audioset_v1_embeddings/eval/0t.tfrecord
# audioset_v1_embeddings/eval/P7.tfrecord
# audioset_v1_embeddings/eval/MB.tfrecord
# audioset_v1_embeddings/eval/Y0.tfrecord
# audioset_v1_embeddings/eval/vG.tfrecord
# audioset_v1_embeddings/eval/U5.tfrecord
# audioset_v1_embeddings/eval/A5.tfrecord
# audioset_v1_embeddings/eval/zp.tfrecord
# audioset_v1_embeddings/eval/Bx.tfrecord
# audioset_v1_embeddings/eval/X1.tfrecord
# audioset_v1_embeddings/eval/js.tfrecord
# audioset_v1_embeddings/eval/vR.tfrecord
# audioset_v1_embeddings/eval/fx.tfrecord
# audioset_v1_embeddings/eval/iV.tfrecord
# audioset_v1_embeddings/eval/Yi.tfrecord
# audioset_v1_embeddings/eval/oZ.tfrecord
# audioset_v1_embeddings/eval/oY.tfrecord
# audioset_v1_embeddings/eval/We.tfrecord
# audioset_v1_embeddings/eval/RO.tfrecord
# audioset_v1_embeddings/eval/9o.tfrecord
# audioset_v1_embeddings/eval/-D.tfrecord
# audioset_v1_embeddings/eval/Gl.tfrecord
# audioset_v1_embeddings/eval/hq.tfrecord
# audioset_v1_embeddings/eval/0J.tfrecord
# audioset_v1_embeddings/eval/Tn.tfrecord
# audioset_v1_embeddings/eval/6V.tfrecord
# audioset_v1_embeddings/eval/hS.tfrecord
# audioset_v1_embeddings/eval/4r.tfrecord
# audioset_v1_embeddings/eval/YC.tfrecord
# audioset_v1_embeddings/eval/pK.tfrecord
# audioset_v1_embeddings/eval/bE.tfrecord
# audioset_v1_embeddings/eval/15.tfrecord
# audioset_v1_embeddings/eval/G3.tfrecord
# audioset_v1_embeddings/eval/ax.tfrecord
# audioset_v1_embeddings/eval/SX.tfrecord
# audioset_v1_embeddings/eval/Ub.tfrecord
# audioset_v1_embeddings/eval/Mp.tfrecord
# audioset_v1_embeddings/eval/6c.tfrecord
# audioset_v1_embeddings/eval/9O.tfrecord
# audioset_v1_embeddings/eval/1k.tfrecord
# audioset_v1_embeddings/eval/IH.tfrecord
# audioset_v1_embeddings/eval/Vq.tfrecord
# audioset_v1_embeddings/eval/Ma.tfrecord
# audioset_v1_embeddings/eval/9T.tfrecord
# audioset_v1_embeddings/eval/Cu.tfrecord
# audioset_v1_embeddings/eval/Qx.tfrecord
# audioset_v1_embeddings/eval/Z9.tfrecord
# audioset_v1_embeddings/eval/vK.tfrecord
# audioset_v1_embeddings/eval/8q.tfrecord
# audioset_v1_embeddings/eval/DC.tfrecord
# audioset_v1_embeddings/eval/ai.tfrecord
# audioset_v1_embeddings/eval/I-.tfrecord
# audioset_v1_embeddings/eval/_T.tfrecord
# audioset_v1_embeddings/eval/v1.tfrecord
# audioset_v1_embeddings/eval/F8.tfrecord
# audioset_v1_embeddings/eval/qm.tfrecord
# audioset_v1_embeddings/eval/77.tfrecord
# audioset_v1_embeddings/eval/x6.tfrecord
# audioset_v1_embeddings/eval/Hr.tfrecord
# audioset_v1_embeddings/eval/h_.tfrecord
# audioset_v1_embeddings/eval/Cq.tfrecord
# audioset_v1_embeddings/eval/SS.tfrecord
# audioset_v1_embeddings/eval/iD.tfrecord
# audioset_v1_embeddings/eval/c4.tfrecord
# audioset_v1_embeddings/eval/MN.tfrecord
# audioset_v1_embeddings/eval/po.tfrecord
# audioset_v1_embeddings/eval/ZR.tfrecord
# audioset_v1_embeddings/eval/WO.tfrecord
# audioset_v1_embeddings/eval/8E.tfrecord
# audioset_v1_embeddings/eval/C3.tfrecord
# audioset_v1_embeddings/eval/sM.tfrecord
# audioset_v1_embeddings/eval/3c.tfrecord
# audioset_v1_embeddings/eval/7y.tfrecord
# audioset_v1_embeddings/eval/OI.tfrecord
# audioset_v1_embeddings/eval/cN.tfrecord
# audioset_v1_embeddings/eval/1T.tfrecord
# audioset_v1_embeddings/eval/44.tfrecord
# audioset_v1_embeddings/eval/_5.tfrecord
# audioset_v1_embeddings/eval/Ht.tfrecord
# audioset_v1_embeddings/eval/gx.tfrecord
# audioset_v1_embeddings/eval/Qh.tfrecord
# audioset_v1_embeddings/eval/M2.tfrecord
# audioset_v1_embeddings/eval/Hu.tfrecord
# audioset_v1_embeddings/eval/AW.tfrecord
# audioset_v1_embeddings/eval/En.tfrecord
# audioset_v1_embeddings/eval/ud.tfrecord
# audioset_v1_embeddings/eval/Sn.tfrecord
# audioset_v1_embeddings/eval/Rg.tfrecord
# audioset_v1_embeddings/eval/gY.tfrecord
# audioset_v1_embeddings/eval/UZ.tfrecord
# audioset_v1_embeddings/eval/lH.tfrecord
# audioset_v1_embeddings/eval/ft.tfrecord
# audioset_v1_embeddings/eval/Ql.tfrecord
# audioset_v1_embeddings/eval/tY.tfrecord
# audioset_v1_embeddings/eval/GO.tfrecord
# audioset_v1_embeddings/eval/sA.tfrecord
# audioset_v1_embeddings/eval/GX.tfrecord
# audioset_v1_embeddings/eval/Cd.tfrecord
# audioset_v1_embeddings/eval/fQ.tfrecord
# audioset_v1_embeddings/eval/3a.tfrecord
# audioset_v1_embeddings/eval/F6.tfrecord
# audioset_v1_embeddings/eval/hZ.tfrecord
# audioset_v1_embeddings/eval/XM.tfrecord
# audioset_v1_embeddings/eval/6_.tfrecord
# audioset_v1_embeddings/eval/Th.tfrecord
# audioset_v1_embeddings/eval/Mx.tfrecord
# audioset_v1_embeddings/eval/Zi.tfrecord
# audioset_v1_embeddings/eval/MA.tfrecord
# audioset_v1_embeddings/eval/Ux.tfrecord
# audioset_v1_embeddings/eval/dN.tfrecord
# audioset_v1_embeddings/eval/jh.tfrecord
# audioset_v1_embeddings/eval/ur.tfrecord
# audioset_v1_embeddings/eval/tg.tfrecord
# audioset_v1_embeddings/eval/a5.tfrecord
# audioset_v1_embeddings/eval/oR.tfrecord
# audioset_v1_embeddings/eval/ra.tfrecord
# audioset_v1_embeddings/eval/5E.tfrecord
# audioset_v1_embeddings/eval/65.tfrecord
# audioset_v1_embeddings/eval/kY.tfrecord
# audioset_v1_embeddings/eval/aZ.tfrecord
# audioset_v1_embeddings/eval/aL.tfrecord
# audioset_v1_embeddings/eval/7b.tfrecord
# audioset_v1_embeddings/eval/HW.tfrecord
# audioset_v1_embeddings/eval/MJ.tfrecord
# audioset_v1_embeddings/eval/Jx.tfrecord
# audioset_v1_embeddings/eval/SU.tfrecord
# audioset_v1_embeddings/eval/z7.tfrecord
# audioset_v1_embeddings/eval/Ur.tfrecord
# audioset_v1_embeddings/eval/eN.tfrecord
# audioset_v1_embeddings/eval/B3.tfrecord
# audioset_v1_embeddings/eval/1B.tfrecord
# audioset_v1_embeddings/eval/Zt.tfrecord
# audioset_v1_embeddings/eval/mx.tfrecord
# audioset_v1_embeddings/eval/1n.tfrecord
# audioset_v1_embeddings/eval/Vc.tfrecord
# audioset_v1_embeddings/eval/o1.tfrecord
# audioset_v1_embeddings/eval/Xl.tfrecord
# audioset_v1_embeddings/eval/aH.tfrecord
# audioset_v1_embeddings/eval/fD.tfrecord
# audioset_v1_embeddings/eval/0B.tfrecord
# audioset_v1_embeddings/eval/Qt.tfrecord
# audioset_v1_embeddings/eval/Oi.tfrecord
# audioset_v1_embeddings/eval/C2.tfrecord
# audioset_v1_embeddings/eval/8j.tfrecord
# audioset_v1_embeddings/eval/yV.tfrecord
# audioset_v1_embeddings/eval/p7.tfrecord
# audioset_v1_embeddings/eval/I7.tfrecord
# audioset_v1_embeddings/eval/19.tfrecord
# audioset_v1_embeddings/eval/JD.tfrecord
# audioset_v1_embeddings/eval/5M.tfrecord
# audioset_v1_embeddings/eval/3S.tfrecord
# audioset_v1_embeddings/eval/M3.tfrecord
# audioset_v1_embeddings/eval/BX.tfrecord
# audioset_v1_embeddings/eval/sR.tfrecord
# audioset_v1_embeddings/eval/lW.tfrecord
# audioset_v1_embeddings/eval/QR.tfrecord
# audioset_v1_embeddings/eval/-Y.tfrecord
# audioset_v1_embeddings/eval/XD.tfrecord
# audioset_v1_embeddings/eval/fY.tfrecord
# audioset_v1_embeddings/eval/py.tfrecord
# audioset_v1_embeddings/eval/6Y.tfrecord
# audioset_v1_embeddings/eval/z0.tfrecord
# audioset_v1_embeddings/eval/4x.tfrecord
# audioset_v1_embeddings/eval/W-.tfrecord
# audioset_v1_embeddings/eval/ta.tfrecord
# audioset_v1_embeddings/eval/_r.tfrecord
# audioset_v1_embeddings/eval/YG.tfrecord
# audioset_v1_embeddings/eval/HQ.tfrecord
# audioset_v1_embeddings/eval/FE.tfrecord
# audioset_v1_embeddings/eval/Ga.tfrecord
# audioset_v1_embeddings/eval/ed.tfrecord
# audioset_v1_embeddings/eval/xu.tfrecord
# audioset_v1_embeddings/eval/5Z.tfrecord
# audioset_v1_embeddings/eval/J1.tfrecord
# audioset_v1_embeddings/eval/0k.tfrecord
# audioset_v1_embeddings/eval/H5.tfrecord
# audioset_v1_embeddings/eval/ZW.tfrecord
# audioset_v1_embeddings/eval/SC.tfrecord
# audioset_v1_embeddings/eval/Bh.tfrecord
# audioset_v1_embeddings/eval/Y7.tfrecord
# audioset_v1_embeddings/eval/5k.tfrecord
# audioset_v1_embeddings/eval/td.tfrecord
# audioset_v1_embeddings/eval/SJ.tfrecord
# audioset_v1_embeddings/eval/q0.tfrecord
# audioset_v1_embeddings/eval/c0.tfrecord
# audioset_v1_embeddings/eval/Gi.tfrecord
# audioset_v1_embeddings/eval/mm.tfrecord
# audioset_v1_embeddings/eval/aN.tfrecord
# audioset_v1_embeddings/eval/wm.tfrecord
# audioset_v1_embeddings/eval/AB.tfrecord
# audioset_v1_embeddings/eval/EZ.tfrecord
# audioset_v1_embeddings/eval/6l.tfrecord
# audioset_v1_embeddings/eval/Yt.tfrecord
# audioset_v1_embeddings/eval/5X.tfrecord
# audioset_v1_embeddings/eval/cE.tfrecord
# audioset_v1_embeddings/eval/wY.tfrecord
# audioset_v1_embeddings/eval/PH.tfrecord
# audioset_v1_embeddings/eval/hl.tfrecord
# audioset_v1_embeddings/eval/Ev.tfrecord
# audioset_v1_embeddings/eval/NT.tfrecord
# audioset_v1_embeddings/eval/mD.tfrecord
# audioset_v1_embeddings/eval/fj.tfrecord
# audioset_v1_embeddings/eval/tl.tfrecord
# audioset_v1_embeddings/eval/nK.tfrecord
# audioset_v1_embeddings/eval/Uy.tfrecord
# audioset_v1_embeddings/eval/B4.tfrecord
# audioset_v1_embeddings/eval/OZ.tfrecord
# audioset_v1_embeddings/eval/Ny.tfrecord
# audioset_v1_embeddings/eval/d1.tfrecord
# audioset_v1_embeddings/eval/BT.tfrecord
# audioset_v1_embeddings/eval/Uo.tfrecord
# audioset_v1_embeddings/eval/GJ.tfrecord
# audioset_v1_embeddings/eval/34.tfrecord
# audioset_v1_embeddings/eval/5y.tfrecord
# audioset_v1_embeddings/eval/9_.tfrecord
# audioset_v1_embeddings/eval/y-.tfrecord
# audioset_v1_embeddings/eval/_V.tfrecord
# audioset_v1_embeddings/eval/YP.tfrecord
# audioset_v1_embeddings/eval/eO.tfrecord
# audioset_v1_embeddings/eval/6a.tfrecord
# audioset_v1_embeddings/eval/Yo.tfrecord
# audioset_v1_embeddings/eval/H6.tfrecord
# audioset_v1_embeddings/eval/ha.tfrecord
# audioset_v1_embeddings/eval/If.tfrecord
# audioset_v1_embeddings/eval/46.tfrecord
# audioset_v1_embeddings/eval/Cp.tfrecord
# audioset_v1_embeddings/eval/Wx.tfrecord
# audioset_v1_embeddings/eval/Ds.tfrecord
# audioset_v1_embeddings/eval/BG.tfrecord
# audioset_v1_embeddings/eval/qK.tfrecord
# audioset_v1_embeddings/eval/Za.tfrecord
# audioset_v1_embeddings/eval/g0.tfrecord
# audioset_v1_embeddings/eval/zI.tfrecord
# audioset_v1_embeddings/eval/VV.tfrecord
# audioset_v1_embeddings/eval/pj.tfrecord
# audioset_v1_embeddings/eval/7V.tfrecord
# audioset_v1_embeddings/eval/V8.tfrecord
# audioset_v1_embeddings/eval/W_.tfrecord
# audioset_v1_embeddings/eval/hw.tfrecord
# audioset_v1_embeddings/eval/hh.tfrecord
# audioset_v1_embeddings/eval/HN.tfrecord
# audioset_v1_embeddings/eval/HU.tfrecord
# audioset_v1_embeddings/eval/IK.tfrecord
# audioset_v1_embeddings/eval/us.tfrecord
# audioset_v1_embeddings/eval/yW.tfrecord
# audioset_v1_embeddings/eval/1p.tfrecord
# audioset_v1_embeddings/eval/5r.tfrecord
# audioset_v1_embeddings/eval/8T.tfrecord
# audioset_v1_embeddings/eval/N6.tfrecord
# audioset_v1_embeddings/eval/5V.tfrecord
# audioset_v1_embeddings/eval/37.tfrecord
# audioset_v1_embeddings/eval/CS.tfrecord
# audioset_v1_embeddings/eval/rK.tfrecord
# audioset_v1_embeddings/eval/9t.tfrecord
# audioset_v1_embeddings/eval/mE.tfrecord
# audioset_v1_embeddings/eval/ck.tfrecord
# audioset_v1_embeddings/eval/e1.tfrecord
# audioset_v1_embeddings/eval/JH.tfrecord
# audioset_v1_embeddings/eval/Uj.tfrecord
# audioset_v1_embeddings/eval/Zd.tfrecord
# audioset_v1_embeddings/eval/bU.tfrecord
# audioset_v1_embeddings/eval/_H.tfrecord
# audioset_v1_embeddings/eval/Kt.tfrecord
# audioset_v1_embeddings/eval/Wp.tfrecord
# audioset_v1_embeddings/eval/WM.tfrecord
# audioset_v1_embeddings/eval/QC.tfrecord
# audioset_v1_embeddings/eval/wT.tfrecord
# audioset_v1_embeddings/eval/0D.tfrecord
# audioset_v1_embeddings/eval/JL.tfrecord
# audioset_v1_embeddings/eval/uO.tfrecord
# audioset_v1_embeddings/eval/4y.tfrecord
# audioset_v1_embeddings/eval/zd.tfrecord
# audioset_v1_embeddings/eval/o8.tfrecord
# audioset_v1_embeddings/eval/l7.tfrecord
# audioset_v1_embeddings/eval/Lj.tfrecord
# audioset_v1_embeddings/eval/lx.tfrecord
# audioset_v1_embeddings/eval/4q.tfrecord
# audioset_v1_embeddings/eval/FL.tfrecord
# audioset_v1_embeddings/eval/Mb.tfrecord
# audioset_v1_embeddings/eval/Ay.tfrecord
# audioset_v1_embeddings/eval/Qy.tfrecord
# audioset_v1_embeddings/eval/Ls.tfrecord
# audioset_v1_embeddings/eval/TH.tfrecord
# audioset_v1_embeddings/eval/q8.tfrecord
# audioset_v1_embeddings/eval/uA.tfrecord
# audioset_v1_embeddings/eval/Mt.tfrecord
# audioset_v1_embeddings/eval/6m.tfrecord
# audioset_v1_embeddings/eval/qt.tfrecord
# audioset_v1_embeddings/eval/8a.tfrecord
# audioset_v1_embeddings/eval/5d.tfrecord
# audioset_v1_embeddings/eval/tJ.tfrecord
# audioset_v1_embeddings/eval/Xo.tfrecord
# audioset_v1_embeddings/eval/Na.tfrecord
# audioset_v1_embeddings/eval/QE.tfrecord
# audioset_v1_embeddings/eval/B_.tfrecord
# audioset_v1_embeddings/eval/VB.tfrecord
# audioset_v1_embeddings/eval/Tt.tfrecord
# audioset_v1_embeddings/eval/wv.tfrecord
# audioset_v1_embeddings/eval/EC.tfrecord
# audioset_v1_embeddings/eval/bJ.tfrecord
# audioset_v1_embeddings/eval/zc.tfrecord
# audioset_v1_embeddings/eval/N4.tfrecord
# audioset_v1_embeddings/eval/CD.tfrecord
# audioset_v1_embeddings/eval/OQ.tfrecord
# audioset_v1_embeddings/eval/8H.tfrecord
# audioset_v1_embeddings/eval/_p.tfrecord
# audioset_v1_embeddings/eval/XI.tfrecord
# audioset_v1_embeddings/eval/0x.tfrecord
# audioset_v1_embeddings/eval/oN.tfrecord
# audioset_v1_embeddings/eval/mZ.tfrecord
# audioset_v1_embeddings/eval/cX.tfrecord
# audioset_v1_embeddings/eval/On.tfrecord
# audioset_v1_embeddings/eval/3D.tfrecord
# audioset_v1_embeddings/eval/C5.tfrecord
# audioset_v1_embeddings/eval/YW.tfrecord
# audioset_v1_embeddings/eval/dq.tfrecord
# audioset_v1_embeddings/eval/8w.tfrecord
# audioset_v1_embeddings/eval/ie.tfrecord
# audioset_v1_embeddings/eval/IA.tfrecord
# audioset_v1_embeddings/eval/e9.tfrecord
# audioset_v1_embeddings/eval/bW.tfrecord
# audioset_v1_embeddings/eval/fh.tfrecord
# audioset_v1_embeddings/eval/3d.tfrecord
# audioset_v1_embeddings/eval/6p.tfrecord
# audioset_v1_embeddings/eval/ib.tfrecord
# audioset_v1_embeddings/eval/O1.tfrecord
# audioset_v1_embeddings/eval/_A.tfrecord
# audioset_v1_embeddings/eval/2C.tfrecord
# audioset_v1_embeddings/eval/q3.tfrecord
# audioset_v1_embeddings/eval/vi.tfrecord
# audioset_v1_embeddings/eval/Gb.tfrecord
# audioset_v1_embeddings/eval/hd.tfrecord
# audioset_v1_embeddings/eval/YU.tfrecord
# audioset_v1_embeddings/eval/AG.tfrecord
# audioset_v1_embeddings/eval/wy.tfrecord
# audioset_v1_embeddings/eval/DQ.tfrecord
# audioset_v1_embeddings/eval/X4.tfrecord
# audioset_v1_embeddings/eval/86.tfrecord
# audioset_v1_embeddings/eval/5b.tfrecord
# audioset_v1_embeddings/eval/xQ.tfrecord
# audioset_v1_embeddings/eval/SL.tfrecord
# audioset_v1_embeddings/eval/8s.tfrecord
# audioset_v1_embeddings/eval/hu.tfrecord
# audioset_v1_embeddings/eval/vO.tfrecord
# audioset_v1_embeddings/eval/rP.tfrecord
# audioset_v1_embeddings/eval/PK.tfrecord
# audioset_v1_embeddings/eval/RL.tfrecord
# audioset_v1_embeddings/eval/-q.tfrecord
# audioset_v1_embeddings/eval/u1.tfrecord
# audioset_v1_embeddings/eval/yi.tfrecord
# audioset_v1_embeddings/eval/sZ.tfrecord
# audioset_v1_embeddings/eval/Ol.tfrecord
# audioset_v1_embeddings/eval/6S.tfrecord
# audioset_v1_embeddings/eval/xj.tfrecord
# audioset_v1_embeddings/eval/7p.tfrecord
# audioset_v1_embeddings/eval/vH.tfrecord
# audioset_v1_embeddings/eval/fR.tfrecord
# audioset_v1_embeddings/eval/uz.tfrecord
# audioset_v1_embeddings/eval/RS.tfrecord
# audioset_v1_embeddings/eval/oI.tfrecord
# audioset_v1_embeddings/eval/Dk.tfrecord
# audioset_v1_embeddings/eval/7x.tfrecord
# audioset_v1_embeddings/eval/vj.tfrecord
# audioset_v1_embeddings/eval/Gk.tfrecord
# audioset_v1_embeddings/eval/Kb.tfrecord
# audioset_v1_embeddings/eval/ty.tfrecord
# audioset_v1_embeddings/eval/1t.tfrecord
# audioset_v1_embeddings/eval/8h.tfrecord
# audioset_v1_embeddings/eval/XN.tfrecord
# audioset_v1_embeddings/eval/1y.tfrecord
# audioset_v1_embeddings/eval/LO.tfrecord
# audioset_v1_embeddings/eval/pE.tfrecord
# audioset_v1_embeddings/eval/oo.tfrecord
# audioset_v1_embeddings/eval/Xc.tfrecord
# audioset_v1_embeddings/eval/Gj.tfrecord
# audioset_v1_embeddings/eval/F9.tfrecord
# audioset_v1_embeddings/eval/U1.tfrecord
# audioset_v1_embeddings/eval/Y5.tfrecord
# audioset_v1_embeddings/eval/A-.tfrecord
# audioset_v1_embeddings/eval/ja.tfrecord
# audioset_v1_embeddings/eval/rU.tfrecord
# audioset_v1_embeddings/eval/7U.tfrecord
# audioset_v1_embeddings/eval/qi.tfrecord
# audioset_v1_embeddings/eval/An.tfrecord
# audioset_v1_embeddings/eval/rY.tfrecord
# audioset_v1_embeddings/eval/JZ.tfrecord
# audioset_v1_embeddings/eval/MQ.tfrecord
# audioset_v1_embeddings/eval/8L.tfrecord
# audioset_v1_embeddings/eval/sT.tfrecord
# audioset_v1_embeddings/eval/lT.tfrecord
# audioset_v1_embeddings/eval/_8.tfrecord
# audioset_v1_embeddings/eval/Aw.tfrecord
# audioset_v1_embeddings/eval/qB.tfrecord
# audioset_v1_embeddings/eval/3m.tfrecord
# audioset_v1_embeddings/eval/QY.tfrecord
# audioset_v1_embeddings/eval/06.tfrecord
# audioset_v1_embeddings/eval/_L.tfrecord
# audioset_v1_embeddings/eval/E1.tfrecord
# audioset_v1_embeddings/eval/xV.tfrecord
# audioset_v1_embeddings/eval/0P.tfrecord
# audioset_v1_embeddings/eval/E6.tfrecord
# audioset_v1_embeddings/eval/5J.tfrecord
# audioset_v1_embeddings/eval/7z.tfrecord
# audioset_v1_embeddings/eval/lB.tfrecord
# audioset_v1_embeddings/eval/ns.tfrecord
# audioset_v1_embeddings/eval/pI.tfrecord
# audioset_v1_embeddings/eval/fw.tfrecord
# audioset_v1_embeddings/eval/rd.tfrecord
# audioset_v1_embeddings/eval/B-.tfrecord
# audioset_v1_embeddings/eval/qu.tfrecord
# audioset_v1_embeddings/eval/NK.tfrecord
# audioset_v1_embeddings/eval/SY.tfrecord
# audioset_v1_embeddings/eval/0q.tfrecord
# audioset_v1_embeddings/eval/43.tfrecord
# audioset_v1_embeddings/eval/VI.tfrecord
# audioset_v1_embeddings/eval/7r.tfrecord
# audioset_v1_embeddings/eval/MV.tfrecord
# audioset_v1_embeddings/eval/Ry.tfrecord
# audioset_v1_embeddings/eval/eH.tfrecord
# audioset_v1_embeddings/eval/EE.tfrecord
# audioset_v1_embeddings/eval/7P.tfrecord
# audioset_v1_embeddings/eval/dO.tfrecord
# audioset_v1_embeddings/eval/vL.tfrecord
# audioset_v1_embeddings/eval/eF.tfrecord
# audioset_v1_embeddings/eval/dj.tfrecord
# audioset_v1_embeddings/eval/Fi.tfrecord
# audioset_v1_embeddings/eval/dR.tfrecord
# audioset_v1_embeddings/eval/be.tfrecord
# audioset_v1_embeddings/eval/zG.tfrecord
# audioset_v1_embeddings/eval/J0.tfrecord
# audioset_v1_embeddings/eval/XE.tfrecord
# audioset_v1_embeddings/eval/tW.tfrecord
# audioset_v1_embeddings/eval/JX.tfrecord
# audioset_v1_embeddings/eval/du.tfrecord
# audioset_v1_embeddings/eval/Zx.tfrecord
# audioset_v1_embeddings/eval/qJ.tfrecord
# audioset_v1_embeddings/eval/WB.tfrecord
# audioset_v1_embeddings/eval/m2.tfrecord
# audioset_v1_embeddings/eval/6I.tfrecord
# audioset_v1_embeddings/eval/eY.tfrecord
# audioset_v1_embeddings/eval/GB.tfrecord
# audioset_v1_embeddings/eval/I6.tfrecord
# audioset_v1_embeddings/eval/-U.tfrecord
# audioset_v1_embeddings/eval/gg.tfrecord
# audioset_v1_embeddings/eval/uf.tfrecord
# audioset_v1_embeddings/eval/kF.tfrecord
# audioset_v1_embeddings/eval/zO.tfrecord
# audioset_v1_embeddings/eval/m_.tfrecord
# audioset_v1_embeddings/eval/g4.tfrecord
# audioset_v1_embeddings/eval/Bw.tfrecord
# audioset_v1_embeddings/eval/HL.tfrecord
# audioset_v1_embeddings/eval/G1.tfrecord
# audioset_v1_embeddings/eval/G5.tfrecord
# audioset_v1_embeddings/eval/7c.tfrecord
# audioset_v1_embeddings/eval/8J.tfrecord
# audioset_v1_embeddings/eval/Tz.tfrecord
# audioset_v1_embeddings/eval/MP.tfrecord
# audioset_v1_embeddings/eval/Xq.tfrecord
# audioset_v1_embeddings/eval/ZT.tfrecord
# audioset_v1_embeddings/eval/Hv.tfrecord
# audioset_v1_embeddings/eval/9K.tfrecord
# audioset_v1_embeddings/eval/I0.tfrecord
# audioset_v1_embeddings/eval/_n.tfrecord
# audioset_v1_embeddings/eval/r5.tfrecord
# audioset_v1_embeddings/eval/Jb.tfrecord
# audioset_v1_embeddings/eval/kE.tfrecord
# audioset_v1_embeddings/eval/Gv.tfrecord
# audioset_v1_embeddings/eval/Xz.tfrecord
# audioset_v1_embeddings/eval/-r.tfrecord
# audioset_v1_embeddings/eval/4f.tfrecord
# audioset_v1_embeddings/eval/ve.tfrecord
# audioset_v1_embeddings/eval/Fq.tfrecord
# audioset_v1_embeddings/eval/u2.tfrecord
# audioset_v1_embeddings/eval/TF.tfrecord
# audioset_v1_embeddings/eval/Xg.tfrecord
# audioset_v1_embeddings/eval/rJ.tfrecord
# audioset_v1_embeddings/eval/_P.tfrecord
# audioset_v1_embeddings/eval/ws.tfrecord
# audioset_v1_embeddings/eval/0w.tfrecord
# audioset_v1_embeddings/eval/VN.tfrecord
# audioset_v1_embeddings/eval/0N.tfrecord
# audioset_v1_embeddings/eval/LV.tfrecord
# audioset_v1_embeddings/eval/cg.tfrecord
# audioset_v1_embeddings/eval/rE.tfrecord
# audioset_v1_embeddings/eval/Ar.tfrecord
# audioset_v1_embeddings/eval/1i.tfrecord
# audioset_v1_embeddings/eval/UO.tfrecord
# audioset_v1_embeddings/eval/_x.tfrecord
# audioset_v1_embeddings/eval/Em.tfrecord
# audioset_v1_embeddings/eval/0r.tfrecord
# audioset_v1_embeddings/eval/He.tfrecord
# audioset_v1_embeddings/eval/yC.tfrecord
# audioset_v1_embeddings/eval/4D.tfrecord
# audioset_v1_embeddings/eval/Tx.tfrecord
# audioset_v1_embeddings/eval/gQ.tfrecord
# audioset_v1_embeddings/eval/Q0.tfrecord
# audioset_v1_embeddings/eval/8f.tfrecord
# audioset_v1_embeddings/eval/fv.tfrecord
# audioset_v1_embeddings/eval/zJ.tfrecord
# audioset_v1_embeddings/eval/jn.tfrecord
# ...
# audioset_v1_embeddings/unbal_train/ZL.tfrecord
# audioset_v1_embeddings/unbal_train/EN.tfrecord
# audioset_v1_embeddings/unbal_train/ll.tfrecord
# audioset_v1_embeddings/unbal_train/Am.tfrecord
# audioset_v1_embeddings/unbal_train/4k.tfrecord
# audioset_v1_embeddings/unbal_train/Fc.tfrecord
# audioset_v1_embeddings/unbal_train/Nq.tfrecord
# audioset_v1_embeddings/unbal_train/nD.tfrecord
# audioset_v1_embeddings/unbal_train/hW.tfrecord
# audioset_v1_embeddings/unbal_train/pe.tfrecord
# audioset_v1_embeddings/unbal_train/K_.tfrecord
# audioset_v1_embeddings/unbal_train/CK.tfrecord
# audioset_v1_embeddings/unbal_train/IV.tfrecord
# audioset_v1_embeddings/unbal_train/oK.tfrecord
# audioset_v1_embeddings/unbal_train/Qv.tfrecord
# audioset_v1_embeddings/unbal_train/hG.tfrecord
# audioset_v1_embeddings/unbal_train/eJ.tfrecord
# audioset_v1_embeddings/unbal_train/se.tfrecord
# audioset_v1_embeddings/unbal_train/Ik.tfrecord
# audioset_v1_embeddings/unbal_train/OC.tfrecord
# audioset_v1_embeddings/unbal_train/_1.tfrecord
# audioset_v1_embeddings/unbal_train/mO.tfrecord
# audioset_v1_embeddings/unbal_train/HA.tfrecord
# audioset_v1_embeddings/unbal_train/WH.tfrecord
# audioset_v1_embeddings/unbal_train/2s.tfrecord
# audioset_v1_embeddings/unbal_train/GU.tfrecord
# audioset_v1_embeddings/unbal_train/fu.tfrecord
# audioset_v1_embeddings/unbal_train/41.tfrecord
# audioset_v1_embeddings/unbal_train/pq.tfrecord
# audioset_v1_embeddings/unbal_train/bD.tfrecord
# audioset_v1_embeddings/unbal_train/er.tfrecord
# audioset_v1_embeddings/unbal_train/lg.tfrecord
# audioset_v1_embeddings/unbal_train/Jv.tfrecord
# audioset_v1_embeddings/unbal_train/85.tfrecord
# audioset_v1_embeddings/unbal_train/zX.tfrecord
# audioset_v1_embeddings/unbal_train/5g.tfrecord
# audioset_v1_embeddings/unbal_train/GZ.tfrecord
# audioset_v1_embeddings/unbal_train/7s.tfrecord
# audioset_v1_embeddings/unbal_train/qf.tfrecord
# audioset_v1_embeddings/unbal_train/yn.tfrecord
# audioset_v1_embeddings/unbal_train/fC.tfrecord
# audioset_v1_embeddings/unbal_train/kG.tfrecord
# audioset_v1_embeddings/unbal_train/vJ.tfrecord
# audioset_v1_embeddings/unbal_train/S5.tfrecord
# audioset_v1_embeddings/unbal_train/Ia.tfrecord
# audioset_v1_embeddings/unbal_train/KR.tfrecord
# audioset_v1_embeddings/unbal_train/DN.tfrecord
# audioset_v1_embeddings/unbal_train/Bu.tfrecord
# audioset_v1_embeddings/unbal_train/ng.tfrecord
# audioset_v1_embeddings/unbal_train/_K.tfrecord
# audioset_v1_embeddings/unbal_train/RI.tfrecord
# audioset_v1_embeddings/unbal_train/jH.tfrecord
# audioset_v1_embeddings/unbal_train/BL.tfrecord
# audioset_v1_embeddings/unbal_train/6u.tfrecord
# audioset_v1_embeddings/unbal_train/KC.tfrecord
# audioset_v1_embeddings/unbal_train/Ru.tfrecord
# audioset_v1_embeddings/unbal_train/jU.tfrecord
# audioset_v1_embeddings/unbal_train/zS.tfrecord
# audioset_v1_embeddings/unbal_train/-v.tfrecord
# audioset_v1_embeddings/unbal_train/To.tfrecord
# audioset_v1_embeddings/unbal_train/wE.tfrecord
# audioset_v1_embeddings/unbal_train/Ai.tfrecord
# audioset_v1_embeddings/unbal_train/Wr.tfrecord
# audioset_v1_embeddings/unbal_train/Ze.tfrecord
# audioset_v1_embeddings/unbal_train/3M.tfrecord
# audioset_v1_embeddings/unbal_train/ig.tfrecord
# audioset_v1_embeddings/unbal_train/LY.tfrecord
# audioset_v1_embeddings/unbal_train/5t.tfrecord
# audioset_v1_embeddings/unbal_train/YX.tfrecord
# audioset_v1_embeddings/unbal_train/tI.tfrecord
# audioset_v1_embeddings/unbal_train/c9.tfrecord
# audioset_v1_embeddings/unbal_train/Xh.tfrecord
# audioset_v1_embeddings/unbal_train/Mq.tfrecord
# audioset_v1_embeddings/unbal_train/zC.tfrecord
# audioset_v1_embeddings/unbal_train/zW.tfrecord
# audioset_v1_embeddings/unbal_train/sv.tfrecord
# audioset_v1_embeddings/unbal_train/M4.tfrecord
# audioset_v1_embeddings/unbal_train/pc.tfrecord
# audioset_v1_embeddings/unbal_train/Ja.tfrecord
# audioset_v1_embeddings/unbal_train/Ip.tfrecord
# audioset_v1_embeddings/unbal_train/2I.tfrecord
# audioset_v1_embeddings/unbal_train/A0.tfrecord
# audioset_v1_embeddings/unbal_train/C9.tfrecord
# audioset_v1_embeddings/unbal_train/Lh.tfrecord
# audioset_v1_embeddings/unbal_train/Pp.tfrecord
# audioset_v1_embeddings/unbal_train/9F.tfrecord
# audioset_v1_embeddings/unbal_train/5s.tfrecord
# audioset_v1_embeddings/unbal_train/Tm.tfrecord
# audioset_v1_embeddings/unbal_train/QD.tfrecord
# audioset_v1_embeddings/unbal_train/YJ.tfrecord
# audioset_v1_embeddings/unbal_train/UD.tfrecord
# audioset_v1_embeddings/unbal_train/e_.tfrecord
# audioset_v1_embeddings/unbal_train/xn.tfrecord
# audioset_v1_embeddings/unbal_train/E7.tfrecord
# audioset_v1_embeddings/unbal_train/ia.tfrecord
# audioset_v1_embeddings/unbal_train/QU.tfrecord
# audioset_v1_embeddings/unbal_train/Dp.tfrecord
# audioset_v1_embeddings/unbal_train/np.tfrecord
# audioset_v1_embeddings/unbal_train/fI.tfrecord
# audioset_v1_embeddings/unbal_train/mH.tfrecord
# audioset_v1_embeddings/unbal_train/hQ.tfrecord
# audioset_v1_embeddings/unbal_train/XK.tfrecord
# audioset_v1_embeddings/unbal_train/FW.tfrecord
# audioset_v1_embeddings/unbal_train/L0.tfrecord
# audioset_v1_embeddings/unbal_train/pL.tfrecord
# audioset_v1_embeddings/unbal_train/PF.tfrecord
# audioset_v1_embeddings/unbal_train/uD.tfrecord
# audioset_v1_embeddings/unbal_train/cI.tfrecord
# audioset_v1_embeddings/unbal_train/8O.tfrecord
# audioset_v1_embeddings/unbal_train/fc.tfrecord
# audioset_v1_embeddings/unbal_train/wb.tfrecord
# audioset_v1_embeddings/unbal_train/s8.tfrecord
# audioset_v1_embeddings/unbal_train/Rn.tfrecord
# audioset_v1_embeddings/unbal_train/zL.tfrecord
# audioset_v1_embeddings/unbal_train/Ah.tfrecord
# audioset_v1_embeddings/unbal_train/2_.tfrecord
# audioset_v1_embeddings/unbal_train/iA.tfrecord
# audioset_v1_embeddings/unbal_train/mW.tfrecord
# audioset_v1_embeddings/unbal_train/F3.tfrecord
# audioset_v1_embeddings/unbal_train/2R.tfrecord
# audioset_v1_embeddings/unbal_train/Rj.tfrecord
# audioset_v1_embeddings/unbal_train/xP.tfrecord
# audioset_v1_embeddings/unbal_train/eB.tfrecord
# audioset_v1_embeddings/unbal_train/Ox.tfrecord
# audioset_v1_embeddings/unbal_train/L4.tfrecord
# audioset_v1_embeddings/unbal_train/PL.tfrecord
# audioset_v1_embeddings/unbal_train/rk.tfrecord
# audioset_v1_embeddings/unbal_train/jR.tfrecord
# audioset_v1_embeddings/unbal_train/hc.tfrecord
# audioset_v1_embeddings/unbal_train/nx.tfrecord
# audioset_v1_embeddings/unbal_train/Ka.tfrecord
# audioset_v1_embeddings/unbal_train/di.tfrecord
# audioset_v1_embeddings/unbal_train/2K.tfrecord
# audioset_v1_embeddings/unbal_train/6v.tfrecord
# audioset_v1_embeddings/unbal_train/Z2.tfrecord
# audioset_v1_embeddings/unbal_train/o7.tfrecord
# audioset_v1_embeddings/unbal_train/pT.tfrecord
# audioset_v1_embeddings/unbal_train/5S.tfrecord
# audioset_v1_embeddings/unbal_train/yr.tfrecord
# audioset_v1_embeddings/unbal_train/Pd.tfrecord
# audioset_v1_embeddings/unbal_train/d_.tfrecord
# audioset_v1_embeddings/unbal_train/P1.tfrecord
# audioset_v1_embeddings/unbal_train/HT.tfrecord
# audioset_v1_embeddings/unbal_train/fb.tfrecord
# audioset_v1_embeddings/unbal_train/k9.tfrecord
# audioset_v1_embeddings/unbal_train/Kk.tfrecord
# audioset_v1_embeddings/unbal_train/Q_.tfrecord
# audioset_v1_embeddings/unbal_train/6F.tfrecord
# audioset_v1_embeddings/unbal_train/iR.tfrecord
# audioset_v1_embeddings/unbal_train/gw.tfrecord
# audioset_v1_embeddings/unbal_train/8A.tfrecord
# audioset_v1_embeddings/unbal_train/ot.tfrecord
# audioset_v1_embeddings/unbal_train/ZH.tfrecord
# audioset_v1_embeddings/unbal_train/7o.tfrecord
# audioset_v1_embeddings/unbal_train/0f.tfrecord
# audioset_v1_embeddings/unbal_train/aI.tfrecord
# audioset_v1_embeddings/unbal_train/kp.tfrecord
# audioset_v1_embeddings/unbal_train/1l.tfrecord
# audioset_v1_embeddings/unbal_train/AD.tfrecord
# audioset_v1_embeddings/unbal_train/fL.tfrecord
# audioset_v1_embeddings/unbal_train/IM.tfrecord
# audioset_v1_embeddings/unbal_train/_B.tfrecord
# audioset_v1_embeddings/unbal_train/Nn.tfrecord
# audioset_v1_embeddings/unbal_train/oe.tfrecord
# audioset_v1_embeddings/unbal_train/Zh.tfrecord
# audioset_v1_embeddings/unbal_train/Zc.tfrecord
# audioset_v1_embeddings/unbal_train/Go.tfrecord
# audioset_v1_embeddings/unbal_train/Fw.tfrecord
# audioset_v1_embeddings/unbal_train/_i.tfrecord
# audioset_v1_embeddings/unbal_train/6n.tfrecord
# audioset_v1_embeddings/unbal_train/DM.tfrecord
# audioset_v1_embeddings/unbal_train/P5.tfrecord
# audioset_v1_embeddings/unbal_train/7Z.tfrecord
# audioset_v1_embeddings/unbal_train/hE.tfrecord
# audioset_v1_embeddings/unbal_train/M8.tfrecord
# audioset_v1_embeddings/unbal_train/WD.tfrecord
# audioset_v1_embeddings/unbal_train/lS.tfrecord
# audioset_v1_embeddings/unbal_train/Kg.tfrecord
# audioset_v1_embeddings/unbal_train/1M.tfrecord
# audioset_v1_embeddings/unbal_train/Sl.tfrecord
# audioset_v1_embeddings/unbal_train/x8.tfrecord
# audioset_v1_embeddings/unbal_train/K9.tfrecord
# audioset_v1_embeddings/unbal_train/L5.tfrecord
# audioset_v1_embeddings/unbal_train/TP.tfrecord
# audioset_v1_embeddings/unbal_train/Js.tfrecord
# audioset_v1_embeddings/unbal_train/wx.tfrecord
# audioset_v1_embeddings/unbal_train/bs.tfrecord
# audioset_v1_embeddings/unbal_train/kw.tfrecord
# audioset_v1_embeddings/unbal_train/2q.tfrecord
# audioset_v1_embeddings/unbal_train/Cf.tfrecord
# audioset_v1_embeddings/unbal_train/lJ.tfrecord
# audioset_v1_embeddings/unbal_train/Uw.tfrecord
# audioset_v1_embeddings/unbal_train/tF.tfrecord
# audioset_v1_embeddings/unbal_train/_h.tfrecord
# audioset_v1_embeddings/unbal_train/UB.tfrecord
# audioset_v1_embeddings/unbal_train/40.tfrecord
# audioset_v1_embeddings/unbal_train/zQ.tfrecord
# audioset_v1_embeddings/unbal_train/-w.tfrecord
# audioset_v1_embeddings/unbal_train/83.tfrecord
# audioset_v1_embeddings/unbal_train/gE.tfrecord
# audioset_v1_embeddings/unbal_train/7M.tfrecord
# audioset_v1_embeddings/unbal_train/O0.tfrecord
# audioset_v1_embeddings/unbal_train/oH.tfrecord
# audioset_v1_embeddings/unbal_train/Os.tfrecord
# audioset_v1_embeddings/unbal_train/pi.tfrecord
# audioset_v1_embeddings/unbal_train/tC.tfrecord
# audioset_v1_embeddings/unbal_train/WT.tfrecord
# audioset_v1_embeddings/unbal_train/-j.tfrecord
# audioset_v1_embeddings/unbal_train/98.tfrecord
# audioset_v1_embeddings/unbal_train/FB.tfrecord
# audioset_v1_embeddings/unbal_train/Zf.tfrecord
# audioset_v1_embeddings/unbal_train/si.tfrecord
# audioset_v1_embeddings/unbal_train/rt.tfrecord
# audioset_v1_embeddings/unbal_train/GT.tfrecord
# audioset_v1_embeddings/unbal_train/u-.tfrecord
# audioset_v1_embeddings/unbal_train/31.tfrecord
# audioset_v1_embeddings/unbal_train/pz.tfrecord
# audioset_v1_embeddings/unbal_train/oF.tfrecord
# audioset_v1_embeddings/unbal_train/s9.tfrecord
# audioset_v1_embeddings/unbal_train/BM.tfrecord
# audioset_v1_embeddings/unbal_train/2P.tfrecord
# audioset_v1_embeddings/unbal_train/hf.tfrecord
# audioset_v1_embeddings/unbal_train/EK.tfrecord
# audioset_v1_embeddings/unbal_train/zn.tfrecord
# audioset_v1_embeddings/unbal_train/FA.tfrecord
# audioset_v1_embeddings/unbal_train/8D.tfrecord
# audioset_v1_embeddings/unbal_train/eE.tfrecord
# audioset_v1_embeddings/unbal_train/Hd.tfrecord
# audioset_v1_embeddings/unbal_train/t3.tfrecord
# audioset_v1_embeddings/unbal_train/Kh.tfrecord
# audioset_v1_embeddings/unbal_train/8d.tfrecord
# audioset_v1_embeddings/unbal_train/zl.tfrecord
# audioset_v1_embeddings/unbal_train/Nl.tfrecord
# audioset_v1_embeddings/unbal_train/4e.tfrecord
# audioset_v1_embeddings/unbal_train/vZ.tfrecord
# audioset_v1_embeddings/unbal_train/bh.tfrecord
# audioset_v1_embeddings/unbal_train/Cs.tfrecord
# audioset_v1_embeddings/unbal_train/KZ.tfrecord
# audioset_v1_embeddings/unbal_train/2O.tfrecord
# audioset_v1_embeddings/unbal_train/Uc.tfrecord
# audioset_v1_embeddings/unbal_train/uq.tfrecord
# audioset_v1_embeddings/unbal_train/7B.tfrecord
# audioset_v1_embeddings/unbal_train/LX.tfrecord
# audioset_v1_embeddings/unbal_train/Y-.tfrecord
# audioset_v1_embeddings/unbal_train/rA.tfrecord
# audioset_v1_embeddings/unbal_train/F2.tfrecord
# audioset_v1_embeddings/unbal_train/RH.tfrecord
# audioset_v1_embeddings/unbal_train/_M.tfrecord
# audioset_v1_embeddings/unbal_train/pH.tfrecord
# audioset_v1_embeddings/unbal_train/uS.tfrecord
# audioset_v1_embeddings/unbal_train/Es.tfrecord
# audioset_v1_embeddings/unbal_train/F7.tfrecord
# audioset_v1_embeddings/unbal_train/KK.tfrecord
# audioset_v1_embeddings/unbal_train/aY.tfrecord
# audioset_v1_embeddings/unbal_train/_m.tfrecord
# audioset_v1_embeddings/unbal_train/4V.tfrecord
# audioset_v1_embeddings/unbal_train/-G.tfrecord
# audioset_v1_embeddings/unbal_train/w9.tfrecord
# audioset_v1_embeddings/unbal_train/20.tfrecord
# audioset_v1_embeddings/unbal_train/4v.tfrecord
# audioset_v1_embeddings/unbal_train/3W.tfrecord
# audioset_v1_embeddings/unbal_train/ZM.tfrecord
# audioset_v1_embeddings/unbal_train/BH.tfrecord
# audioset_v1_embeddings/unbal_train/jF.tfrecord
# audioset_v1_embeddings/unbal_train/-6.tfrecord
# audioset_v1_embeddings/unbal_train/4E.tfrecord
# audioset_v1_embeddings/unbal_train/W4.tfrecord
# audioset_v1_embeddings/unbal_train/zx.tfrecord
# audioset_v1_embeddings/unbal_train/tZ.tfrecord
# audioset_v1_embeddings/unbal_train/y6.tfrecord
# audioset_v1_embeddings/unbal_train/bz.tfrecord
# audioset_v1_embeddings/unbal_train/zz.tfrecord
# audioset_v1_embeddings/unbal_train/Tw.tfrecord
# audioset_v1_embeddings/unbal_train/0l.tfrecord
# audioset_v1_embeddings/unbal_train/Yw.tfrecord
# audioset_v1_embeddings/unbal_train/kP.tfrecord
# audioset_v1_embeddings/unbal_train/MZ.tfrecord
# audioset_v1_embeddings/unbal_train/zo.tfrecord
# audioset_v1_embeddings/unbal_train/NP.tfrecord
# audioset_v1_embeddings/unbal_train/p2.tfrecord
# audioset_v1_embeddings/unbal_train/Wd.tfrecord
# audioset_v1_embeddings/unbal_train/Hw.tfrecord
# audioset_v1_embeddings/unbal_train/gz.tfrecord
# audioset_v1_embeddings/unbal_train/29.tfrecord
# audioset_v1_embeddings/unbal_train/G_.tfrecord
# audioset_v1_embeddings/unbal_train/T2.tfrecord
# audioset_v1_embeddings/unbal_train/Nb.tfrecord
# audioset_v1_embeddings/unbal_train/i6.tfrecord
# audioset_v1_embeddings/unbal_train/fA.tfrecord
# audioset_v1_embeddings/unbal_train/lv.tfrecord
# audioset_v1_embeddings/unbal_train/3h.tfrecord
# audioset_v1_embeddings/unbal_train/tx.tfrecord
# audioset_v1_embeddings/unbal_train/UF.tfrecord
# audioset_v1_embeddings/unbal_train/QJ.tfrecord
# audioset_v1_embeddings/unbal_train/Q9.tfrecord
# audioset_v1_embeddings/unbal_train/9u.tfrecord
# audioset_v1_embeddings/unbal_train/4Q.tfrecord
# audioset_v1_embeddings/unbal_train/1O.tfrecord
# audioset_v1_embeddings/unbal_train/47.tfrecord
# audioset_v1_embeddings/unbal_train/vq.tfrecord
# audioset_v1_embeddings/unbal_train/V9.tfrecord
# audioset_v1_embeddings/unbal_train/D9.tfrecord
# audioset_v1_embeddings/unbal_train/bt.tfrecord
# audioset_v1_embeddings/unbal_train/W5.tfrecord
# audioset_v1_embeddings/unbal_train/5U.tfrecord
# audioset_v1_embeddings/unbal_train/wr.tfrecord
# audioset_v1_embeddings/unbal_train/O6.tfrecord
# audioset_v1_embeddings/unbal_train/3o.tfrecord
# audioset_v1_embeddings/unbal_train/Um.tfrecord
# audioset_v1_embeddings/unbal_train/-c.tfrecord
# audioset_v1_embeddings/unbal_train/0p.tfrecord
# audioset_v1_embeddings/unbal_train/pQ.tfrecord
# audioset_v1_embeddings/unbal_train/rG.tfrecord
# audioset_v1_embeddings/unbal_train/tM.tfrecord
# audioset_v1_embeddings/unbal_train/Rm.tfrecord
# audioset_v1_embeddings/unbal_train/C7.tfrecord
# audioset_v1_embeddings/unbal_train/c3.tfrecord
# audioset_v1_embeddings/unbal_train/cs.tfrecord
# audioset_v1_embeddings/unbal_train/4K.tfrecord
# audioset_v1_embeddings/unbal_train/pG.tfrecord
# audioset_v1_embeddings/unbal_train/iw.tfrecord
# audioset_v1_embeddings/unbal_train/OS.tfrecord
# audioset_v1_embeddings/unbal_train/Dn.tfrecord
# audioset_v1_embeddings/unbal_train/Qo.tfrecord
# audioset_v1_embeddings/unbal_train/Br.tfrecord
# audioset_v1_embeddings/unbal_train/18.tfrecord
# audioset_v1_embeddings/unbal_train/Mj.tfrecord
# audioset_v1_embeddings/unbal_train/kz.tfrecord
# audioset_v1_embeddings/unbal_train/xz.tfrecord
# audioset_v1_embeddings/unbal_train/aD.tfrecord
# audioset_v1_embeddings/unbal_train/xr.tfrecord
# audioset_v1_embeddings/unbal_train/1b.tfrecord
# audioset_v1_embeddings/unbal_train/Tv.tfrecord
# audioset_v1_embeddings/unbal_train/QT.tfrecord
# audioset_v1_embeddings/unbal_train/ZJ.tfrecord
# audioset_v1_embeddings/unbal_train/zR.tfrecord
# audioset_v1_embeddings/unbal_train/b6.tfrecord
# audioset_v1_embeddings/unbal_train/oL.tfrecord
# audioset_v1_embeddings/unbal_train/9S.tfrecord
# audioset_v1_embeddings/unbal_train/uG.tfrecord

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import pandas as pd
import glob

# %% [markdown]
# In order to run this on a linux machine, I used this notebook in [Google Colaboratory](https://colab.research.google.com/)
# The following cells are for the uploading of necessary files to the colab instance.
# If you are running this locally, you can skip this section

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-c8b36cab-1579-4ae4-9f65-0353dc94364a" name="files[]" multiple disabled />
#      <output id="result-c8b36cab-1579-4ae4-9f65-0353dc94364a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
for k,v in uploaded.items():
  with open(k,'wb') as f:
    f.write(v)

# %%
uploaded.keys()
# Out:
# dict_keys([])

# %% [markdown]
# Here is where the laughter and not laughter labels are loaded from local .csv files.
# If you want to create a subset using a different category of labels, create new files containing a list of the labels you want to select as your positive and negative classes. You can find a list of all the Audioset labels [here](class_labels_indices.csv)

# %%
labels = pd.read_csv('unbalanced_train_segments.csv',header=2, quotechar=r'"',skipinitialspace=True)
laugh_labels = pd.read_csv('laugh_labels.csv',names=['num','label','description'])
not_laugh_labels = pd.read_csv('human_non_laugh_labels.csv',names=['num','label','description'])
l_str = '|'.join(laugh_labels['label'].values)
print(l_str)
labels.head()
# Out:
# /m/01j3sz|/t/dd00001|/m/07r660_|/m/07s04w4|/m/07sq110|/m/07rgt08
#         # YTID  ...                                    positive_labels
# 0  ---1_cCGK4M  ...  /m/01g50p,/m/0284vy3,/m/06d_3,/m/07jdr,/m/07rwm0c
# 1  ---2_BBVHAA  ...                                           /m/09x0r
# 2  ---B_v8ZoBY  ...                                           /m/04rlf
# 3  ---EDNidJUA  ...              /m/02qldy,/m/02zsn,/m/05zppz,/m/09x0r
# 4  ---N4cFAE1A  ...                                  /m/04rlf,/m/09x0r
#
# [5 rows x 4 columns]

# %%
n_str = '|'.join(not_laugh_labels['label'].values)
labels['not_laughter'] = (labels['positive_labels'].str.contains(n_str) & ~labels['positive_labels'].str.contains(l_str))
labels.head()
print(labels.not_laughter.sum()/ len(labels)) #about 49% of the videos did not have any laughter classes
# Out:
# 0.49183779518843523

# %% [markdown]
# ## Eval set

# %%
# %%time
labels = pd.read_csv('eval_segments.csv',header=2, quotechar=r'"',skipinitialspace=True)
labels['laughter'] = labels['positive_labels'].str.contains(l_str)
labels['not_laughter'] = (labels['positive_labels'].str.contains(n_str) & ~labels['positive_labels'].str.contains(l_str))


positive = labels[labels['laughter']==True]
negative = labels[labels['not_laughter']==True].sample(positive.shape[0])
subset = positive.append(negative)
subset.to_csv('eval_laugh_speech_training_subset.csv')
print(subset.shape[0])


files = glob.glob('audioset_v1_embeddings/eval/*')
subset_ids = subset['# YTID'].values

#this loops through the actual tf record embedding files for the evaluation subset and puts
#them into eval_laugh_speech_subset.tfrecord file
i=0
writer = tf.python_io.TFRecordWriter('eval_laugh_speech_subset.tfrecord')
for tfrecord in files:
    for example in tf.python_io.tf_record_iterator(tfrecord):
        tf_example = tf.train.Example.FromString(example)
        vid_id = tf_example.features.feature['video_id'].bytes_list.value[0].decode(encoding = 'UTF-8')
        if vid_id in subset_ids:
            writer.write(example)
            i+=1
print(i)

writer.close()
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0720 02:44:22.222311 140260003391360 deprecation.py:323] From <timed exec>:21: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# 586
# 586
# CPU times: user 28 s, sys: 984 ms, total: 28.9 s
# Wall time: 29 s

# %%
#investigating the dataframes produced above
positive.head()
#positive.shape

# %%
from google.colab import files
#files.download('bal_laugh_speech_subset.tfrecord')
files.download('eval_laugh_speech_subset.tfrecord')

# %% [markdown]
# ## train set

# %%
# !pip install tqdm
from tqdm import tqdm
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (4.28.1)

# %% [markdown]
# #### Warning: The audioset dataset is large and this will take a while to run. It took about 2 hours to process.

# %%
# %%time
labels = pd.read_csv('unbalanced_train_segments.csv',header=2, quotechar=r'"',skipinitialspace=True)
n_str = '|'.join(not_laugh_labels['label'].values)
labels['laughter'] = labels['positive_labels'].str.contains(l_str)
labels['not_laughter'] = (labels['positive_labels'].str.contains(n_str) & ~labels['positive_labels'].str.contains(l_str))

positive = labels[labels['laughter']==True]
negative = labels[labels['not_laughter']==True].sample(positive.shape[0])
subset = positive.append(negative)
subset.to_csv('laugh_speech_training_subset.csv')

print(subset.shape[0])

import glob
files = glob.glob('audioset_v1_embeddings/unbal_train/*')
subset_ids = subset['# YTID'].values

i=0
writer = tf.python_io.TFRecordWriter('bal_laugh_speech_subset.tfrecord')
for tfrecord in tqdm(files):
    for example in tf.python_io.tf_record_iterator(tfrecord):
        tf_example = tf.train.Example.FromString(example)
        vid_id = tf_example.features.feature['video_id'].bytes_list.value[0].decode(encoding = 'UTF-8')
        if vid_id in subset_ids:
            writer.write(example)
            i+=1
print(i)

writer.close()
print(writer)
# Out:
#   0%|          | 0/4096 [00:00<?, ?it/s]WARNING: Logging before flag parsing goes to stderr.
# W0720 14:37:56.061984 140353652848512 deprecation.py:323] From <timed exec>:20: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# 18768
# 100%|██████████| 4096/4096 [35:08<00:00,  1.42it/s]
# 18768
# <tensorflow.python.lib.io.tf_record.TFRecordWriter object at 0x7fa6568be6a0>
# CPU times: user 35min 9s, sys: 9.98 s, total: 35min 19s
# Wall time: 35min 15s

# %% [markdown]
# This is only necessary if you want to download from Colab

# %%
from google.colab import files
files.download('bal_laugh_speech_subset.tfrecord')

# %%
files.download('eval_laugh_speech_subset.tfrecord')
