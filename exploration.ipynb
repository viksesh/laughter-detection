# %%
import pandas as pd

# %%
#test = pd.read_csv('LaughDetection/Data/balanced_train_segments.csv')
class_labels = pd.read_csv('LaughDetection/Data/class_labels_indices.csv')

# %%
#class_labels.head()
#formatting the class mapping into a dictionary
class_labels.head()
unique_keys = class_labels.mid.values
display_class = class_labels.display_name.values
class_mapping = dict(zip(unique_keys, display_class))

# %%
class_mapping
# Out:
# {'/g/122z_qxw': 'Firecracker',
#  '/m/011k_j': 'Timpani',
#  '/m/01280g': 'Wild animals',
#  '/m/012f08': 'Motor vehicle (road)',
#  '/m/012n7d': 'Ambulance (siren)',
#  '/m/012ndj': 'Fire engine, fire truck (siren)',
#  '/m/012xff': 'Toothbrush',
#  '/m/0130jx': 'Sink (filling or washing)',
#  '/m/013y1f': 'Organ',
#  '/m/0140xf': 'Christmas music',
#  '/m/0145m': 'Afrobeat',
#  '/m/014yck': 'Aircraft engine',
#  '/m/014zdl': 'Explosion',
#  '/m/0150b9': 'Change ringing (campanology)',
#  '/m/0155w': 'Blues',
#  '/m/015jpf': 'Dial tone',
#  '/m/015lz1': 'Singing',
#  '/m/015p6': 'Bird',
#  '/m/015vgc': 'Carnatic music',
#  '/m/015y_n': 'Swing music',
#  '/m/0164x2': 'Music of Africa',
#  '/m/016622': 'Tubular bells',
#  '/m/016cjb': 'Gospel music',
#  '/m/018j2': 'Banjo',
#  '/m/018vs': 'Bass guitar',
#  '/m/018w8': 'Basketball bounce',
#  '/m/0192l': 'Bagpipes',
#  '/m/0195fx': 'Subway, metro, underground',
#  '/m/0199g': 'Bicycle',
#  '/m/019jd': 'Boat, Water vehicle',
# ...
